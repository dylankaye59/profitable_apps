# %% [markdown]
# # Analysing app data from the App Store and Google Play to extract the most profitable insights.
#
# Our aim is to find what type of apps are likely to attract the most users. We are a team of data analysts working at a company that builds Android and IOS mobile apps. We publish our apps on the Google Play and the App Store.
#
# The apps we build at our company are free to download and install, this leads to our main source of revenue being from in-app ads. This means that a higher number of users of our apps means a higher number of engagements with ads and so determines our revenue for any given app. The goal of this project is to analyse data and provide insights that will allow our developer to understand what type of apps would attract the most users and so be most profitable.

# %% [markdown]
# # Opening and exploring the datasets
#
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# As collecting data for over 4 million apps would require a significant amount of time investment and money, we will instead analyse a sample of the data. To avoid spending resources on data collection we will be using two datasets that are suitable for our goals:
#
# * [A dataset](https://www.kaggle.com/lava18/google-play-store-apps) containing data about approximately 10,000 Android apps from Google Play; the data was collected in August 2018. This data can be directly downloaded from [here.](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv)
# * [A dataset](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) containing data about approximately 7,000 iOS apps from the App Store; the data was collected in July 2017. This data can be directly downloaded from [here.](https://dq-content.s3.amazonaws.com/350/AppleStore.csv)
#
# To start we will be opening and exploring the datasets. First we need to open the datasets. In the code below (will describe both operations as simultaneous for the purpose of simplifying the explanation), we will:
#
# * Import the `reader()` from the `csv` module
# * Open the `AppleStore.csv` and `googleplaystore.csv` files using the `open()` function, and assign the outputs to the variables `opened_file1` and `opened_file2` respectively.
# * Read in the opened files using the `reader()` function, and assign the outputs to the variables `read_file1` and `read_file2` separately.
# * Transform the read-in files to a list of lists using the `list()` and save the outputs to the variables `apple_data` and `gps_data` separately
# * Slice the datasets to remove the first row of the data that contains the headers and assign it to the variables `apple_header` and `gps_header` separately.
# * Then assign the remainder of the rows, minus the header row, back to the variables `apple_data` and `gps_data`.

# %%
from csv import reader

#Dataset from the Googleplaystore
opened_file2 = open('googleplaystore.csv')
read_file2 = reader(opened_file2)
gps_data = list(read_file2)
gps_header = gps_data[0]
gps_data = gps_data[1:]

#Dataset from the Applestore
opened_file1 = open('AppleStore.csv')
read_file1 = reader(opened_file1)
apple_data = list(read_file1)
apple_header = apple_data[0]
apple_data = apple_data[1:]

# %% [markdown]
# To make exploring the data easier, we will create a function named `explore_data()`. The code below will be used to create and define the function `explore_data`, in it we will:
#
# * define the `explore_data` function to take in four parameters:
#     * `dataset` - data opened previously and contained as a list of lists
#     * `start` and `end` - both be integers that will represent the start and   end of data slicing
#     * `rows_and_columns` - a boolean that has `False` as a default argument
# * slice the `dataset` using `data[start:end]` and assigning the output to the variable `dataset_slice`
# * loop through `dataset_slice` and for each iteration prints a row using `print(row)` and adds a new line after each row using `print('\n')`
# * Optionally include an `if` statement to print the number of rows and columns if `rows_and_columns` is `True`

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
print(apple_header)
print('\n')
explore_data(apple_data, 0, 4, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %% [markdown]
# In the output above we can see that there are 7197 IOS apps within the App Store data set and 16 columns. The columns that will be most useful for our analysis are `track_name`, `currency`, `price`, `rating_count_tot`, `rating_count_ver`, `cont_rating`, `prime_genre`. For descriptions of the column names, as they are not particularly self explanatory, see the [documentation](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps)
#
# Now lets take a look at the Google Play store dataset.

# %%
print(gps_header)
print('\n')
explore_data(gps_data, 0, 4, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# In the output above we can see that there are 10841 android apps within the Google Play store data set and 13 columns. The columns that will be most useful for our analysis are `App`, `Category`, `rating` `Installs`, `Type`, `Price`, `Content Rating`, `genres`.

# %% [markdown]
# # Deleting Wrong Data
#
# In the [discussion section](https://www.kaggle.com/lava18/google-play-store-apps/discussion) of the Google Play dataset, we can see that [one of the discussions](https://www.kaggle.com/lava18/google-play-store-apps/discussion/164101) describes an error for row 10472. Below we will print the row and compare it to a correct one and the header row.

# %%
print(gps_header) 
print('\n')
print(gps_data[10472])
print('\n')
print(gps_data[11])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['Name Art Photo Editor - Focus n Filters', 'ART_AND_DESIGN', '4.4', '8788', '12M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'July 31, 2018', '1.0.15', '4.0 and up']

# %% [markdown]
# We can see that for row 10472 it has incorrect values for `category` being `1.9` and `Rating` being `19`. The value of `1.9` does not refer to any known category of app due to it being a numerical value and it would seem to be that it was supposed to come under the column `rating`, and the value of `19` is too high for the `rating` column as apps are capped at a maximum rating of 5 on the Google Play Store. It appears this row is missing the `category` value which has shifted the data points to their incorrect positons.
#
# Due to this error we will need to remove this row from the dataset, which we will do in the code below.

# %%
print(len(gps_data)) # Number of rows
del gps_data[10472]
print('\n')
print(gps_data[10472]) # confirming data has been deleted
print('\n')
print(len(gps_data)) # number of rows after deletion
# Out:
# 10841
#
#
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']
#
#
# 10840

# %% [markdown]
# Checking the [discussion section](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/discussion) of the App Store dataset we can see that no wrong data has been reported and so we have left that dataset alone.

# %% [markdown]
# # Duplicate Data
#
# ## Identifying the duplicate data
#
# When we explore the the Google Play dataset it can be seen that there are rows of duplicate app data.
#
# For example instagram appears 4 times in the dataset:

# %%
for app in gps_data:
    name = app[0]
    if name == 'Instagram':
        print(app)
        print('\n')
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# Below we will create two list:
# * one for storing names of duplicate apps and another for storing the name of unique apps.
#
# Here we will loop through the Google Play Store dataset and will do the following:
# * save the app name to the variable `name`
# * if `name` was already in the `unique_apps`, list we appended `name` to the `duplicate_apps` list
# * else if `name` was not in the `unique_apps` list, we appended `name` to the `unique_apps` list.
# * then outside and after the loop we print the length of the `duplicate_apps` list to find the total of apps with duplicate entries within the dataset, as well as some examples.

# %%
duplicate_apps = []
unique_apps = []

for app in gps_data:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
        
print('Number of duplicate apps:', len(duplicate_apps))
print('\n')
print('Examples of duplicate apps:', duplicate_apps[:15])
# Out:
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %% [markdown]
# It is important that we do not keep duplicate data as it can skewer the results of our analysis, so we will need to remove duplicate entries so there is only one per app.
#
# From above we have found there to be 1181 cases of duplicate data, now we could remove duplicate entries at random but instead we can do this a better way using information from within the data.
#
# When looking at the Instagram example earlier you can see what varies between the rows printed is the value of the fourth positon on each row that corresponds to the number of reviews given by users for the app. We can extrapolate from this that the higher number of reviews given will mean that a given row of data is more recent. Using this we can remove all duplicate entries for a given app bar the one with the highest number of reviews.

# %% [markdown]
# ## Removing the duplicate data

# %%
print('Expected length:', len(gps_data) - 1181)
# Out:
# Expected length: 9659

# %% [markdown]
# As seen above when we remove the duplicate data we should be expecting to be left with 9659 rows of unique data.
#
# To remove the duplicate data we will need to:
# * create a dictionary, where each dictionary key is a unique app name and the corresponding dictionary value is the highest number of reviews of that app
# * use the information stored in the dictionary and create a new dataset, which will have only one entry per app (and for each app, we'll only select the entry with the highest number of reviews).

# %%
reviews_max = {}

for app in gps_data:
    name = app[0]
    n_reviews = float(app[3])
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    if name not in reviews_max:
        reviews_max[name] = n_reviews
        
print('Actual length:', len(reviews_max))
# Out:
# Actual length: 9659

# %% [markdown]
# So above we have built the dictionary `reviews_max` which contains each app of the duplicate data with the highest number reviews per app. From the `Actual length` of `9659` we can see that the length of dictionary has reached what we have predicted.
#
# In the code below we are going to use the dictionary `reviews_max` to remove the duplicate rows from `gps_data`:
# * we will start by creating two empty lists: `gps_clean` (to store the new cleaned data set with no duplicate data) and `already_added` (to store the app names)
# * we will loop through the dataset and for each iteration we will:
#     * isolate the name of the app and number of reviews to the variables `name` and `n_reviews` respectively
#     * add the current row of data `app` to the list `gps_clean` and add the app name `name` to the list `already_added` if:
#         * the number of reviews `n_reviews` of the current app is equal to the number of reviews given by that app within the dictionary `reviews_max`, and
#         * that the app name `name` is not in the list `already_added`. This is to make sure that duplicate rows that have the same number of reviews are not added in as well. You can see from the Instagram app data earlier that there are two rows with the same number of reviews and so with just the condition `if n_reviews == reviews_max[name]` both rows of data would be added to the list instead of a desired one.

# %%
gps_clean = []
already_added = []

for app in gps_data:
    name = app[0]
    n_reviews = float(app[3])
    if n_reviews == reviews_max[name] and name not in already_added:
        gps_clean.append(app)
        already_added.append(name)
        
explore_data(gps_clean, 0, 4, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# Using the `explore_data` function we defined earlier we can now confirm that the number of rows of data is now 9659. showing that we have cleaned the data of duplicates successfully.
#
# We will not need to clean the `apple_data` dataset at this point as there are no duplicate entries within that data set:
# * In the code below we modified and ran the code used previously for identifying duplicate data in the `gps_data` dataset.
# * We can see that there are no duplicate apps present within this dataset.

# %%
duplicate_apps2 = []
unique_apps2 = []

for app in apple_data:
    name = app[0]
    if name in unique_apps2:
        duplicate_apps2.append(name)
    else:
        unique_apps2.append(name)
        
print('Number of duplicate apps:', len(duplicate_apps2))
# Out:
# Number of duplicate apps: 0

# %% [markdown]
# # Removing non-english apps
#
# We use English for the apps that we develop at our company and so we would like to analyse only apps that have been designed for an english speaking audience.
#
# Below we see a couple of examples from each dataset which shows that there are non-english apps contained within the datasets.

# %%
print(apple_data[813][1])
print(apple_data[6731][1])
print('\n')
print(gps_clean[4412][0])
print(gps_clean[7940][0])
# Out:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜
#
#
# 中国語 AQリスニング
# لعبة تقدر تربح DZ

# %% [markdown]
# We are not interested in keeping apps that are like the ones shown above so we will remove them. One way to do this is to remove each app with a name containing a symbol that is not commonly used in english text. English text usually includes letters from the English alphabet, numbers composed of digits from 0 to 9, punctuation marks (., !, ?, ;), and other symbols (+, *, /).
#
# These characters that are used within the english text are encoded to ASCII standard and are in the range of 0 to 127. Using this range we can build a function that detects whether a character belongs to the set of common english characters or not.
#
# Using the built-in function `ord()` we can find the corresponding encoded number for each character of a string. We use this in the code below and check whether each characters encoding value is greater than 127, if it is then `False` is returned highlighting that the app is most likely non-english and not relevant for our analytical purposes.

# %%
def is_english(a_string):
    for char in a_string:
        if ord(char) > 127:
            return False
    return True

print(is_english('Instagram'))
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# False
# False
# False

# %% [markdown]
# We can see that the function does work however it is unable to identify english apps that have emojis or characters like `™` as these fall outside the ASCII range and have encoded values of over 127. See the example below:

# %%
print(ord('™'))
print(ord('😜'))
# Out:
# 8482
# 128540

# %% [markdown]
# Using the function `is_english` as it stands will cause us to lose useful data as many apps wil be incorrectly labeled as non-English. To minimise the impact of data loss we will edit the `is_english` function to return `False` if the name of an app has more than 3 characters with encoded numbers that are greater than 127. This means that apps with 3 characters that are emojis or other special characters will still be labeled as english will return `True` in the function

# %%
def is_english(a_string):
    special_char = 0
    for char in a_string:
        if ord(char) > 127:
            special_char += 1
    if special_char > 3:
        return False
    return True

print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
# Out:
# True
# True
# False

# %% [markdown]
# Using the `is_english` function we check the name in each row of data, and if the name satisfies our condition (3 or less characters that are more than 127 in encoded values) then we append the corresponding row of data `app` to the list `gps_english` for the Google Play Store data or to the list `apple_english` for the App Store data.

# %%
gps_english = []
apple_english = []

for app in gps_clean:
    name = app[0]
    if is_english(name) == True:
        gps_english.append(app)
        
for app in apple_data:
    name = app[1]
    if is_english(name) == True:
        apple_english.append(app)
        
explore_data(gps_english, 0, 3, True)
print('\n')
explore_data(apple_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 6183
# Number of columns: 16

# %% [markdown]
# After we have removed the non-english apps from our data we are now left with 9614 apps for the Google Play Store and 6183 for the App Store.

# %% [markdown]
# # Isolating the free apps

# %% [markdown]
# As mentioned in our introduction to this project our company only nuild apps that are free to download and install, and our main source of income comes from in-app adds. Now currently our `gps_english` and `apple_english` datasets contain both free and non-free apps. In the code below we will loop through each dataset to isolate the free apps into two new separate lists `gps_free` for Google Play Store apps and `apple_free` for App Store apps.

# %%
gps_free = []
apple_free = []

for app in gps_english:
    price = 'Free'
    if price == app[6]:
        gps_free.append(app)
        
for app in apple_english:
    price = float(app[4])
    if price == 0:
        apple_free.append(app)
        
explore_data(gps_free, 0, 3, True)
print('\n')
explore_data(apple_free, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 8863
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 3222
# Number of columns: 16

# %% [markdown]
# After exploring the data in the new lists we now have 8863 apps left for the Google Play Store dataset and 3222 apps left for the App Store dataset.

# %% [markdown]
# # Most Common Apps by Genre
#
# As we covered in the introduction, our aim is to identify the types of apps that are liekly to attract the most users as our revenue will be determined by the higher numbers of users that see our in app ads.
#
# To minimize risks and overhead, our validation strategy for an app idea has three steps:
# 1. Build a minimal Android version of the app, and add it to Google Play.
# 2. If the app has a good response from users, we develop it further.
# 3. If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# As we wish to add the app onto both the Google Play Store and the App Store, we need to find app profiles that would be successful in both markets. For instance, a profile that works well for both markets might be a productivity app that makes use of gamification.
#
# To start this analysis we need to determine the most common geeres for each market. For this, we'll need to build frequency tables for a few columns in our datasets.
#
# By inspecting the header row for each data set in the code below the columns that would be most of use are the `Category` and `Genres` columns for the Google Play Store and the `Prime_Genre` column for the App Store.

# %%
print(gps_header)
print('\n')
print(apple_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# In the code below we built two functions to help create frequency tables for the `Category`, `Genres` and `Prime_Genre` columns for the data:
# * One function to generate frequency tables that show percentages
# * Another function we can use to display the percentages in a descending order

# %%
def freq_table(dataset, index):
    data_table = {}
    total = len(dataset)
    for row in dataset:
        column = row[index]
        if column in data_table:
            data_table[column] += 1
        else:
            data_table[column] = 1
    
    for data in data_table:
        data_table[data] = (data_table[data] / total) * 100
    
    return data_table

def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# ## App Store Data
#
# First we start by analysing the frequency table for the `Prime_Genre` column of the App Store Data set below

# %%
display_table(apple_free, -5) # Prime_Genre
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# From the free English apps data we can see that `58.16%` of the apps come under the Genre `Games`, the second most numerous being `Entertainment` at `7.88%`. This is followed by `Photo & Video` at `4.95%`, `Education` at `3.66%` and `Social Networking` at `3.28%`.
#
# From this data it seems that most of the free english apps that are located on the App store have been designed for entertainment (games, photo and video, social networking, sports, music) rather than for practical purposes  (education, shopping, utilities, productivity, lifestyle).
#
# At this point we cannot make a definitive app profile that would be suited to us at this stage for the App Store market. While we can see that Entertainment apps, specifically apps under the category `Games`, occupy more than half of the free english apps on the store this does not show which genre is the most popular or has the most number of users. This only shows which categories of apps are most on offer, which does not necessarily reflect the demand of the users. We will need to make further analyses to pull better conclusions.

# %% [markdown]
# ## Google Play Store Data
#
# Now below we will be analysing the frequency tables for the `Category` and `Genres` columns of the Google Play Store data set. Both these columns seems to serve a similar function within the dataset.

# %%
display_table(gps_free, 1) # Category
# Out:
# FAMILY : 18.898792733837304
# GAME : 9.725826469592688
# TOOLS : 8.462146000225657
# BUSINESS : 4.592124562789123
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.5315355974275078
# SPORTS : 3.396141261423897
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2381812027530184
# HEALTH_AND_FITNESS : 3.0802211440821394
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7939749520478394
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.1621347173643235
# ENTERTAINMENT : 0.9590432133589079
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# EVENTS : 0.7108202640189552
# PARENTING : 0.6544059573507841
# ART_AND_DESIGN : 0.6431230960171499
# COMICS : 0.6205573733498815
# BEAUTY : 0.5979916506826132

# %% [markdown]
# From the free English apps data we can see that `18.89%` of the apps come under the category `Family`, followed by `9.72%` under  `Game` and `8.46%` under `Tools`.
#
# The `Family` category does not give enough clarity so we will investigate it further. From this [article](https://androidcommunity.com/google-play-now-shows-family-category-20150610/) for when the family category was launched on the Google Play Store in 2015 it can be seen that it mostly consists of games and entertainment apps aimed at children.
#
# Even if we class apps under the category `Family` as entertainment (Game, Sports, Social) there is a markedly increase of free english apps that have been designed for practical purposes (Tools, Business, Lifestyle, Productivity, Finance) on the Google Play Store than with the App Store.

# %%
display_table(gps_free, -4) # Genres
# Out:
# Tools : 8.450863138892023
# Entertainment : 6.070179397495204
# Education : 5.348076272142616
# Business : 4.592124562789123
# Productivity : 3.8925871601038025
# Lifestyle : 3.8925871601038025
# Finance : 3.7007785174320205
# Medical : 3.5315355974275078
# Sports : 3.463838429425702
# Personalization : 3.317161232088458
# Communication : 3.2381812027530184
# Action : 3.102786866749408
# Health & Fitness : 3.0802211440821394
# Photography : 2.944826808078529
# News & Magazines : 2.798149610741284
# Social : 2.6627552747376737
# Travel & Local : 2.324269434728647
# Shopping : 2.245289405393208
# Books & Reference : 2.1437436533904997
# Simulation : 2.042197901387792
# Dating : 1.8616721200496444
# Arcade : 1.8503892587160102
# Video Players & Editors : 1.771409229380571
# Casual : 1.7601263680469368
# Maps & Navigation : 1.399074805370642
# Food & Drink : 1.241114746699763
# Puzzle : 1.128286133363421
# Racing : 0.9928917973598104
# Role Playing : 0.9364774906916393
# Libraries & Demo : 0.9364774906916393
# Auto & Vehicles : 0.9251946293580051
# Strategy : 0.9026289066907368
# House & Home : 0.8236488773552973
# Weather : 0.8010831546880289
# Events : 0.7108202640189552
# Adventure : 0.6769716800180525
# Comics : 0.6092745120162473
# Beauty : 0.5979916506826132
# Art & Design : 0.5979916506826132
# Parenting : 0.4964458986799052
# Card : 0.4513144533453684
# Casino : 0.42874873067809993
# Trivia : 0.4174658693444658
# Educational;Education : 0.3949001466771973
# Board : 0.38361728534356315
# Educational : 0.37233442400992894
# Education;Education : 0.33848584000902626
# Word : 0.25950581067358686
# Casual;Pretend Play : 0.2369400880063184
# Music : 0.20309150400541578
# Racing;Action & Adventure : 0.16924292000451313
# Puzzle;Brain Games : 0.16924292000451313
# Entertainment;Music & Video : 0.16924292000451313
# Casual;Brain Games : 0.1353943360036105
# Casual;Action & Adventure : 0.1353943360036105
# Arcade;Action & Adventure : 0.1241114746699763
# Action;Action & Adventure : 0.10154575200270789
# Educational;Pretend Play : 0.09026289066907367
# Simulation;Action & Adventure : 0.07898002933543948
# Parenting;Education : 0.07898002933543948
# Entertainment;Brain Games : 0.07898002933543948
# Board;Brain Games : 0.07898002933543948
# Parenting;Music & Video : 0.06769716800180525
# Educational;Brain Games : 0.06769716800180525
# Casual;Creativity : 0.06769716800180525
# Art & Design;Creativity : 0.06769716800180525
# Education;Pretend Play : 0.05641430666817105
# Role Playing;Pretend Play : 0.045131445334536835
# Education;Creativity : 0.045131445334536835
# Role Playing;Action & Adventure : 0.033848584000902626
# Puzzle;Action & Adventure : 0.033848584000902626
# Entertainment;Creativity : 0.033848584000902626
# Entertainment;Action & Adventure : 0.033848584000902626
# Educational;Creativity : 0.033848584000902626
# Educational;Action & Adventure : 0.033848584000902626
# Education;Music & Video : 0.033848584000902626
# Education;Brain Games : 0.033848584000902626
# Education;Action & Adventure : 0.033848584000902626
# Adventure;Action & Adventure : 0.033848584000902626
# Video Players & Editors;Music & Video : 0.022565722667268417
# Sports;Action & Adventure : 0.022565722667268417
# Simulation;Pretend Play : 0.022565722667268417
# Puzzle;Creativity : 0.022565722667268417
# Music;Music & Video : 0.022565722667268417
# Entertainment;Pretend Play : 0.022565722667268417
# Casual;Education : 0.022565722667268417
# Board;Action & Adventure : 0.022565722667268417
# Video Players & Editors;Creativity : 0.011282861333634209
# Trivia;Education : 0.011282861333634209
# Travel & Local;Action & Adventure : 0.011282861333634209
# Tools;Education : 0.011282861333634209
# Strategy;Education : 0.011282861333634209
# Strategy;Creativity : 0.011282861333634209
# Strategy;Action & Adventure : 0.011282861333634209
# Simulation;Education : 0.011282861333634209
# Role Playing;Brain Games : 0.011282861333634209
# Racing;Pretend Play : 0.011282861333634209
# Puzzle;Education : 0.011282861333634209
# Parenting;Brain Games : 0.011282861333634209
# Music & Audio;Music & Video : 0.011282861333634209
# Lifestyle;Pretend Play : 0.011282861333634209
# Lifestyle;Education : 0.011282861333634209
# Health & Fitness;Education : 0.011282861333634209
# Health & Fitness;Action & Adventure : 0.011282861333634209
# Entertainment;Education : 0.011282861333634209
# Communication;Creativity : 0.011282861333634209
# Comics;Creativity : 0.011282861333634209
# Casual;Music & Video : 0.011282861333634209
# Card;Action & Adventure : 0.011282861333634209
# Books & Reference;Education : 0.011282861333634209
# Art & Design;Pretend Play : 0.011282861333634209
# Art & Design;Action & Adventure : 0.011282861333634209
# Arcade;Pretend Play : 0.011282861333634209
# Adventure;Education : 0.011282861333634209

# %% [markdown]
# The `Genres` column of the dataset seems to contain similar data to that of the `Category` column, but appears to include more nuanced categorisation. However not all of it is clear as we have a genre of `Education` as well as `Educational;Education` and `Education;Education`. For the purposes of this project it makes more sense to use the `Category` column as its more straight forward and less confusing, allowing us to pull the data we need more easily.
#
# From anaylsing what are the most common apps by genre for free english apps we can see that the App Store is predominantly dominated by apps designed for entertainment (mostly under Games) and that the Google Play Store features more of a mix between entertainment and practical uses.

# %% [markdown]
# # Most Popular Apps by Genre on the App Store
#
# To find out what the most popular genres are we need to look for a column in the data that we can use to calculate an average "popularity" value per genre. The App Store data set has no clear winner here so as a workaround we will use the `rating_count_tot` column. The idea being here that the higher the number of user ratings for an app the more popular it should be.
#
# In the code below we will calculate the average number of ratings per genre for the App Store data set and display this information in a descending order:

# %%
apple_freq_genres = freq_table(apple_free, -5)

table_display = []
for genre in apple_freq_genres:
    total = 0
    len_genre = 0
    for row in apple_free:
        genre_app = row[-5]
        if genre_app == genre:
            total += float(row[5])
            len_genre += 1
    average_ratings = total / len_genre
    table_pair = (average_ratings, genre)
    table_display.append(table_pair)
    
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0])
# Out:
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 71548.34905660378
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 39758.5
# Food & Drink : 33333.92307692308
# Finance : 31467.944444444445
# Photo & Video : 28441.54375
# Travel : 28243.8
# Shopping : 26919.690476190477
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22788.6696905016
# News : 21248.023255813954
# Productivity : 21028.410714285714
# Utilities : 18684.456790123455
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Business : 7491.117647058823
# Education : 7003.983050847458
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# From the output above we can see that the genres with the highest number of average user ratings are `Navigation`, `Reference` and `Social Networking`.
#
# Let's have a look at these genres in more detail:
# * Note - we have defined some functions as well below for changing the font of the output text which we will be using going forward.

# %%
def go_bold(a_string):
    return ('\033[1m' + a_string + '\033[0m')

def go_bold_red(a_string):
    return ('\033[1;31m' + a_string + '\033[0m')

def bold_underline(a_string):
    return ('\033[1;4m' + a_string + '\033[0m')

print(go_bold('Navigation'))
for app in apple_free:
    if app[-5] == "Navigation":
        print(app[1], ':', app[5])
        
print('\n')
print(go_bold('Reference'))

for app in apple_free:
    if app[-5] == "Reference":
        print(app[1], ':', app[5])
        
print('\n')
print(go_bold("Social Networking"))

for app in apple_free:
    if app[-5] == "Social Networking":
        print(app[1], ':', app[5])
# Out:
# Navigation
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
#
#
# Reference
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0
#
#
# Social Networking
# Facebook : 2974676
# Pinterest : 1061624
# Skype for iPhone : 373519
# Messenger : 351466
# Tumblr : 334293
# WhatsApp Messenger : 287589
# Kik : 260965
# ooVoo – Free Video Call, Text and Voice : 177501
# TextNow - Unlimited Text + Calls : 164963
# Viber Messenger – Text & Call : 164249
# Followers - Social Analytics For Instagram : 112778
# MeetMe - Chat and Meet New People : 97072
# We Heart It - Fashion, wallpapers, quotes, tattoos : 90414
# InsTrack for Instagram - Analytics Plus More : 85535
# Tango - Free Video Call, Voice and Chat : 75412
# LinkedIn : 71856
# Match™ - #1 Dating App. : 60659
# Skype for iPad : 60163
# POF - Best Dating App for Conversations : 52642
# Timehop : 49510
# Find My Family, Friends & iPhone - Life360 Locator : 43877
# Whisper - Share, Express, Meet : 39819
# Hangouts : 36404
# LINE PLAY - Your Avatar World : 34677
# WeChat : 34584
# Badoo - Meet New People, Chat, Socialize. : 34428
# Followers + for Instagram - Follower Analytics : 28633
# GroupMe : 28260
# Marco Polo Video Walkie Talkie : 27662
# Miitomo : 23965
# SimSimi : 23530
# Grindr - Gay and same sex guys chat, meet and date : 23201
# Wishbone - Compare Anything : 20649
# imo video calls and chat : 18841
# After School - Funny Anonymous School News : 18482
# Quick Reposter - Repost, Regram and Reshare Photos : 17694
# Weibo HD : 16772
# Repost for Instagram : 15185
# Live.me – Live Video Chat & Make Friends Nearby : 14724
# Nextdoor : 14402
# Followers Analytics for Instagram - InstaReport : 13914
# YouNow: Live Stream Video Chat : 12079
# FollowMeter for Instagram - Followers Tracking : 11976
# LINE : 11437
# eHarmony™ Dating App - Meet Singles : 11124
# Discord - Chat for Gamers : 9152
# QQ : 9109
# Telegram Messenger : 7573
# Weibo : 7265
# Periscope - Live Video Streaming Around the World : 6062
# Chat for Whatsapp - iPad Version : 5060
# QQ HD : 5058
# Followers Analysis Tool For Instagram App Free : 4253
# live.ly - live video streaming : 4145
# Houseparty - Group Video Chat : 3991
# SOMA Messenger : 3232
# Monkey : 3060
# Down To Lunch : 2535
# Flinch - Video Chat Staring Contest : 2134
# Highrise - Your Avatar Community : 2011
# LOVOO - Dating Chat : 1985
# PlayStation®Messages : 1918
# BOO! - Video chat camera with filters & stickers : 1805
# Qzone : 1649
# Chatous - Chat with new people : 1609
# Kiwi - Q&A : 1538
# GhostCodes - a discovery app for Snapchat : 1313
# Jodel : 1193
# FireChat : 1037
# Google Duo - simple video calling : 1033
# Fiesta by Tango - Chat & Meet New People : 885
# Google Allo — smart messaging : 862
# Peach — share vividly : 727
# Hey! VINA - Where Women Meet New Friends : 719
# Battlefield™ Companion : 689
# All Devices for WhatsApp - Messenger for iPad : 682
# Chat for Pokemon Go - GoChat : 500
# IAmNaughty – Dating App to Meet New People Online : 463
# Qzone HD : 458
# Zenly - Locate your friends in realtime : 427
# League of Legends Friends : 420
# 豆瓣 : 407
# Candid - Speak Your Mind Freely : 398
# 知乎 : 397
# Selfeo : 366
# Fake-A-Location Free ™ : 354
# Popcorn Buzz - Free Group Calls : 281
# Fam — Group video calling for iMessage : 279
# QQ International : 274
# Ameba : 269
# SoundCloud Pulse: for creators : 240
# Tantan : 235
# Cougar Dating & Life Style App for Mature Women : 213
# Rawr Messenger - Dab your chat : 180
# WhenToPost: Best Time to Post Photos for Instagram : 158
# Inke—Broadcast an amazing life : 147
# Mustknow - anonymous video Q&A : 53
# CTFxCmoji : 39
# Lobi : 36
# Chain: Collaborate On MyVideo Story/Group Video : 35
# botman - Real time video chat : 7
# BestieBox : 0
# MATCH ON LINE chat : 0
# niconico ch : 0
# LINE BLOG : 0
# bit-tube - Live Stream Video Chat : 0

# %% [markdown]
# From the `Navigation`, `Reference` and `Social Networking` genres it appears that their average number of user ratings are being skewed by a few very popular apps. The market these genres entail would be much harder for our company to break into due to the dominance by apps with a signficant audience and share of the local market on the store.
#
# To verify this and investigate further of the top three genres, below We will define a function called `genre_rating` that takes the variable `genre` as a parameter. This function will:
# * take in a parameter that takes in a string that corresponds to one of the genre names from the `Prime_Genre` (index `-5`) column in the App Store data set.
# * Create 2 variables for counting the total amount of user ratings (`total`) as well as the total for just the apps with over 100,000 (`big_total`). 2 variables for counting the physical total number of apps (`number_apps`) and for the number of apps that count over 100,000 user ratings (`number_big_apps`)
# * use `app` to iterate over the `apple_free` data set:
#     * Uses an `if` statement within this loop to count the number of big apps within the defined parameter (`genre`) and total their amount of user ratings.
#         * This `if` statement also contains a condition where `if` `number_big_apps` is less than `3` then the app name and user rating total will be printed. This is to limit the length of the output and allow us to see the two most popular apps for each genre.
#     *  Another `if` statement is used within this loop to count the total number of apps within the defined parameter and total all their user ratings
#         * another `if` statement is included to print the two most popular apps in absence of any in the genre that have over 100,000 user ratings.
# * `print` the total number of apps in a genre, the total number of apps with over 100,000 user ratings in a genre, apps with 100,000+ user ratings with their user ratings as a percentage of the total number of user ratings of all apps in a genre, and finally the total number of apps with 100,000+ user ratings as a percentage of the total number of apps in a genre.

# %%
def genre_rating(genre): # takes a string as input that needs to match a genre 
    print('\n')
    print(bold_underline(genre))
    total = 0
    big_total = 0
    number_apps = 0
    number_big_apps = 0
    for app in apple_free:
        if app[-5] == str(genre) and int(app[5]) > 100000:
            number_big_apps += 1
            if number_big_apps < 3:
                print(app[1], ':', app[5])
            big_total += int(app[5])
        if app[-5] == str(genre):
            total += int(app[5])
            number_apps += 1
            if number_big_apps == 0 and number_apps < 3:
                print(app[1], ':', app[5])
    print(go_bold('Total apps in genre'), ':', number_apps)
    print(go_bold('Total 100000+ apps in genre'), ':', number_big_apps)
    print(go_bold('Percentage of 100000+ apps of total user ratings'), ':', 
           (round(big_total / total, 4) * 100), '%')
    print(go_bold('Percentage of 100000+ apps of total apps'), ':', 
           (round(number_big_apps / number_apps, 4) * 100), '%')
            
genre_rating('Navigation')
genre_rating('Reference')
genre_rating('Social Networking')
# Out:
# Navigation
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Total apps in genre : 6
# Total 100000+ apps in genre : 2
# Percentage of 100000+ apps of total user ratings : 96.78999999999999 %
# Percentage of 100000+ apps of total apps : 33.33 %
#
#
# Reference
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Total apps in genre : 18
# Total 100000+ apps in genre : 2
# Percentage of 100000+ apps of total user ratings : 87.92 %
# Percentage of 100000+ apps of total apps : 11.110000000000001 %
#
#
# Social Networking
# Facebook : 2974676
# Pinterest : 1061624
# Total apps in genre : 106
# Total 100000+ apps in genre : 11
# Percentage of 100000+ apps of total user ratings : 82.59 %
# Percentage of 100000+ apps of total apps : 10.38 %

# %% [markdown]
# Above we have isolated the apps that have over 100000 user ratings (used as proxy for the number of users and so the apps popularity). It appears our initial thoughts were correct (a few apps in the top 3 most popular genres on average are skewing theresults). We also wanted to see what the total share of user ratings would be with the apps with big audiences compared to the total market share for each genre on the App Store.
#
# What we can see is that apps with 100000+ user ratings for the genre `Navigation` consist of `96.79%` of the total user ratings for that genre while only being `33.33%` of the total `Navigation` apps, for `Reference` this is `87.91%` for `11.11%`, and for `Social Networking` this is `82.58%` for `10.38%`.
#
# Now while it appears that in the most popular genres on the App Store they are being dominated by a few large apps, it is also worth invesigating the rest with the `genre_rating` function we have created. That is what we will do below:

# %%
genre_rating('Music')
genre_rating('Weather')
genre_rating('Book')
genre_rating('Food & Drink')
genre_rating('Finance')
genre_rating('Photo & Video')
genre_rating('Travel')
genre_rating('Shopping')
genre_rating('Health & Fitness')
genre_rating('Sports')
genre_rating('Games')
genre_rating('News')
genre_rating('Productivity')
genre_rating('Utilities')
genre_rating('Lifestyle')
genre_rating('Entertainment')
genre_rating('Business')
genre_rating('Education')
genre_rating('Catalogs')
genre_rating('Medical')
# Out:
# Music
# Pandora - Music & Radio : 1126879
# Spotify Music : 878563
# Total apps in genre : 66
# Total 100000+ apps in genre : 9
# Percentage of 100000+ apps of total user ratings : 87.35000000000001 %
# Percentage of 100000+ apps of total apps : 13.639999999999999 %
#
#
# Weather
# The Weather Channel: Forecast, Radar & Alerts : 495626
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 208648
# Total apps in genre : 28
# Total 100000+ apps in genre : 6
# Percentage of 100000+ apps of total user ratings : 88.8 %
# Percentage of 100000+ apps of total apps : 21.43 %
#
#
# Book
# Kindle – Read eBooks, Magazines & Textbooks : 252076
# Audible – audio books, original series & podcasts : 105274
# Total apps in genre : 14
# Total 100000+ apps in genre : 2
# Percentage of 100000+ apps of total user ratings : 64.2 %
# Percentage of 100000+ apps of total apps : 14.29 %
#
#
# Food & Drink
# Starbucks : 303856
# Domino's Pizza USA : 258624
# Total apps in genre : 26
# Total 100000+ apps in genre : 4
# Percentage of 100000+ apps of total user ratings : 90.66 %
# Percentage of 100000+ apps of total apps : 15.379999999999999 %
#
#
# Finance
# Chase Mobile℠ : 233270
# Mint: Personal Finance, Budget, Bills & Money : 232940
# Total apps in genre : 36
# Total 100000+ apps in genre : 5
# Percentage of 100000+ apps of total user ratings : 71.25 %
# Percentage of 100000+ apps of total apps : 13.889999999999999 %
#
#
# Photo & Video
# Instagram : 2161558
# Snapchat : 323905
# Total apps in genre : 160
# Total 100000+ apps in genre : 6
# Percentage of 100000+ apps of total user ratings : 68.47 %
# Percentage of 100000+ apps of total apps : 3.75 %
#
#
# Travel
# Google Earth : 446185
# Yelp - Nearby Restaurants, Shopping & Services : 223885
# Total apps in genre : 40
# Total 100000+ apps in genre : 3
# Percentage of 100000+ apps of total user ratings : 72.19 %
# Percentage of 100000+ apps of total apps : 7.5 %
#
#
# Shopping
# Groupon - Deals, Coupons & Discount Shopping App : 417779
# eBay: Best App to Buy, Sell, Save! Online Shopping : 262241
# Total apps in genre : 84
# Total 100000+ apps in genre : 7
# Percentage of 100000+ apps of total user ratings : 57.089999999999996 %
# Percentage of 100000+ apps of total apps : 8.33 %
#
#
# Health & Fitness
# Calorie Counter & Diet Tracker by MyFitnessPal : 507706
# Lose It! – Weight Loss Program and Calorie Counter : 373835
# Total apps in genre : 65
# Total 100000+ apps in genre : 4
# Percentage of 100000+ apps of total user ratings : 74.15 %
# Percentage of 100000+ apps of total apps : 6.15 %
#
#
# Sports
# ESPN: Get scores, news, alerts & watch live sports : 290996
# Yahoo Fantasy Sports : 190670
# Total apps in genre : 69
# Total 100000+ apps in genre : 5
# Percentage of 100000+ apps of total user ratings : 58.42 %
# Percentage of 100000+ apps of total apps : 7.249999999999999 %
#
#
# Games
# Clash of Clans : 2130805
# Temple Run : 1724546
# Total apps in genre : 1874
# Total 100000+ apps in genre : 109
# Percentage of 100000+ apps of total user ratings : 71.67 %
# Percentage of 100000+ apps of total apps : 5.82 %
#
#
# News
# Twitter : 354058
# Fox News : 132703
# Total apps in genre : 43
# Total 100000+ apps in genre : 3
# Percentage of 100000+ apps of total user ratings : 65.63 %
# Percentage of 100000+ apps of total apps : 6.98 %
#
#
# Productivity
# Evernote - stay organized : 161065
# Gmail - email by Google: secure, fast & organized : 135962
# Total apps in genre : 56
# Total 100000+ apps in genre : 4
# Percentage of 100000+ apps of total user ratings : 45.34 %
# Percentage of 100000+ apps of total apps : 7.140000000000001 %
#
#
# Utilities
# Google – Search made just for mobile : 479440
# Flashlight Ⓞ : 130450
# Total apps in genre : 81
# Total 100000+ apps in genre : 4
# Percentage of 100000+ apps of total user ratings : 55.86 %
# Percentage of 100000+ apps of total apps : 4.9399999999999995 %
#
#
# Lifestyle
# Zillow Real Estate - Homes for Sale & for Rent : 342969
# Tinder : 143040
# Total apps in genre : 51
# Total 100000+ apps in genre : 3
# Percentage of 100000+ apps of total user ratings : 69.76 %
# Percentage of 100000+ apps of total apps : 5.88 %
#
#
# Entertainment
# Netflix : 308844
# Fandango Movies - Times + Tickets : 291787
# Total apps in genre : 254
# Total 100000+ apps in genre : 8
# Percentage of 100000+ apps of total user ratings : 42.980000000000004 %
# Percentage of 100000+ apps of total apps : 3.15 %
#
#
# Business
# Indeed Job Search : 38681
# Flashlight ◎ : 24744
# Total apps in genre : 17
# Total 100000+ apps in genre : 0
# Percentage of 100000+ apps of total user ratings : 0.0 %
# Percentage of 100000+ apps of total apps : 0.0 %
#
#
# Education
# Duolingo - Learn Spanish, French and more : 162701
# Guess My Age  Math Magic : 123190
# Total apps in genre : 118
# Total 100000+ apps in genre : 2
# Percentage of 100000+ apps of total user ratings : 34.589999999999996 %
# Percentage of 100000+ apps of total apps : 1.69 %
#
#
# Catalogs
# CPlus for Craigslist app - mobile classifieds : 13345
# DRAGONS MODS FREE for Minecraft PC Game Edition : 2027
# Total apps in genre : 4
# Total 100000+ apps in genre : 0
# Percentage of 100000+ apps of total user ratings : 0.0 %
# Percentage of 100000+ apps of total apps : 0.0 %
#
#
# Medical
# SnoreLab : Record Your Snoring : 1341
# Blink Health : 1198
# Total apps in genre : 6
# Total 100000+ apps in genre : 0
# Percentage of 100000+ apps of total user ratings : 0.0 %
# Percentage of 100000+ apps of total apps : 0.0 %

# %% [markdown]
# It seems that with most of the genres there are a few apps in each that skew the data of the average number of ratings, we saw this trend earlier in the 3 genres with the highest average user ratings. You see this in the `Games` genre with the apps `Clash of Clans` and `Temple Run`, the `Music` genre with `Pandora` and `Spotify`, and the `Navigation` genre with `Waze` and `Google Maps`.
#
# Now while there are some genres which do not have apps with user ratings that total over 100,000, they do however have very few apps in their category and it can be seen that their most popular apps have much less user ratings than other popular apps in other genres. This can be seen in the genre `Medical` with the apps `Snorelab` and `Blink Health` which have `1341` and `11981` respectively, `Catalogs` with `CPlus` and `DRAGONS MODS` which have `13345` and `2027` respectively, `Business` with `Indeed` and `Flashlight` which have `38681` and `24744`respectively. So while there would be less competition if we were to design apps for these genres, from looking at their popularity the potential for profitability is far less and so we will avoid these genres.
#
# We want to develop for genres that have a high potential for profitability but are not overly saturated with too many apps, as that would make it hard to break into the market due to high levels of competition. Earlier in the project we analysed the percentage of the total apps that each genre had on the App Store, with `Games` making up `58.16%` and `Entertainment` making up `7.88%`. For these genres we should avoid developing our app for, but we could incorporate features from these genres into our app idea as they are popular but instead have our apps primary focus be elsewhere.
#
# As mentioned previously most of the genres contain a few popular apps that skew their data, so unless we want to develop an app for a genre that has a very small market and so low profitability, we need to make a compromise. Looking at the above data we want to select genres that have their total user ratings more spread out over their apps, where there is less domination by a few popular apps and so gives us a better chance to break into said market. We also want genres that are not oversaturated with apps.
#
# Genres that look promising in this regard are:
# * `Book`
# * `Shopping`
# * `Sports`
# * `Productivity`
# * `Utilities`
# * `Education`
#
# To get an idea of the total market share that each of the above genres has on the App Store for free English apps we will create the function `total_genre_rating` and use it to calculate the total amount of user ratings for a genre (and so the genres popularity and its share of the store market), and calculate the percentage that this genre total is of the App Stores combined user ratings. We have done this in the code below and demonstrated the results for each genre:

# %%
def total_genre_rating(genre): # takes a string as input that needs to match a genre 
    print('\n')
    print(bold_underline(genre))
    total_genre = 0
    percent_all_data = 0
    for app in apple_free:
        percent_all_data += int(app[5])
        if app[-5] == str(genre):
            total_genre += int(app[5])
    print(go_bold('Total user ratings for genre'), ':', total_genre)
    print(go_bold('Percentage of genre ratings of the total store ratings'), 
          ':', (round(total_genre / percent_all_data, 4) * 100), '%')

print(go_bold_red("***Genres being considered for app development***"))

total_genre_rating('Shopping')
total_genre_rating('Sports')
total_genre_rating('Utilities')
total_genre_rating('Productivity')
total_genre_rating('Education')
total_genre_rating('Book')

print('\n')
print(go_bold_red("***Other Genres***"))

total_genre_rating('Navigation')
total_genre_rating('Reference')
total_genre_rating('Social Networking')
total_genre_rating('Music')
total_genre_rating('Weather')
total_genre_rating('Food & Drink')
total_genre_rating('Finance')
total_genre_rating('Photo & Video')
total_genre_rating('Travel')
total_genre_rating('Health & Fitness')
total_genre_rating('Games')
total_genre_rating('News')
total_genre_rating('Lifestyle')
total_genre_rating('Entertainment')
total_genre_rating('Business')
total_genre_rating('Catalogs')
total_genre_rating('Medical')
# Out:
# ***Genres being considered for app development***
#
#
# Shopping
# Total user ratings for genre : 2261254
# Percentage of genre ratings of the total store ratings : 2.83 %
#
#
# Sports
# Total user ratings for genre : 1587614
# Percentage of genre ratings of the total store ratings : 1.9800000000000002 %
#
#
# Utilities
# Total user ratings for genre : 1513441
# Percentage of genre ratings of the total store ratings : 1.8900000000000001 %
#
#
# Productivity
# Total user ratings for genre : 1177591
# Percentage of genre ratings of the total store ratings : 1.47 %
#
#
# Education
# Total user ratings for genre : 826470
# Percentage of genre ratings of the total store ratings : 1.03 %
#
#
# Book
# Total user ratings for genre : 556619
# Percentage of genre ratings of the total store ratings : 0.7000000000000001 %
#
#
# ***Other Genres***
#
#
# Navigation
# Total user ratings for genre : 516542
# Percentage of genre ratings of the total store ratings : 0.65 %
#
#
# Reference
# Total user ratings for genre : 1348958
# Percentage of genre ratings of the total store ratings : 1.69 %
#
#
# Social Networking
# Total user ratings for genre : 7584125
# Percentage of genre ratings of the total store ratings : 9.48 %
#
#
# Music
# Total user ratings for genre : 3783551
# Percentage of genre ratings of the total store ratings : 4.73 %
#
#
# Weather
# Total user ratings for genre : 1463837
# Percentage of genre ratings of the total store ratings : 1.83 %
#
#
# Food & Drink
# Total user ratings for genre : 866682
# Percentage of genre ratings of the total store ratings : 1.08 %
#
#
# Finance
# Total user ratings for genre : 1132846
# Percentage of genre ratings of the total store ratings : 1.4200000000000002 %
#
#
# Photo & Video
# Total user ratings for genre : 4550647
# Percentage of genre ratings of the total store ratings : 5.6899999999999995 %
#
#
# Travel
# Total user ratings for genre : 1129752
# Percentage of genre ratings of the total store ratings : 1.41 %
#
#
# Health & Fitness
# Total user ratings for genre : 1514371
# Percentage of genre ratings of the total store ratings : 1.8900000000000001 %
#
#
# Games
# Total user ratings for genre : 42705967
# Percentage of genre ratings of the total store ratings : 53.39 %
#
#
# News
# Total user ratings for genre : 913665
# Percentage of genre ratings of the total store ratings : 1.1400000000000001 %
#
#
# Lifestyle
# Total user ratings for genre : 840774
# Percentage of genre ratings of the total store ratings : 1.05 %
#
#
# Entertainment
# Total user ratings for genre : 3563577
# Percentage of genre ratings of the total store ratings : 4.46 %
#
#
# Business
# Total user ratings for genre : 127349
# Percentage of genre ratings of the total store ratings : 0.16 %
#
#
# Catalogs
# Total user ratings for genre : 16016
# Percentage of genre ratings of the total store ratings : 0.02 %
#
#
# Medical
# Total user ratings for genre : 3672
# Percentage of genre ratings of the total store ratings : 0.0 %

# %% [markdown]
# Of the six genres we can see that `Shopping` holds the highest market share with `2.83%` of the total user ratings, and `Book` holds the least at `0.7%`. It interesting to note that although the `Book` genre has the lowest market share it does have the highest average user ratings per app at `39758.5` compared to the other 5 genres. In the output below you can see that this is being cause by a few apps that hold the majority of the total user ratings for the `Book` genre.
#
# * `Utilities` - Includes various calculators, flashlights, web browsers ect. Many of the apps that fit into this category would not be used for long lengths of time such as the alarm clock and QR reader, ideally we want to design an app that can retain a user for longer periods of times so there is higher chance of said user engaging with our ads. Designing a internet browser as well requires alot of time and monetary investment, and so would be out of the scope of our company.
# * `Book` - Of all the genres we are looking at for an app profile this one has the least amount of apps but the highest average number of ratings. This is due to the genre having a few apps with a high number of user ratings. Trying to compete with the dominating apps such as `Kindle` and `Audible` would be very difficult as these apps have large companies with great financial backing. There purpose, one to be a library of books and the other to offer the same but in an audio format, would be almost impossible to supplant as there isnt much else to innovate on.
#     * For this genre we need to get more creative if we wanted to stand out. The `Hooked` and `Color Therapy Adult Coloring Book for Adults` each take unique approaches and its apparent how they have managed to stand out amongst this genre. Like the `Hooked` app we can focus on fan-fiction or user created content, and include networking opportunites for the users incorporating aspects of apps from the `Social Media` genre. We can have it so users can upload their own source material. We can then have ads displaced on the user interface outside and inside texts.
# * `Education` - Here we see a mix of game-style education apps such as `Elevate`, apps designed for educational instituions such as `canvas` and learning apps such as `duolingo`. This genre has potential for high user retention as we can implement learning paths alongside a course structure, however this would best be aimed at a younger audience as focusing on specialist subjects or older audiences could potentially require educational specialists to come up with the material for the app and so could prove to be costly.
#     * Having a learning path with multiple lessons and modules would give us the opportunity to display ads within the app. We could include weekly challenges if we decide to include gaming elements, that could explore the topics and subject we decide to include. This could help with user retention as it provide fresh materials for user to come back to.
# * `Productivity` - This genre appears to focus on 'office' style apps such as `Gmail` and `Microsoft Word`. Now while alot of these types of apps would tend to be used more frequently and potentially multiple times a day, it appears that this market is dominated by a few companies with lots of popular apps.
#     * However when looking at what types of apps that dominate the App Store it is clear the apps designed for "fun" take this spot over "work" or "office" apps. You can see this with the `Games` genre taking up `53.39%` of all the user ratings for the app store. Designing a app that would fit the `Productivity` genre may give us a chance to stand out on the app store as a whole as it is oversaturated with "fun" apps.
#     * As the genre is dominated by office apps we can design an app that employs 'gamification' to help it stand out amongst the other apps. We could include elements like a task manager and planner that would include earning points for unlocks or achievements based on meeting set goals and completing tasks.
# * `Sports` - Consists of many apps belonging to large sport news networks and fantasy sport leagues. Developing an app for reporting sports news would require potentially hiring extra staff to take the roles of writers, reporters or entertainers. It would be a big undertaking that prove to be very costly.
#     * We could look at developing a fantasy sport leagues app, this would not require the expensive overheads that a news network could entail. We can easily embed a social networking function and allow users to set up leagues with their friends so as to encourages users to participate with others online and to get them to encourage people they know to get the app.
#     * `Social Networking` is a popular genre and accounts for `9.48%` of the user ratings of free english apps of the App Store, and so taking some ideas of what makes that genre popular and applying it to our more niche market could help us stand out.
#     * We could include quizzes and trivia games about various sport related topics. We can also include a sports reference guide that would alow users to search current and past information about players, teams, tournaments ect. depending on the sport. Including these aspects that you would most likely find in the `Games` and `Reference` genres can keep user retainment and engagement for longer as they will not have to use any external apps to search up relevant information for sports teams and for related sports trivia games.
# * `Shopping` - Apps here are often online stores which would require purchasing and delivering inventory which be outside the scope of our company. While apps like`eBay` are free to use and sign up the primary revenues comes from eBay taking a cut of the profits from sellers and auctioneers. This ultimately goes against the aims we have set out for this project.
#
# Below I have created a funtion called `list_app_ratings` showing the apps and their user ratings for the list 6 genres above. This was for analysis and to show a comparison.

# %%
def list_app_ratings(a_string):
    print('\n')
    print(go_bold(a_string))
    for app in apple_free:
        if app[-5] == a_string:
            print(app[1], ':', app[5])
    
list_app_ratings('Book')
list_app_ratings('Education')
list_app_ratings('Shopping')
list_app_ratings('Utilities')
list_app_ratings('Productivity')
list_app_ratings('Sports')
# Out:
# Book
# Kindle – Read eBooks, Magazines & Textbooks : 252076
# Audible – audio books, original series & podcasts : 105274
# Color Therapy Adult Coloring Book for Adults : 84062
# OverDrive – Library eBooks and Audiobooks : 65450
# HOOKED - Chat Stories : 47829
# BookShout: Read eBooks & Track Your Reading Goals : 879
# Dr. Seuss Treasury — 50 best kids books : 451
# Green Riding Hood : 392
# Weirdwood Manor : 197
# MangaZERO - comic reader : 9
# ikouhoushi : 0
# MangaTiara - love comic reader : 0
# 謎解き : 0
# 謎解き2016 : 0
#
#
# Education
# Duolingo - Learn Spanish, French and more : 162701
# Guess My Age  Math Magic : 123190
# Lumosity - Brain Training : 96534
# Elevate - Brain Training and Games : 58092
# Fit Brains Trainer : 46363
# ClassDojo : 35440
# Memrise: learn languages : 20383
# Peak - Brain Training : 20322
# Canvas by Instructure : 19981
# ABCmouse.com - Early Learning Academy : 18749
# Quizlet: Study Flashcards, Languages & Vocabulary : 16683
# Photomath - Camera Calculator : 16523
# iTunes U : 15801
# Blackboard Mobile Learn™ : 13567
# Star Chart : 13482
# Remind: Fast, Efficient School Messaging : 9796
# PBS KIDS Video : 8651
# Toca Kitchen Monsters : 8062
# Toca Hair Salon - Christmas Gift : 8049
# Edmodo : 7197
# Prodigy Math Game : 6683
# Epic! - Unlimited Books for Kids : 6676
# ChineseSkill -Learn Mandarin Chinese Language Free : 6077
# Google Classroom : 5942
# TED : 5782
# Khan Academy: you can learn anything : 5459
# Got It - Homework Help Math, Chem, Physics Solver : 4903
# PowerSchool Mobile : 4547
# SkyView® Free - Explore the Universe : 4188
# Hopscotch : 4057
# IXL - Math and English : 3546
# Simply Piano by JoyTunes - Learn & play piano : 2925
# Kids A-Z : 2887
# Infinite Campus Mobile Portal : 2286
# PlayKids - Educational Cartoons and Games for Kids : 2196
# Memorado Brain Training for Memory & Mindfulness : 2067
# Bookshelf : 2064
# Mathway - Math Problem Solver : 1854
# Schoology : 1777
# HelloTalk Language Exchange Learning App : 1619
# SpellingCity : 1566
# Nick Jr. : 1541
# Babbel – Learn Languages Spanish, French & more : 1533
# Yup - Homework Help with Math & Science Tutors : 1424
# Mondly: Learn 33 Languages: Spanish English French : 1395
# WWF Together : 1385
# Tinycards - Learn with Fun, Free Flashcards : 1131
# Nearpod : 1057
# Starfall FREE : 1019
# Reflex Student : 1010
# GoldieBlox and the Movie Machine : 1000
# Pearson eText : 981
# codeSpark Academy with The Foos - coding for kids : 977
# Dr. Panda Restaurant Asia : 853
# NOGGIN - Preschool Shows & Educational Kids Videos : 782
# Tynker - Learn to Code. Programming Made Easy. : 771
# BrainHQ - Brain Training : 684
# Top Hat Lecture : 668
# Pearson eText for Schools : 609
# Curious World: Games, Videos, Books for Children : 604
# McGraw-Hill K-12 ConnectED Mobile : 594
# Socrative Student : 581
# Swift Playgrounds : 578
# MarcoPolo Ocean : 529
# TestNav : 491
# Starfall Learn to Read : 474
# Speakaboos Reading App: Stories & Songs for Kids : 440
# Bloxels: Build, Play & Share Your Own Video Games : 382
# GoNoodle Kids : 372
# Global Shark Tracker : 336
# The Robot Factory by Tinybop : 335
# Daniel Tiger’s Day & Night : 314
# Kahoot! Play Fun Learning Games : 300
# Spanish SOLO: Learn Spanish With Lessons On The Go : 275
# Math 42 : 248
# Star Walk 2 Ads+ Night Sky Map - Stars and Planets : 161
# Toca Dance Free : 149
# Endless Learning Academy : 143
# 270toWin : 141
# Win the White House : 123
# Sago Mini Babies Dress Up : 115
# Nancy Drew Codes and Clues Mystery Coding Game : 110
# 1600 : 110
# BEAKER by THIX : 94
# Highlights™ Shapes - Preschool Learning Puzzles : 90
# Little Panda's Candy Shop - Lollipop Factory : 84
# Mathpix - Solve and graph math using pictures : 83
# Blue Apprentice Elementary Science Game by Galxyz : 79
# PINKFONG Birthday Party : 70
# Hopster: Kids TV, Nursery Rhymes, Music, Fun Games : 58
# Sago Mini Holiday Trucks and Diggers : 56
# Dr. Panda Toy Cars Free : 51
# Virry Educational. Play, learn with real animals : 50
# Highlights Monster Day : 49
# PlayKids Learn - Learning through play : 49
# PBS KIDS ScratchJr : 38
# Lemon Lumberjack's Letter Mill : 34
# Ready Jet Go! Space Explorer : 34
# Chinese Recipes - Asian cuisine : 32
# Nature Cat's Great Outdoors : 31
# Show My Homework : 17
# PINKFONG 123 Numbers : 17
# Aquarium VR : 12
# Little Panda Mini Games-3D : 9
# Stylish School Timetable : 7
# Merry Christmas -Activities : 7
# Mastering the piano with Lang Lang : 6
# Baby Panda's Carnival : 6
# Driving test 2017 : 5
# Cutie Patootie - Xmas Surprise : 5
# Free IQ Test: Calculate your IQ : 5
# Beautiful Japanese Handwriting for iPhone : 0
# GhostCallDX : 0
# Baby Learns Transportation : 0
# Baby Panda's Bath Time : 0
# Beautiful Japanese Handwriting : 0
# Spring Festival by BabyBus : 0
# Dinosaur Planet : 0
#
#
# Shopping
# Groupon - Deals, Coupons & Discount Shopping App : 417779
# eBay: Best App to Buy, Sell, Save! Online Shopping : 262241
# Wish - Shopping Made Fun : 141960
# shopkick - Shopping Rewards & Discounts : 130823
# Amazon App: shop, scan, compare, and read reviews : 126312
# Target : 108131
# Zappos: shop shoes & clothes, fast free shipping : 103655
# Walgreens – Pharmacy, Photo, Coupons and Shopping : 88885
# Best Buy : 80424
# Walmart: Free 2-Day Shipping,* Easy Store Shopping : 70286
# OfferUp - Buy. Sell. Simple. : 57348
# Apple Store : 55171
# Shop Savvy Barcode Scanner - Price Compare & Deals : 54630
# Ibotta: Cash Back App, Grocery Coupons & Shopping : 44313
# letgo: Buy & Sell Second Hand Stuff : 38424
# CVS Pharmacy : 35981
# Victoria’s Secret – The Sexiest Bras & Lingerie : 34507
# Etsy: Shop Handmade, Vintage & Creative Goods : 30434
# Gilt : 26353
# Mercari: Shopping Marketplace to Buy & Sell Stuff : 24244
# Shopular Coupons, Weekly Deals for Target, Walmart : 22729
# RetailMeNot Shopping Deals, Coupons, Savings : 18544
# Poshmark: Buy & Sell Fashion : 18035
# Whole Foods Market : 17906
# 5miles: Buy and Sell Used Stuff Locally : 16105
# Sephora Makeup & Beauty App – Insider Tips & Style : 15593
# Cartwheel by Target : 14682
# SHEIN Shopping - Women's Clothing & Fashion : 12663
# Ebates: Cash Back, Coupons & Rebate Shopping App : 12617
# Wayfair - Shop Furniture, Home Decor, Daily Sales : 12578
# CVS : 12402
# SNKRS : 12298
# Macy's : 11013
# AliExpress Shopping App : 10647
# ASOS : 9725
# Jet: Online Shopping Deals & Bulk Wholesale Prices : 9006
# Romwe shopping- Fashion Clothing for women : 8558
# Black Friday 2017 Ads App - BlackFriday.fm : 8221
# Sam's Club: Wholesale Shopping & Bulk Buy Deals : 8149
# Kohl's App: Scan, Shop, Pay and Save! : 7174
# Flipp - Weekly Ads, Shopping List, and Coupons : 6677
# AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes : 6408
# Nike+ : 5464
# Sam’s Club Scan & Go : 5448
# Close5 - Buy & Sell Stuff Locally : 5010
# Checkout 51: Grocery Coupons & Cash Back Savings : 4878
# Retale - Coupons, Weekly Ads & Stores Nearby : 4861
# Kmart – Download Now, Shop Online & Pick Up Today! : 4186
# Honest App: Shop baby & diaper products : 3173
# GOAT: Buy & Sell Sneakers : 3116
# ZARA : 2731
# Depop - Buy, Sell and Share : 2478
# Foot Locker : 2477
# Fuel Rewards® program : 2249
# KIXIFY - Buy & Sell Sneakers : 1735
# JCPenney : 1661
# 淘宝HD－Taobao for iPad : 1103
# Inkly: Greeting Cards, Postcards, Flowers & Gifts : 1034
# Amazon Prime Now : 895
# Red－shop the world : 768
# UA Shop by Under Armour : 741
# H&M : 687
# boohoo.com : 655
# Footaction : 364
# My College Bookstore : 225
# Shpock Boot Sale & Classifieds App. Buy & Sell : 212
# 天猫HD : 198
# Kirkland's Spin to Win : 177
# Vestiaire Collective - Pre-Owned Luxury Fashion : 169
# Lush Cosmetics : 164
# 京东 HD : 150
# Missguided : 113
# The Clymb — Gear Deals : 104
# OVO Store : 95
# eBay Kleinanzeigen - Free. Easy. Local. : 74
# Gumtree Classifieds: Buy & Sell - Local for Sale : 72
# WEAR - Fashion Lookbook : 66
# UNiDAYS: Student Discounts for Shopping Top Brands : 53
# JD Sports : 18
# Showroomprive - Private Fashion Sales : 11
# minne - shopping handmade item : 8
# DaWanda - The marketplace for unique products : 0
# vente-privee : 0
# gogogo : 0
#
#
# Utilities
# Google – Search made just for mobile : 479440
# Flashlight Ⓞ : 130450
# My Verizon : 126948
# myAT&T : 108507
# The Calculator - Free and Easy Calculating! : 99244
# Speedtest by Ookla : 65016
# Google Chrome – The Fast and Secure Web Browser : 55750
# Alarm Clock HD Free - Digital Alarm Clock Display : 54496
# Calculator Pro for iPad Free - Smart Calculator : 47803
# Bitmoji - Your Personal Emoji : 37972
# Calculator‰ : 36879
# Flashlight ！ : 35769
# Truecaller - Spam Identification & Block : 27791
# Browser and File Manager for Documents : 27750
# Flashlight for iPhone , iPod and iPad : 26697
# RainbowKey - Color keyboard themes, fonts & GIF : 23063
# Calculator HD Free : 14986
# QR Reader for iPhone : 12683
# Puffin Web Browser : 11677
# Evolution Calculator - CP & XP - for Pokemon GO! : 9269
# Gboard — a new keyboard from Google : 8873
# Free QR Code Reader & Barcode Scanner for iPhone : 7343
# GIF Keyboard : 5979
# Alarm Clock for Me - Best Wake Up Music & Clock : 4959
# Quick Scan - QR Code Reader : 4783
# Voice Recorder (FREE) : 4640
# Emoji Keyboard for Me - Free Emoji Keyboard Themes : 4162
# Calculator for iPad Free. : 4021
# Scanbot - Scanner App & Fax : 3936
# Word Flow Keyboard - GIF, swipe, custom theme : 3213
# AT&T Mobile Transfer - Free : 3024
# Lookout: Security and Identity Theft Protection : 2661
# Firefox web browser : 2619
# My Sprint Mobile : 2238
# Google Authenticator : 1652
# VPN SecureLine - privacy & security by Avast : 1534
# Instant Repost for Instagram-Stories Repost Upload : 1528
# . Calculator . : 1525
# QR Code Reader by Scan : 1452
# QR Reader for iPad : 1341
# Sleep Talk Recorder : 1110
# The Rock Clock™ : 951
# Peel Smart Remote: TV guide & Universal Remote : 756
# Themeboard : 704
# Onion Browser - Secure & Anonymous Web with Tor : 691
# ThemeOut : 612
# PokéFind - IV & CP Calculator and Map for Poké GO : 591
# TestFlight : 538
# Firefox Focus: The privacy browser : 477
# Apple Support : 388
# Wonder Keyboard: Sound Smart & Funny with AI : 375
# Giffage – The GIF Keyboard for GIFs : 315
# Social Picket - Stalker & Spy for Instagram : 285
# QQ邮箱 : 281
# Poke Map Realtime Locator & Radar for Pokémon Go : 243
# Moji Edit- Your Custom Emoji Avatar Face : 238
# DurantEmoji by Kevin Durant : 200
# Bitauto Autoprice : 157
# GIPHY KEYS. The GIF Keyboard : 138
# ZaZa Remote-Universal Remote Control : 83
# My Boost : 83
# UC浏览器HD : 78
# Copy My Data : 72
# QQ邮箱HD : 55
# Virginia Tech Emoji : 50
# Jordan Keyboard : 49
# Simeji - Japanese Keyboard with Emoticons : 49
# MY EE : 43
# Helper for Pokemon Go : 42
# PIN Genie Vault – Secret photo album & Password : 34
# GoldenMoji - Golden Retriever Emojis : 27
# Laurie Hernandez the Human Emoji : 26
# SFR Mon Compte : 19
# My Vodafone : 8
# Hugsafe Petracker : 0
# TownWiFi - WiFi Everywhere : 0
# Caf - Mon Compte : 0
# U Compass ( North, South, East and West ) : 0
# Wi-Fiミレル : 0
# TransParent Compass : 0
# My au : 0
#
#
# Productivity
# Evernote - stay organized : 161065
# Gmail - email by Google: secure, fast & organized : 135962
# iTranslate - Language Translator & Dictionary : 123215
# Yahoo Mail - Keeps You Organized! : 113709
# Google Docs : 64259
# Google Drive - free online storage : 59255
# Dropbox : 49578
# Microsoft Word : 47999
# Microsoft OneNote : 39638
# Microsoft Outlook - email and calendar : 32807
# Hotspot Shield Free VPN Proxy & Wi-Fi Privacy : 32499
# Documents 6 - File manager, PDF reader and browser : 29110
# Google Sheets : 24602
# Microsoft Excel : 24430
# Inbox by Gmail : 21561
# T-Mobile : 19977
# Paper by FiftyThree - Sketch, Diagram, Take Notes : 18219
# MyScript Calculator - Handwriting calculator : 16555
# VPN Proxy Master - Unlimited WiFi security VPN : 13674
# Microsoft OneDrive – File & photo cloud storage : 12797
# Ever - Capture Your Memories : 12755
# Speak & Translate － Voice and Text Translator : 12062
# Tayasui Sketches : 11505
# Drawing Desk - Draw, Paint, Doodle & Sketch board : 11040
# Microsoft PowerPoint : 10939
# Email - Fast & Secure mail for Gmail iCloud Yahoo : 10778
# Google Slides : 9920
# HP All-in-One Printer Remote : 9819
# Google Calendar – Make the most of every day : 7656
# Verizon Cloud : 6482
# Free VPN HexaTech - Unlimited VPN Proxy for iPhone : 5934
# Productive habits & daily goals tracker : 4736
# Adobe Spark Video, Animated Videos in minutes : 4302
# Adobe Illustrator Draw : 3215
# Concepts - Sketch, Design, Illustrate : 3101
# Trello : 2793
# Adobe Spark Page — Create Stunning Web Pages : 2528
# Workflow: Powerful Automation Made Simple : 1498
# ATracker - Daily Task and Time Tracking : 1114
# Bear : 891
# Family Organizer - Calendar Planner : 828
# Fingerprint Login: PassKey Password & Apps Lock : 718
# 360云盘 : 437
# Mail Master by NetEase : 361
# Content Transf : 299
# HOUND Voice Search & Assistant : 297
# AutoScout24 - mobile used & new car market : 220
# WEB.DE Mail : 168
# GMX Mail : 102
# MetaMoJi Note Lite : 93
# Infinite Painter : 65
# Jottit : 14
# Free QR Code Reader simply to scan a QR Code : 10
# Official QR Code reader "Q" - QR app. - : 0
# Digiposte + : 0
# BarcodeReader「ICONIT」 : 0
#
#
# Sports
# ESPN: Get scores, news, alerts & watch live sports : 290996
# Yahoo Fantasy Sports : 190670
# WatchESPN : 159735
# The Masters Tournament : 148160
# Yahoo Sports - Teams, Scores, News & Highlights : 137951
# ESPN Fantasy Football Baseball Basketball Hockey : 64925
# CBS Sports App - Sports Scores, News, Stats, Watch : 59639
# FOX Sports Mobile : 57500
# 2016 U.S. Open Golf Championship : 54192
# NBC Sports : 47172
# NBA : 43682
# ESPN Tournament Challenge : 39642
# 2016 US Open Tennis Championships : 37522
# NFL : 27317
# MLB.com At Bat : 21830
# The Championships, Wimbledon 2016 - Tennis Grand Slam : 20953
# DraftKings - Daily Fantasy Golf, Baseball, & More : 20251
# Bleacher Report: Sports news, scores, & highlights : 16979
# Univision Deportes: Liga MX, MLS, Fútbol En Vivo : 16683
# NASCAR MOBILE : 16385
# NHL : 15554
# FOX Sports GO : 13898
# NCAA March Madness Live - Men's College Basketball : 13572
# PGA Championship 2016 – Baltusrol Golf Club : 10472
# 365Scores : 9879
# NFL Fantasy Football - Official NFL Fantasy App : 8234
# FanDuel - Daily Fantasy Baseball, Golf & Sports : 8014
# GolfNow – Book Tee Times, Golf GPS, Scorecard : 7535
# Ryder Cup 2016 – Hazeltine National Golf Club : 3818
# Onefootball - Soccer Scores & Live News : 3194
# NFL HUDDLE: Football Card Trader : 2896
# KICK: Official Football Card Trader : 2641
# Hudl : 2622
# SportsManias: Sports Emojis, Fantasy & Team News : 2431
# BTN2Go : 1628
# Pac-12 Now : 1221
# Watch NFL Network : 1110
# Golf Live Extra : 840
# UFC ® : 809
# Premier League - Official App : 791
# NCAA Sports : 636
# The Olympics - Official App for the Olympic Games : 470
# NBC Sports Scores : 428
# DK Live – Fantasy Sports Play by Play and News : 416
# Résultats Foot en Direct : 339
# NFL Rush Gameday : 272
# NFL Gridiron from Panini - Card Collecting-Trading : 257
# Hiking Project : 247
# 2016 U.S. Open Golf Championship for iPad : 146
# The Open : 142
# European Qualifiers Official App : 135
# TwinSpires Official Kentucky Derby Wagering App : 131
# SofaScore Live Sports: Scores, VIDEO & Stats : 103
# Team USA App : 101
# NBAmoji : 89
# FOX Sports VR : 81
# BAA Marathon : 70
# TCS NYC Marathon : 43
# Vendée Globe 2016 : 42
# Dream Team - be your own fantasy football manager : 35
# NFL Draft - Fan Mobile Pass : 32
# WKC Dog Show 2017 : 30
# CCTV5 : 14
# My8to18 : 10
# Race Calendar 2016 : 1
# Team GB Live : 1
# francetv JO – Regarder les Jeux Olympiques de Rio 2016 : 0
# FFmoji 2016 - Your Fantasy Football Emoji Keyboard : 0
# HowDidiDo : 0

# %% [markdown]
# # Most Popular Apps by Genre on Google Play
#
# For the Google Play market we actually have data on the number of installs for an app so we should be able to get a clearer picture of a genres and apps popularity. When looking at this data however it appears that the numbers do not seem precise enough and the values given appear to be open-ended (100+, 1,000+, 5,000+, etc.)

# %%
display_table(gps_free, 5) # the Installs columns
# Out:
# 1,000,000+ : 15.728308699086089
# 100,000+ : 11.55365000564143
# 10,000,000+ : 10.549475346947986
# 10,000+ : 10.199706645605326
# 1,000+ : 8.394448832223853
# 100+ : 6.916393997517771
# 5,000,000+ : 6.826131106848697
# 500,000+ : 5.562450637481666
# 50,000+ : 4.772650344127271
# 5,000+ : 4.513144533453684
# 10+ : 3.542818458761142
# 500+ : 3.2494640640866526
# 50,000,000+ : 2.3017037120613786
# 100,000,000+ : 2.1324607920568655
# 50+ : 1.9180864267178157
# 5+ : 0.7898002933543946
# 1+ : 0.5077287600135394
# 500,000,000+ : 0.270788672007221
# 1,000,000,000+ : 0.2256572266726842
# 0+ : 0.045131445334536835

# %% [markdown]
# The problem with this data is that if an app is defined as having 1,000+ installs we would not know whether this app has 1,000 installs, 1,250, or 1,500. This goes the same across all the other install categorisations. Now we don't need very precise data for our purposes, we only want to find out which app genres attract the most users.
#
# We will leave the numbers as they are so that an app with 100,000+ installs will have 100,000 installs and an app with 10,000+ installs with have 10,000 installs and so on.
#
# To perform computations and further analysis we will need to convert each install number from a string to a float. Here we will need to remove the commas and the plus characters, or the conversion will fail and cause an error. To help make the output more readable we have defined a function call `sort_table_desc` which will sort a frequency table into descending order.

# %%
def sort_table_desc(freq_table): # defining a function to sort the output into descending order
    freq_table_sorted = sorted(freq_table, reverse = True)
    for entry in freq_table_sorted:
        print(entry[1], ':', '{:,}'.format(entry[0]))
    print('\n')

gps_categories = freq_table(gps_free, 1) # using an earlier defined function for generating a frequency table

gps_categories_table = [] # creating an empty list to use for ordering the output
for category in gps_categories:
    total = 0
    len_category = 0
    for app in gps_free:
        category_app = app[1]
        if category_app == category:
            num_installs = app[5]
            num_installs = num_installs.replace('+', '')
            num_installs = num_installs.replace(',', '')
            num_installs = float(num_installs)
            total += num_installs
            len_category += 1
    avg_num_installs = total / len_category
    key_cat_as_tuple = (avg_num_installs, category)
    gps_categories_table.append(key_cat_as_tuple)

sort_table_desc(gps_categories_table)

for app in gps_free:
    num_installs = app[5]
    num_installs = num_installs.replace('+', '')
    num_installs = num_installs.replace(',', '')
    num_installs = int(num_installs)
    app[5] = str(num_installs)
# Out:
# COMMUNICATION : 38,456,119.167247385
# VIDEO_PLAYERS : 24,727,872.452830188
# SOCIAL : 23,253,652.127118643
# PHOTOGRAPHY : 17,840,110.40229885
# PRODUCTIVITY : 16,787,331.344927534
# GAME : 15,588,015.603248259
# TRAVEL_AND_LOCAL : 13,984,077.710144928
# ENTERTAINMENT : 11,640,705.88235294
# TOOLS : 10,801,391.298666667
# NEWS_AND_MAGAZINES : 9,549,178.467741935
# BOOKS_AND_REFERENCE : 8,767,811.894736841
# SHOPPING : 7,036,877.311557789
# PERSONALIZATION : 5,201,482.6122448975
# WEATHER : 5,074,486.197183099
# HEALTH_AND_FITNESS : 4,188,821.9853479853
# MAPS_AND_NAVIGATION : 4,056,941.7741935486
# FAMILY : 3,697,848.1731343283
# SPORTS : 3,638,640.1428571427
# ART_AND_DESIGN : 1,986,335.0877192982
# FOOD_AND_DRINK : 1,924,897.7363636363
# EDUCATION : 1,833,495.145631068
# BUSINESS : 1,712,290.1474201474
# LIFESTYLE : 1,437,816.2687861272
# FINANCE : 1,387,692.475609756
# HOUSE_AND_HOME : 1,331,540.5616438356
# DATING : 854,028.8303030303
# COMICS : 817,657.2727272727
# AUTO_AND_VEHICLES : 647,317.8170731707
# LIBRARIES_AND_DEMO : 638,503.734939759
# PARENTING : 542,603.6206896552
# BEAUTY : 513,151.88679245283
# EVENTS : 253,542.22222222222
# MEDICAL : 120,550.61980830671

# %% [markdown]
# From the data above we can see that the top 3 genres for average number of installs per app are `Communication` at `38,456,119`, `Video_players` at `24,727,872`, and `Social` at `23,253,652`. Below we will explore the genre `Communication` further.

# %%
app_installs_table = []
for app in gps_free:
    if app[1] == 'COMMUNICATION':
        key_cat_as_tuple = (int(app[5]), app[0])
        app_installs_table.append(key_cat_as_tuple)

sort_table_desc(app_installs_table)
# Out:
# WhatsApp Messenger : 1,000,000,000
# Skype - free IM & video calls : 1,000,000,000
# Messenger – Text and Video Chat for Free : 1,000,000,000
# Hangouts : 1,000,000,000
# Google Chrome: Fast & Secure : 1,000,000,000
# Gmail : 1,000,000,000
# imo free video calls and chat : 500,000,000
# Viber Messenger : 500,000,000
# UC Browser - Fast Download Private & Secure : 500,000,000
# LINE: Free Calls & Messages : 500,000,000
# Google Duo - High Quality Video Calls : 500,000,000
# imo beta free calls and text : 100,000,000
# Yahoo Mail – Stay Organized : 100,000,000
# Who : 100,000,000
# WeChat : 100,000,000
# UC Browser Mini -Tiny Fast Private & Secure : 100,000,000
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000
# Telegram : 100,000,000
# Opera Mini - fast web browser : 100,000,000
# Opera Browser: Fast and Secure : 100,000,000
# Messenger Lite: Free Calls & Messages : 100,000,000
# Kik : 100,000,000
# KakaoTalk: Free Calls & Text : 100,000,000
# GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000
# Firefox Browser fast & private : 100,000,000
# BBM - Free Calls & Messages : 100,000,000
# Android Messages : 100,000,000
# free video calls and chat : 50,000,000
# Zalo – Video Call : 50,000,000
# Mail.Ru - Email App : 50,000,000
# Dolphin Browser - Fast, Private & Adblock🐬 : 50,000,000
# Contacts : 50,000,000
# CM Browser - Ad Blocker , Fast Download , Privacy : 50,000,000
# Azar : 50,000,000
# myMail – Email for Hotmail, Gmail and Outlook Mail : 10,000,000
# chomp SMS : 10,000,000
# ZenUI Dialer & Contacts : 10,000,000
# Xperia Link™ : 10,000,000
# Whoscall - Caller ID & Block : 10,000,000
# WhatsCall Free Global Phone Call App & Cheap Calls : 10,000,000
# WhatsApp Business : 10,000,000
# WEB.DE Mail : 10,000,000
# Voxer Walkie Talkie Messenger : 10,000,000
# TouchPal Keyboard - Fun Emoji & Android Keyboard : 10,000,000
# Text SMS : 10,000,000
# Talkray - Free Calls & Texts : 10,000,000
# Talkatone: Free Texts, Calls & Phone Number : 10,000,000
# Puffin Web Browser : 10,000,000
# Psiphon Pro - The Internet Freedom VPN : 10,000,000
# Portable Wi-Fi hotspot : 10,000,000
# Orfox: Tor Browser for Android : 10,000,000
# Opera Mini browser beta : 10,000,000
# Omlet Chat : 10,000,000
# Mr. Number-Block calls & spam : 10,000,000
# Messenger for SMS : 10,000,000
# MegaFon Dashboard : 10,000,000
# ICQ — Video Calls & Chat Messenger : 10,000,000
# Hiya - Caller ID & Block : 10,000,000
# Hangouts Dialer - Call Phones : 10,000,000
# GroupMe : 10,000,000
# Google Voice : 10,000,000
# Google Allo : 10,000,000
# Glide - Video Chat Messenger : 10,000,000
# GO Notifier : 10,000,000
# GMX Mail : 10,000,000
# Free WiFi Connect : 10,000,000
# Free Adblocker Browser - Adblock & Popup Blocker : 10,000,000
# ExDialer - Dialer & Contacts : 10,000,000
# Discord - Chat for Gamers : 10,000,000
# DU Browser—Browse fast & fun : 10,000,000
# Cricket Visual Voicemail : 10,000,000
# Contacts+ : 10,000,000
# Calls Blacklist - Call Blocker : 10,000,000
# CallApp: Caller ID, Blocker & Phone Call Recorder : 10,000,000
# Browser 4G : 10,000,000
# Adblock Browser for Android : 10,000,000
# AT&T Visual Voicemail : 10,000,000
# Your Freedom VPN Client : 5,000,000
# Web Browser & Explorer : 5,000,000
# Sync.ME – Caller ID & Block : 5,000,000
# Skype Lite - Free Video Call & Chat : 5,000,000
# My Vodacom SA : 5,000,000
# My Tele2 : 5,000,000
# Microsoft Edge : 5,000,000
# K-9 Mail : 5,000,000
# JusTalk - Free Video Calls and Fun Video Chat : 5,000,000
# Full Screen Caller ID : 5,000,000
# Ear Agent: Super Hearing : 5,000,000
# Daum Mail - Next Mail : 5,000,000
# Chrome Dev : 5,000,000
# Calls & Text by Mo+ : 5,000,000
# Caller ID & Call Block - DU Caller : 5,000,000
# Call Free – Free Call : 5,000,000
# Call Control - Call Blocker : 5,000,000
# CM Transfer - Share any files with friends nearby : 5,000,000
# CIA - Caller ID & Call Blocker : 5,000,000
# Brave Browser: Fast AdBlocker : 5,000,000
# Bluetooth Auto Connect : 5,000,000
# AT&T Call Protect : 5,000,000
# mysms SMS Text Messaging Sync : 1,000,000
# mail.com mail : 1,000,000
# Wi-Fi Auto-connect : 1,000,000
# Web Browser for Android : 1,000,000
# WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 1,000,000
# Vonage Mobile® Call Video Text : 1,000,000
# Virtual Walkie Talkie : 1,000,000
# Video Caller Id : 1,000,000
# True Contact - Real Caller ID : 1,000,000
# TracFone My Account : 1,000,000
# Tiny Call Confirm : 1,000,000
# Should I Answer? : 1,000,000
# Seznam.cz : 1,000,000
# Safest Call Blocker : 1,000,000
# SW-100.tch by Callstel : 1,000,000
# RocketDial Dialer & Contacts : 1,000,000
# PHONE for Google Voice & GTalk : 1,000,000
# Ninesky Browser : 1,000,000
# Newton Mail - Email App for Gmail, Outlook, IMAP : 1,000,000
# My magenta : 1,000,000
# My Vodafone (GR) : 1,000,000
# Messaging+ SMS, MMS Free : 1,000,000
# Lite for Facebook Messenger : 1,000,000
# InBrowser - Incognito Browsing : 1,000,000
# Ghostery Privacy Browser : 1,000,000
# Firefox Focus: The privacy browser : 1,000,000
# Email TypeApp - Mail App : 1,000,000
# DW Contacts & Phone & Dialer : 1,000,000
# ClanPlay: Community and Tools for Gamers : 1,000,000
# Caller ID + : 1,000,000
# Call Blocker - Blacklist, SMS Blocker : 1,000,000
# CB Radio Chat - for friends! : 1,000,000
# Burner - Free Phone Number : 1,000,000
# BBMoji - Your personalized BBM Stickers : 1,000,000
# AntennaPict β : 1,000,000
# All Email Providers : 1,000,000
# Adblock Plus for Samsung Internet - Browse safe. : 1,000,000
# AW - free video calls and chat : 1,000,000
# AT&T Messages for Tablet : 1,000,000
# 2ndLine - Second Phone Number : 1,000,000
# Web Browser : 500,000
# U - Webinars, Meetings & Messenger : 500,000
# TownWiFi | Wi-Fi Everywhere : 500,000
# Talkie - Wi-Fi Calling, Chats, File Sharing : 500,000
# SolMail - All-in-One email app : 500,000
# LokLok: Draw on a Lock Screen : 500,000
# Lightning Web Browser : 500,000
# FreedomPop Messaging Phone/SIM : 500,000
# BD Data Plan (3G & 4G) : 500,000
# WiFi Access Point (hotspot) : 100,000
# T-Mobile DIGITS : 100,000
# QRZ Assistant : 100,000
# Portable Wi-Fi hotspot Free : 100,000
# PlacarTv Futebol Ao Vivo : 100,000
# Morse Code Reader : 100,000
# M star Dialer : 100,000
# K-@ Mail - Email App : 100,000
# Goodbox - Mega App : 100,000
# Everbridge : 100,000
# Channel 19 : 100,000
# CB On Mobile : 100,000
# Baby Monitor AV : 100,000
# BT MeetMe with Dolby Voice : 100,000
# Antillean Gold Telegram (original version) : 100,000
# AZ Browser. Private & Download : 100,000
# X Browser : 50,000
# N-Com Wizard : 50,000
# My BF App : 50,000
# IZ2UUF Morse Koch CW : 50,000
# HipChat - beta version : 50,000
# Free Wi-fi HotspoT : 50,000
# BT Messenger : 50,000
# BD Internet Packages (Updated) : 50,000
# AudioBT: BT audio GPS/SMS/Text : 50,000
# 3G DZ Configuration : 50,000
# m:go BiH : 10,000
# [verify-U] VideoIdent : 10,000
# Ring : 10,000
# Pocket Prefix Plus : 10,000
# Mail1Click - Secure Mail : 10,000
# Jazz Wi-Fi : 10,000
# Inbox.eu : 10,000
# Ham Radio Prefixes : 10,000
# Feel Performer : 10,000
# Eg Call : 10,000
# EZ Wifi Notification : 10,000
# Deaf World DW : 10,000
# DMR BrandMeister Tool : 10,000
# ClanHQ : 10,000
# BT One Phone Mobile App : 10,000
# BF Browser by Betfilter - Stop Gambling Today! : 10,000
# BD Dialer : 10,000
# Ad Blocker Turbo - Adblocker Browser : 10,000
# Access Point Names : 10,000
# /u/app : 10,000
# retteMi.ch : 5,000
# mail.co.uk Mail : 5,000
# love sms good morning : 5,000
# Sat-Fi : 5,000
# Mircules DX Cluster Lite : 5,000
# Learn Morse Code - G0HYN Learn Morse : 5,000
# K-9 Material (unofficial) : 5,000
# Ham DX Cluster & Spots Finder : 5,000
# DM for WhatsApp : 5,000
# DM Talk New : 5,000
# Council Voting Calculator : 5,000
# CS Browser Beta : 5,000
# BT One Voice mobile access : 5,000
# BD Live Call : 5,000
# AK Phone : 5,000
# AG Contacts, Lite edition : 5,000
# cluster.dk : 1,000
# Sat-Fi Voice : 1,000
# SMS Sender - sluzba.cz : 1,000
# ReadyOp DT : 1,000
# FO AIRBUS TLSE : 1,000
# FC Browser - Focus Privacy Browser : 1,000
# EU Council : 1,000
# DM Tracker : 1,000
# Call Blocker & Blacklist : 1,000
# CS Customizer : 1,000
# CS Browser | #1 & BEST BROWSER : 1,000
# CQ-Mobile : 1,000
# BlueDV AMBE : 1,000
# BQ Partners : 1,000
# BN MALLORCA Radio : 1,000
# BK Chat : 1,000
# BH Mail : 1,000
# AV Phone : 1,000
# AU Call Blocker - Block Unwanted Calls Texts 2018 : 1,000
# Traffic signs BD : 500
# Rádio Sol Nascente DF : 500
# Have your say on Europe : 500
# ES-1 : 500
# CW BLE Peripheral Simulator : 500
# CQ-Alert : 500
# Best Auto Call Recorder Free : 500
# ATC Unico BS : 500
# tournaments and more.aj.2 : 100
# chat dz : 100
# [EF]ShoutBox : 100
# Programi podrške EU : 100
# MARKET FO : 100
# Katalogen.ax : 100
# FP Connect : 100
# FO STELIA Méaulte : 100
# FO SODEXO : 100
# FO RCBT : 100
# FO PSA Sept-Fons : 100
# FO OP St-Nazaire : 100
# FO Interim : 100
# FO AIRBUS Nantes : 100
# EP RSS Reader : 100
# EHiN-FH conferenceapp : 100
# DG Card : 100
# Cy Messenger : 100
# Carpooling FH Hagenberg : 100
# CW Bluetooth SPP : 100
# CJ DVD Rentals : 100
# CJ Browser - Fast & Private : 100
# CF Chat: Connecting Friends : 100
# C W Browser : 100
# Bee'ah Employee App : 100
# BV : 100
# Amadeus GR & CY : 100
# Aj.Petra : 100
# Hyundai CX Conference : 50
# DK TEL Dialer : 50
# Cb browser : 50
# BS-Mobile : 50
# AC-BL : 50
# ei : 10
# Oklahoma Ag Co-op Council : 10
# Hlášenírozhlasu.cz : 10
# FP Live : 10
# FNH Payment Info : 10
# FN Web Radio : 10
# Ek IRA : 10
# EO Mumbai : 10
# EJ messenger : 10
# DM - The Offical Messaging App : 10
# DK Browser : 10
# CK Call NEW : 10
# Best Browser BD social networking : 10
# BJ - Confidential : 10
# Test Server SMS FA : 5
# Of the wall Arapaho bk : 5
# BA SALES : 1

# %% [markdown]
# The data from the App Store showed us that there was a skewing of a genres popularity being caused by a few apps with a high number of user ratings. There seems to be similar trend here with the data from the Google Play Store.
#
# We can see that there are a few apps with over a billion installs (`WhatsApp`, `Skype`, `Messenger`, `Hangouts`, `Google Chrome`, and `Gmail`) and even more with over 500 and 100 million installs.
#
# From analysing this genre below we can see that there are 27 apps that have over 100 million installs. When these apps are removed we can see that the average number of installs per app drops to `3,603,485` which is a ten-fold decrease.

# %%
under_100m_apps = []
over_100m_apps = [] 
total = 0
total_under_100m = 0
for app in gps_free:
    num_installs = int(app[5])
    if app[1] == 'COMMUNICATION' and num_installs < 100000000:
        under_100m_apps.append(num_installs)
        total += 1
        total_under_100m += 1
    elif app[1] == 'COMMUNICATION' and num_installs >= 100000000:
        over_100m_apps.append(num_installs)
        total += 1
print(go_bold_red('COMMUNICATION'))        
print(go_bold('Number of apps'), ':', total)
print(go_bold('Number of apps under 100 million'), ':', total_under_100m)
print(go_bold('Average installs for apps under 100 million'), ':', 
              ('{:,}'.format(round(sum(under_100m_apps) / len(under_100m_apps)))))
print(go_bold('Average installs for apps at and over 100 million'), ':', 
              ('{:,}'.format(round(sum(over_100m_apps) / len(over_100m_apps)))))
# Out:
# COMMUNICATION
# Number of apps : 287
# Number of apps under 100 million : 260
# Average installs for apps under 100 million : 3,603,485
# Average installs for apps at and over 100 million : 374,074,074

# %% [markdown]
# To see if this pattern continues amongst the other top 5 genres, we have created the function `average_installs`. This function will carry out the same analysis that we did for the `Communication` genre.
#
# Below we can see that this pattern does in fact hold up amongst the other popular genres. When we remove the apps that have over 100 million installs we can see that the average drops dramatically. Of the top 5 genres we can see that `Photography` has the least disparity with a roughly 2.5 times decrease in the average number of installs per app, however this is still a significant decrease.

# %%
def average_installs(a_string): # Accepts only string from 'Category' column of gps_free
    under_100m_apps = []
    over_100m_apps = [] 
    total = 0
    total_under_100m = 0
    for app in gps_free:
        num_installs = int(app[5])
        if app[1] == a_string and num_installs < 100000000:
            under_100m_apps.append(num_installs)
            total += 1
            total_under_100m += 1
        elif app[1] == a_string and num_installs >= 100000000:
            over_100m_apps.append(num_installs)
            total += 1
    print(go_bold_red(a_string))        
    print(go_bold('Number of apps'), ':', total)
    print(go_bold('Number of apps under 100 million'), ':', total_under_100m)
    print(go_bold('Average installs for apps under 100 million'), ':', 
                  ('{:,}'.format(round(sum(under_100m_apps) / len(under_100m_apps)))))
    if sum(over_100m_apps) != 0:
        print(go_bold('Average installs for apps at and over 100 million'), ':', 
              ('{:,}'.format(round(sum(over_100m_apps) / len(over_100m_apps)))))
    print('\n')
    
average_installs('VIDEO_PLAYERS')
average_installs('SOCIAL')
average_installs('PHOTOGRAPHY')
average_installs('PRODUCTIVITY')
# Out:
# VIDEO_PLAYERS
# Number of apps : 159
# Number of apps under 100 million : 150
# Average installs for apps under 100 million : 5,544,878
# Average installs for apps at and over 100 million : 344,444,444
#
#
# SOCIAL
# Number of apps : 236
# Number of apps under 100 million : 223
# Average installs for apps under 100 million : 3,084,583
# Average installs for apps at and over 100 million : 369,230,769
#
#
# PHOTOGRAPHY
# Number of apps : 261
# Number of apps under 100 million : 242
# Average installs for apps under 100 million : 7,670,532
# Average installs for apps at and over 100 million : 147,368,421
#
#
# PRODUCTIVITY
# Number of apps : 345
# Number of apps under 100 million : 323
# Average installs for apps under 100 million : 3,379,657
# Average installs for apps at and over 100 million : 213,636,364

# %% [markdown]
# Looking at each of these other genres in more detail below we can see that the market is being dominated by a few apps with a high number of installs. For the `VIDEO_PLAYERS` genres we can see giants such as `YouTube`, `Google Play Movies & TV` and `MX Player`. For `SOCIAL` We have the likes of `Instagram`, `Google+` and `Facebook` that dominate this genre. For `PHOTOGRAPHY` we have `Google Photos` at a million installs and various photo editor apps at 100,000. For `PRODUCTIVITY` alot of the top apps are owned by Google and Microsoft, making it not just competing against popular apps but also against monopolies of that market.
#
# The concern here is that these apps with high numbers of installs are distorting the popularity of their genres, and if we were to develop an app for these genres we would be up against these giant companies.

# %%
def installs_per_app(a_string):
    app_installs_table = []
    for app in gps_free:
        if app[1] == a_string:
            key_cat_as_tuple = (int(app[5]), app[0])
            app_installs_table.append(key_cat_as_tuple)
    return app_installs_table

print(go_bold_red('VIDEO_PLAYERS')) 
sort_table_desc(installs_per_app('VIDEO_PLAYERS'))
print(go_bold_red('SOCIAL')) 
sort_table_desc(installs_per_app('SOCIAL'))
print(go_bold_red('PHOTOGRAPHY')) 
sort_table_desc(installs_per_app('PHOTOGRAPHY'))
print(go_bold_red('PRODUCTIVITY')) 
sort_table_desc(installs_per_app('PRODUCTIVITY'))
# Out:
# VIDEO_PLAYERS
# YouTube : 1,000,000,000
# Google Play Movies & TV : 1,000,000,000
# MX Player : 500,000,000
# VivaVideo - Video Editor & Photo Movie : 100,000,000
# VideoShow-Video Editor, Video Maker, Beauty Camera : 100,000,000
# VLC for Android : 100,000,000
# Motorola Gallery : 100,000,000
# Motorola FM Radio : 100,000,000
# Dubsmash : 100,000,000
# Vote for : 50,000,000
# Vigo Video : 50,000,000
# VMate : 50,000,000
# Samsung Video Library : 50,000,000
# Ringdroid : 50,000,000
# MiniMovie - Free Video and Slideshow Editor : 50,000,000
# LIKE – Magic Video Maker & Community : 50,000,000
# KineMaster – Pro Video Editor : 50,000,000
# HD Video Downloader : 2018 Best video mate : 50,000,000
# DU Recorder – Screen Recorder, Video Editor, Live : 50,000,000
# video player for android : 10,000,000
# iMediaShare – Photos & Music : 10,000,000
# YouTube Studio : 10,000,000
# Video Player All Format : 10,000,000
# Video Downloader - for Instagram Repost App : 10,000,000
# Video Downloader : 10,000,000
# Ustream : 10,000,000
# Quik – Free Video Editor for photos, clips, music : 10,000,000
# PowerDirector Video Editor App: 4K, Slow Mo & More : 10,000,000
# Omlet Arcade - Stream, Meet, Play : 10,000,000
# Naruto Shippuden - Watch Free! : 10,000,000
# Music - Mp3 Player : 10,000,000
# Mobizen Screen Recorder for SAMSUNG : 10,000,000
# Magisto Video Editor & Maker : 10,000,000
# Inst Download - Video & Photo : 10,000,000
# HTC Service － DLNA : 10,000,000
# HTC Gallery : 10,000,000
# FrostWire: Torrent Downloader & Music Player : 10,000,000
# FilmoraGo - Free Video Editor : 10,000,000
# Code : 10,000,000
# Cartoon Network App : 10,000,000
# BitTorrent®- Torrent Downloads : 10,000,000
# BSPlayer FREE : 10,000,000
# All Video Downloader : 10,000,000
# AfreecaTV : 10,000,000
# AZ Screen Recorder - No Root : 10,000,000
# YouCut - Video Editor & Video Maker, No Watermark : 5,000,000
# WiFi Baby Monitor - NannyCam : 5,000,000
# Video Editor : 5,000,000
# HTC Service—Video Player : 5,000,000
# Droid Zap by Motorola : 5,000,000
# Adobe Premiere Clip : 5,000,000
# ActionDirector Video Editor - Edit Videos Fast : 5,000,000
# video player : 1,000,000
# iSmart DV : 1,000,000
# iPlayIT for YouTube VR Player : 1,000,000
# XX HD Video downloader-Free Video Downloader : 1,000,000
# Vuze Torrent Downloader : 1,000,000
# Video.Guru - Video Maker : 1,000,000
# Video Status : 1,000,000
# Video Editor,Crop Video,Movie Video,Music,Effects : 1,000,000
# VidPlay : 1,000,000
# VUE: video editor & camcorder : 1,000,000
# VPlayer : 1,000,000
# Tencent Video - Supporting the whole network : 1,000,000
# SVT Play : 1,000,000
# Play Tube : 1,000,000
# OnePlus Gallery : 1,000,000
# OBJECTIVE : 1,000,000
# Multiple Videos at Same Time : 1,000,000
# Mobizen Screen Recorder for LG - Record, Capture : 1,000,000
# Iqiyi (for tablet) : 1,000,000
# HD Video Player : 1,000,000
# HD Video Download for Facebook : 1,000,000
# HD Movie Video Player : 1,000,000
# G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version) : 1,000,000
# Funny videos for whatsapp : 1,000,000
# EZCast – Cast Media to TV : 1,000,000
# DU Privacy-hide apps、sms、file : 1,000,000
# DS video : 1,000,000
# DS photo : 1,000,000
# BluTV : 1,000,000
# BSPlayer ARMv7 VFP CPU support : 1,000,000
# AndStream - Streaming Download : 1,000,000
# All Video Downloader 2018 : 1,000,000
# AX Player -Nougat Video Player : 1,000,000
# Video Player All Format for Android : 500,000
# GoPlus Cam : 500,000
# DR TV : 500,000
# CJ VLC HD Remote (+ Stream) : 500,000
# amazer - Global Kpop Video Community : 100,000
# Video Downloader for FB : Video Download with Link : 100,000
# Sketch 'n' go : 100,000
# Nero AirBurn : 100,000
# GoAction : 100,000
# Free TV series : 100,000
# Ez Screen Recorder (no ad) : 100,000
# EZ Web Video Cast | Chromecast : 100,000
# ES Audio Player ( Shortcut ) : 100,000
# BGCN TV : 100,000
# AW Screen Recorder No Root : 100,000
# AB Repeat Player : 100,000
# dv Prompter : 50,000
# bgtime.tv : 50,000
# ES-IPTV : 50,000
# BR Series : 50,000
# AX Video Player : 50,000
# ACTIVEON CX & CX GOLD : 50,000
# ek tuhi : 10,000
# W Box VMS : 10,000
# MelifeCam-M : 10,000
# HD VideoDownlaoder For Fb : XXVideo Downloader : 10,000
# HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017 : 10,000
# EZ-SEE : 10,000
# EZ Usenet for Easynews® : 10,000
# EZ TV Player : 10,000
# EML UPnP-AV Control Point : 10,000
# Downvids Helper - One touch DW : 10,000
# DG Video Editor : 10,000
# DG UPnP Player Free : 10,000
# Casper Ssinema : 10,000
# BS player remote : 10,000
# BK News Channel : 10,000
# W Box VMS HD : 5,000
# Videos downloader for Facebook:fast fb video saver : 5,000
# Q-See Plus : 5,000
# M-Sight Pro : 5,000
# HD Video Player - Video & MP3 Player | AV Player | : 5,000
# Furrion ES Control : 5,000
# EF Sidekick : 5,000
# DZ Popup Video Player : 5,000
# DV Lottery Photo : 5,000
# BR Video Player : 5,000
# BG video - floating video - background video : 5,000
# Ay : 5,000
# A-B repeater : 5,000
# 4K VIDEO PLAYER ULTRA HD : 5,000
# Music for Youtube - Tube Music BG, Red+ : 1,000
# Movie Downloader Torrent : Az Torrent : 1,000
# EZ game screen recorder with audio 1080P : 1,000
# CINE BR : 1,000
# BZ Langenthaler Tagblatt : 1,000
# BC iptv player : 1,000
# Ay Sabz Gunbad Waly : 1,000
# AV-IPTV : 1,000
# YourTube Video Views BG : 500
# Video Wallpaper Show : 500
# DG Screen Recorder : 500
# CX Monthly Tech News : 500
# CJ Camcorder : 500
# A-Z Screen Recorder - : 500
# List iptv FR : 100
# EC MANAGER : 100
# Bx-WiFi-GI : 100
# Bc Vod : 100
# BG MUSIC PLAYER - MUSIC PLAYER : 100
# AK Lodi Films : 100
# AJ Player : 100
# CI Stream : 10
# Art of F J Taylor : 10
#
#
# SOCIAL
# Instagram : 1,000,000,000
# Google+ : 1,000,000,000
# Facebook : 1,000,000,000
# Snapchat : 500,000,000
# Facebook Lite : 500,000,000
# VK : 100,000,000
# Tumblr : 100,000,000
# Tik Tok - including musical.ly : 100,000,000
# Tango - Live Video Broadcast : 100,000,000
# Pinterest : 100,000,000
# LinkedIn : 100,000,000
# Badoo - Free Chat & Dating App : 100,000,000
# BIGO LIVE - Live Stream : 100,000,000
# ooVoo Video Calls, Messaging & Stories : 50,000,000
# Zello PTT Walkie Talkie : 50,000,000
# SKOUT - Meet, Chat, Go Live : 50,000,000
# POF Free Dating App : 50,000,000
# MeetMe: Chat & Meet New People : 50,000,000
# textPlus: Free Text & Calls : 10,000,000
# magicApp Calling & Messaging : 10,000,000
# YouNow: Live Stream Video Chat : 10,000,000
# We Heart It : 10,000,000
# Waplog - Free Chat, Dating App, Meet Singles : 10,000,000
# TextNow - free text + calls : 10,000,000
# Text free - Free Text + Call : 10,000,000
# Text Me: Text Free, Call Free, Second Phone Number : 10,000,000
# Tapatalk - 100,000+ Forums : 10,000,000
# Tagged - Meet, Chat & Dating : 10,000,000
# SayHi Chat, Meet New People : 10,000,000
# Quora : 10,000,000
# Phone Tracker : Family Locator : 10,000,000
# Periscope - Live Video : 10,000,000
# Path : 10,000,000
# Mico- Stranger Chat Random video Chat, Live, Meet : 10,000,000
# Messenger Messenger : 10,000,000
# Messenger : 10,000,000
# Messages, Text and Video Chat for Messenger : 10,000,000
# LiveMe - Video chat, new friends, and make money : 10,000,000
# Legend - Animate Text in Video : 10,000,000
# LOVOO : 10,000,000
# Kate Mobile for VK : 10,000,000
# Jaumo Dating, Flirt & Live Video : 10,000,000
# HTC Social Plugin - Facebook : 10,000,000
# Grindr - Gay chat : 10,000,000
# Free phone calls, free texting SMS on free number : 10,000,000
# Find My Friends : 10,000,000
# Dating App, Flirt & Chat : W-Match : 10,000,000
# Amino: Communities and Chats : 10,000,000
# Who Viewed My Facebook Profile - Stalkers Visitors : 5,000,000
# Whisper : 5,000,000
# Web Browser & Fast Explorer : 5,000,000
# VidStatus app - Status Videos & Status Downloader : 5,000,000
# Timehop : 5,000,000
# Text Free: WiFi Calling App : 5,000,000
# Telegram X : 5,000,000
# SPARK - Live random video chat & meet new people : 5,000,000
# Nextdoor - Local neighborhood news & classifieds : 5,000,000
# Meetup : 5,000,000
# Meet – Talk to Strangers Using Random Video Chat : 5,000,000
# Instachat 😜 : 5,000,000
# Hornet - Gay Social Network : 5,000,000
# Hide Something - Photo, Video : 5,000,000
# HOLLA Live: Meet New People via Random Video Chat : 5,000,000
# FunForMobile Ringtones & Chat : 5,000,000
# Frim: get new friends on local chat rooms : 5,000,000
# Fame Boom for Real Followers, Likes : 5,000,000
# Blogger : 5,000,000
# 💘 WhatsLov: Smileys of love, stickers and GIF : 1,000,000
# pixiv : 1,000,000
# Wishbone - Compare Anything : 1,000,000
# VMate Lite - Funny Short Videos Social Network : 1,000,000
# U LIVE – Video Chat & Stream : 1,000,000
# TwitCasting Live : 1,000,000
# The Messenger App : 1,000,000
# Stickers for Facebook : 1,000,000
# Snaappy – 3D fun AR core communication platform : 1,000,000
# Moment : 1,000,000
# MobilePatrol Public Safety App : 1,000,000
# Messenger Pro : 1,000,000
# Love Sticker : 1,000,000
# Love Images : 1,000,000
# Lesbian Chat & Dating - SPICY : 1,000,000
# Jodel - The Hyperlocal App : 1,000,000
# GUYZ - Gay Chat & Gay Dating : 1,000,000
# Frontback - Social Photos : 1,000,000
# Friendly for Facebook : 1,000,000
# Free Messages, Video, Chat,Text for Messenger Plus : 1,000,000
# FollowMeter for Instagram : 1,000,000
# Fiesta by Tango - Find, Meet and Make New Friends : 1,000,000
# Faster for Facebook Lite : 1,000,000
# Family GPS tracker KidControl + GPS by SMS Locator : 1,000,000
# Facebook Local : 1,000,000
# Facebook Creator : 1,000,000
# EZ Video Download for Facebook : 1,000,000
# Couple - Relationship App : 1,000,000
# Banjo : 1,000,000
# BOO! - Next Generation Messenger : 1,000,000
# B-Messenger Video Chat : 1,000,000
# All Social Networks : 1,000,000
# +Download 4 Instagram Twitter : 1,000,000
# Web Browser ( Fast & Secure Web Explorer) : 500,000
# Verdad o Reto : 500,000
# Swift for Facebook Lite : 500,000
# Stream - Live Video Community : 500,000
# Qeek for Instagram - Zoom profile insta DP : 500,000
# Puffin for Facebook : 500,000
# Profile Tracker - Who Viewed My Facebook Profile : 500,000
# Pink Color for Facebook : 500,000
# Mirrativ: Live Stream Any App : 500,000
# Greeting Cards & Wishes : 500,000
# Gayvox - Gay Lesbian Bi Dating : 500,000
# Fake Chat (Direct Message) : 500,000
# Daddyhunt: Gay Dating : 500,000
# Bloglovin' : 500,000
# uCiC- Videos and Photos on demand : 100,000
# YAY - TBH : 100,000
# What U See : 100,000
# The Video Messenger App : 100,000
# Social network all in one 2018 : 100,000
# See U - Random video chat, video chat : 100,000
# Phoenix - Facebook & Messenger : 100,000
# Patook - make platonic friends : 100,000
# Meet U - Get Friends for Snapchat, Kik & Instagram : 100,000
# MB Notifications for FB (Free) : 100,000
# KPOP Amino for K-Pop Entertainment : 100,000
# KDRAMA Amino for K-Drama Fans : 100,000
# FutureNet your social app : 100,000
# Fr Daoud Lamei : 100,000
# Faster Social for Facebook : 100,000
# Dr. B.R.Ambedkar : 100,000
# Dr B R Ambedkar (Jai Bhim) : 100,000
# Dating.dk : 100,000
# DP and Status for WhatsApp 2018 : 100,000
# Chat For Strangers - Video Chat : 100,000
# Blogaway for Android (Blogger) : 100,000
# Undertale AU Amino : 50,000
# Rande.cz : 50,000
# Hashtags For Likes.co : 50,000
# Golden telegram : 50,000
# FCB Connect - FC Barcelona : 50,000
# Equestria Amino for MLP : 50,000
# EXO-L Amino for EXO Fans : 50,000
# CP Dialer : 50,000
# BT Dating -Find your match, help cupid, be social : 50,000
# Anime et Manga Amino en Français : 50,000
# Unlimited Group Links - Whatsapp, FB, Telegram : 10,000
# U-Report : 10,000
# Stickers for Imo, fb, whatsapp : 10,000
# Share G - Images Sharing - Wallpapers App : 10,000
# Mini for Facebook lite : 10,000
# Mali J : 10,000
# Lite Messenger for Facebook Lite : 10,000
# Jamaa Amino for Animal Jam : 10,000
# Ek Maratha : 10,000
# Eddsworld Amino : 10,000
# Digi-TV.ch : 10,000
# Daily Murli Saar Widget : 10,000
# DM Me - Chat : 10,000
# Cyprus Police : 10,000
# Best DP and Status : 10,000
# BT Communicator : 10,000
# BK Traffic Control cum Chart : 10,000
# Au Pair : 10,000
# funny Image Comments for FB : 5,000
# TNEB Bill Online Payment (Tamil) : 5,000
# TN e Sevai TN EB Bill Patta Citta EC Birth All Hub : 5,000
# Profile Pictures and DP for Whatsapp : 5,000
# Instant DP Downloader for Instagram : 5,000
# Dp for Facebook : 5,000
# Dp For Whatsapp : 5,000
# DP Display Pictures Life Quotes Motivational GM : 5,000
# DM for IG 😘 - Image & Video Saver for Instagram : 5,000
# DB Event App : 5,000
# Check Your Visitors on FB ? : 5,000
# signály.cz : 1,000
# eChallan Andhra Pradesh (AP) : 1,000
# Zdravei.BG : 1,000
# V Bucks ProTips New : 1,000
# TN EC Online New : 1,000
# Students.ch : 1,000
# Sabka Malik Ek Sai : 1,000
# Noticias DF : 1,000
# Media Sosial TNI AU : 1,000
# Join R, Community Engagement : 1,000
# H letter images : 1,000
# European Solidarity Corps : 1,000
# DW Streaming : 1,000
# DC Comics Amino : 1,000
# CG Districts : 1,000
# Black Social : 1,000
# BR Chat Bot : 1,000
# BGKontakti Vienna BG Kontakti : 1,000
# BGKontakti Bayern BG Kontakti : 1,000
# BG LINKED (BGLINKED) : 1,000
# Auto DM for Twitter 🔥 : 1,000
# Alarm.fo – choose your info : 1,000
# iCard BD Plus : 500
# Downloader plus for FB : 500
# DK Murali : 500
# DF BugMeNot : 500
# Br Browser : 500
# BGKontakti London BG Kontakti : 500
# i-share AF/KLM (AFKL ishare) : 100
# TN Patta /Chitta /EC New : 100
# Rejoin Your Ex : 100
# Naruto & Boruto FR : 100
# Myjob@BM : 100
# Movement BE : 100
# Message AI - Write Better Messages (Free) : 100
# GirlTalk.dk : 100
# Frases Cristianas de Esperanza y Fe : 100
# Evasion.bz : 100
# Eternal Light AG : 100
# Discípulos em BH : 100
# DV Statistics : 100
# DM Storage (for twitter) : 100
# CJ Gospel Hour : 100
# Alumni BJ : 100
# UP EB Bill Payment & Details : 50
# FB Advanced Search : 50
# EG Way Life : 50
# Coupe Adhémar EY 2017 : 50
# quran-DZ : 10
# bm-Events : 10
# Reisedealz.eu : 10
# Otto DM : 10
# News Dz : 10
# Hum Ek Hain 2.02 : 10
# EO RAIPUR : 10
# DN Blog : 10
# BA 3 Banjarmasin : 10
# CB Heroes : 5
# C.P. CERVANTES (TOBARRA) : 5
# BH Connect : 1
# Amleen Ey : 1
# Pekalongan CJ : 0
#
#
# PHOTOGRAPHY
# Google Photos : 1,000,000,000
# Z Camera - Photo Editor, Beauty Selfie, Collage : 100,000,000
# YouCam Perfect - Selfie Photo Editor : 100,000,000
# YouCam Makeup - Magic Selfie Makeovers : 100,000,000
# Sweet Selfie - selfie camera, beauty cam, photo edit : 100,000,000
# S Photo Editor - Collage Maker , Photo Collage : 100,000,000
# Retrica : 100,000,000
# PicsArt Photo Studio: Collage Maker & Pic Editor : 100,000,000
# PhotoGrid: Video & Pic Collage Maker, Photo Editor : 100,000,000
# Photo Editor Pro : 100,000,000
# Photo Editor Collage Maker Pro : 100,000,000
# Photo Collage Editor : 100,000,000
# LINE Camera - Photo editor : 100,000,000
# Cymera Camera- Photo Editor, Filter,Collage,Layout : 100,000,000
# Candy Camera - selfie, beauty camera, photo editor : 100,000,000
# Camera360: Selfie Photo Editor with Funny Sticker : 100,000,000
# BeautyPlus - Easy Photo Editor & Selfie Camera : 100,000,000
# B612 - Beauty & Filter Camera : 100,000,000
# AR effect : 100,000,000
# Video Editor Music,Cut,No Crop : 50,000,000
# VSCO : 50,000,000
# Square InPic - Photo Editor & Collage Maker : 50,000,000
# Snapseed : 50,000,000
# Selfie Camera - Photo Editor & Filter & Sticker : 50,000,000
# SNOW - AR Camera : 50,000,000
# Pixlr – Free Photo Editor : 50,000,000
# Pic Collage - Photo Editor : 50,000,000
# PhotoWonder: Pro Beauty Photo Editor Collage Maker : 50,000,000
# Photo Lab Picture Editor: face effects, art frames : 50,000,000
# Photo Effects Pro : 50,000,000
# Photo Editor by Aviary : 50,000,000
# Photo Editor Selfie Camera Filter & Mirror Image : 50,000,000
# Motorola Camera : 50,000,000
# MomentCam Cartoons & Stickers : 50,000,000
# MakeupPlus - Your Own Virtual Makeup Artist : 50,000,000
# Keepsafe Photo Vault: Hide Private Photos & Videos : 50,000,000
# InstaSize Photo Filters & Collage Editor : 50,000,000
# InstaBeauty -Makeup Selfie Cam : 50,000,000
# Boomerang from Instagram : 50,000,000
# Adobe Photoshop Express:Photo Editor Collage Maker : 50,000,000
# ASUS Gallery : 50,000,000
# Wondershare PowerCam : 10,000,000
# Sweet Snap - live filter, Selfie photo edit : 10,000,000
# Sweet Camera - Selfie Filters, Beauty Camera : 10,000,000
# Scoompa Video - Slideshow Maker and Video Editor : 10,000,000
# RetroSelfie - Selfie Editor : 10,000,000
# Retro Camera : 10,000,000
# QuickPic - Photo Gallery with Google Drive Support : 10,000,000
# Pixlr-o-matic : 10,000,000
# PixelLab - Text on pictures : 10,000,000
# PhotoScan by Google Photos : 10,000,000
# PhotoLayers〜Superimpose,Eraser : 10,000,000
# PhotoFunia : 10,000,000
# PhotoDirector Photo Editor App : 10,000,000
# Photo Studio : 10,000,000
# Photo Mixer : 10,000,000
# Photo Frames : 10,000,000
# Photo Frame : 10,000,000
# Photo Editor by BeFunky : 10,000,000
# Photo Editor : 10,000,000
# Photo Collage Maker : 10,000,000
# Photo Collage - Layout Editor : 10,000,000
# Photo Collage - InstaMag : 10,000,000
# Phonto - Text on Photos : 10,000,000
# PIP Selfie Camera Photo Editor : 10,000,000
# Open Camera : 10,000,000
# No Crop & Square for Instagram : 10,000,000
# My Photo Keyboard : 10,000,000
# Mirror Photo:Editor Collage (HD) : 10,000,000
# Meitu – Beauty Cam, Easy Photo Editor : 10,000,000
# Love Collage - Photo Editor : 10,000,000
# LightX Photo Editor & Photo Effects : 10,000,000
# HD Camera for Android : 10,000,000
# HD Camera Ultra : 10,000,000
# GoPro (formerly Capture) : 10,000,000
# Free Slideshow Maker & Video Editor : 10,000,000
# Fotor Photo Editor - Photo Collage & Photo Effects : 10,000,000
# Font Studio- Photo Texts Image : 10,000,000
# Flickr : 10,000,000
# Facejjang : 10,000,000
# FaceApp : 10,000,000
# Face Filter, Selfie Editor - Sweet Camera : 10,000,000
# EyeEm - Camera & Photo Filter : 10,000,000
# Color Touch Effects : 10,000,000
# Candy selfie - photo editor, live filter camera : 10,000,000
# Cameringo Lite. Filters Camera : 10,000,000
# Camera360 Lite - Selfie Camera : 10,000,000
# Camera for Android : 10,000,000
# Camera MX - Free Photo & Video Camera : 10,000,000
# Camera FV-5 Lite : 10,000,000
# Bokeh (Background defocus) : 10,000,000
# Blur Image Background : 10,000,000
# Bestie - Camera360 Selfie : 10,000,000
# Beauty Makeup Snappy Collage Photo Editor - Lidow : 10,000,000
# Background Eraser : 10,000,000
# AfterFocus : 10,000,000
# ASUS PixelMaster Camera : 10,000,000
# A+ Gallery - Photos & Videos : 10,000,000
# Visage Lab – face retouch : 5,000,000
# Sweet Camera : 5,000,000
# SuperPhoto - Effects & Filters : 5,000,000
# Story Saver for Instagram : 5,000,000
# Silent Camera [High Quality] : 5,000,000
# Shutterfly: Free Prints, Photo Books, Cards, Gifts : 5,000,000
# Pretty Makeup, Beauty Photo Editor & Snappy Camera : 5,000,000
# Pixgram- video photo slideshow : 5,000,000
# Picture Grid Builder : 5,000,000
# Photo Editor- : 5,000,000
# Muzy - Share photos & collages : 5,000,000
# Moto Photo Editor : 5,000,000
# MIX by Camera360 : 5,000,000
# Huji Cam : 5,000,000
# High-Speed Camera (GIF,Burst) : 5,000,000
# HD Camera - Best Cam with filters & panorama : 5,000,000
# HD Camera : 5,000,000
# Ghost In Photo : 5,000,000
# Collage&Add Stickers papelook : 5,000,000
# Change photo background : 5,000,000
# Camera ZOOM FX - FREE : 5,000,000
# Blur Image Background Editor (Blur Photo Editor) : 5,000,000
# Blur Image - DSLR focus effect : 5,000,000
# Adobe Photoshop Fix : 5,000,000
# Adobe Illustrator Draw : 5,000,000
# A Better Camera : 5,000,000
# love : 1,000,000
# XDV : 1,000,000
# Waterfall Photo Frames : 1,000,000
# Video Maker with Photo and Music : 1,000,000
# Unicorn Photo : 1,000,000
# Ultimate Background Eraser : 1,000,000
# TouchNote: Cards & Gifts : 1,000,000
# Thumbnail Maker : 1,000,000
# Snapfish : 1,000,000
# Snap Cat Face Camera : 1,000,000
# Six Pack Abs Photo Editor : 1,000,000
# Selfie Photo Editor : 1,000,000
# Selfie Camera: Beauty Camera, Photo Editor,Collage : 1,000,000
# Samsung SMART CAMERA App : 1,000,000
# Pic Stitch - #1 Collage Maker : 1,000,000
# Phogy, 3D Camera : 1,000,000
# Pencil Photo Sketch-Sketching Drawing Photo Editor : 1,000,000
# Night Photo Frame : 1,000,000
# Mega Photo : 1,000,000
# Makeup Photo Editor: Makeup Camera & Makeup Editor : 1,000,000
# Makeup Editor -Beauty Photo Editor & Selfie Camera : 1,000,000
# LightMeter Free : 1,000,000
# LALALAB prints your photos, photobooks and magnets : 1,000,000
# Kids Photo Frames : 1,000,000
# KVAD Camera +: Selfie, Photo Filter, Grids : 1,000,000
# InstaCam - Camera for Selfie : 1,000,000
# Insave-Download for Instagram : 1,000,000
# Hypocam : 1,000,000
# HD Camera Pro for Android : 1,000,000
# HD Camera - silent shutter : 1,000,000
# HD Camera - Quick Snap Photo & Video : 1,000,000
# FreePrints – Free Photos Delivered : 1,000,000
# Footej Camera : 1,000,000
# FilterGrid - Cam&Photo Editor : 1,000,000
# F-Stop Gallery : 1,000,000
# Ez iCam : 1,000,000
# DSLR Camera Hd Ultra Professional : 1,000,000
# Cut Out : Background Eraser and background changer : 1,000,000
# Canon CameraWindow : 1,000,000
# Camera51 - a smarter camera : 1,000,000
# Camera Pro : 1,000,000
# Blur : 1,000,000
# Beauty Makeup – Photo Makeover : 1,000,000
# BQ Camera : 1,000,000
# Auto Background Changer : 1,000,000
# Afterlight : 1,000,000
# Add Watermark Free : 1,000,000
# Add Text To Photo : 1,000,000
# easyFocus : 500,000
# camera zoom moon : 500,000
# U Camera : Phone 6s OS 9 style : 500,000
# Sweet Snap Lite - live filter, Selfie photo editor : 500,000
# How Do I Look : 500,000
# Groovebook Photo Books & Gifts : 500,000
# Garden Photo Frames - Garden Photo Editor : 500,000
# DU GIF Maker: GIF Maker, Video to GIF & GIF Editor : 500,000
# Brica BPRO5 AE : 500,000
# Blurfoto : Auto blur photo background & DSLR focus : 500,000
# Background Changer & Eraser : 500,000
# BT Camera : 500,000
# ez Share Android app : 100,000
# V.360° Camera : 100,000
# SportLook : 100,000
# Picai - Smart AI Camera : 100,000
# Photo frame : 100,000
# Gold Teeth Photo Editor : 100,000
# Fifa World Cup 2018: Photo Frame Editor & DP Maker : 100,000
# DU Collage Maker - Photo Collage & Grid & Layout : 100,000
# DSLR Photography Training apps : 100,000
# DP Maker : 100,000
# DP Creator for WhatsApp : 100,000
# Cover Camera for FB : 100,000
# Camera V7 24 Megapixel : 100,000
# Black & White Camera - Lovely BW : 100,000
# B Tiff Viewer : 100,000
# AZ Camera - Manual Pro Cam : 100,000
# 4K Ultra Camera : 100,000
# 24 megapixel hd camera : 100,000
# Wifi Action Camera : 50,000
# Moony Lab - Print Photos, Books & Magnets ™ : 50,000
# DV Lottery Photo Tool : 50,000
# DP Status 2017 : 50,000
# BlitzWolf Shutter - BW Shutter : 50,000
# B&W Photo Filter Editor : 50,000
# Z Camera : 10,000
# Square DP For Whatsapp : 10,000
# Profile w/o crop for Telegram : 10,000
# Night Camera Blur Effect : 10,000
# Leica Q : 10,000
# FN Cam : 10,000
# FH WiFiCam : 10,000
# DSLR camera - Auto Focus and Blur Professional : 10,000
# DP Photo Editor : 10,000
# DF Night Selfies : 10,000
# DENVER ACTION CAM 3 : 10,000
# Be Fabulous PHOTO BOOTH : 10,000
# BL 1-Click Camera - Free : 10,000
# Insta Square Profile DP : 5,000
# FL Drone 2 : 5,000
# DP Editor : 5,000
# CB Edits PNG & CB Backgrounds : 5,000
# Photo Editor - BPhoto : 1,000
# Photo BG Changer : 1,000
# PIP-Camera FN Photo Effect : 1,000
# Magical Insta DP : 1,000
# Live DV : 1,000
# Light Meter - EV : 1,000
# Leica CL : 1,000
# FB Photographie : 1,000
# Dp For FB : 1,000
# DV-4036 by Somikon : 1,000
# DS-L4 Viewer : 1,000
# BK Photography : 1,000
# Auto Dslr Photo Effect : Auto Focus Effect : 1,000
# All Types DP & Status Maker : 1,000
# AEE AP : 1,000
# Selfie With Champion AJ Style : 500
# DC-014 : 500
# CB Hair Png - New Hair Png For CB Editing : 500
# BC Camera : 500
# AI Image Recognizer (beta) : 500
# Wallpaper.cz : 100
# LC-DB-LITE : 100
# FD Fotografia : 100
# DV KING 4K : 100
# DV KING : 100
# CG Prints : 100
# CB VIDEO VISION : 100
# Blender BG - Photo Blend With Background : 100
# BL Portfolio : 100
# Analog BW - Camera filter effect foto film retouch : 100
# AJ Cam : 100
# A.J. Styles HD Wallpapers 2018 : 100
# Touch DV : 50
# Displaying You VR : 50
# i am EB : 10
# BG Editor : 5
#
#
# PRODUCTIVITY
# Google Drive : 1,000,000,000
# Microsoft Word : 500,000,000
# Google Calendar : 500,000,000
# Dropbox : 500,000,000
# Cloud Print : 500,000,000
# WPS Office - Word, Docs, PDF, Note, Slide & Sheet : 100,000,000
# SwiftKey Keyboard : 100,000,000
# Samsung Notes : 100,000,000
# Microsoft PowerPoint : 100,000,000
# Microsoft Outlook : 100,000,000
# Microsoft OneNote : 100,000,000
# Microsoft OneDrive : 100,000,000
# Microsoft Excel : 100,000,000
# Google Slides : 100,000,000
# Google Sheets : 100,000,000
# Google Keep : 100,000,000
# Google Docs : 100,000,000
# Evernote – Organizer, Planner for Notes & Memos : 100,000,000
# ES File Explorer File Manager : 100,000,000
# ColorNote Notepad Notes : 100,000,000
# CamScanner - Phone PDF Creator : 100,000,000
# Adobe Acrobat Reader : 100,000,000
# myAT&T : 50,000,000
# Verizon Cloud : 50,000,000
# QR Droid : 50,000,000
# My Airtel-Online Recharge, Pay Bill, Wallet, UPI : 50,000,000
# Mobizen Screen Recorder - Record, Capture, Edit : 50,000,000
# MEGA : 50,000,000
# File Browser by Astro (File Manager) : 50,000,000
# Do It Later: Tasks & To-Dos : 50,000,000
# Calculator - unit converter : 50,000,000
# Alarm Clock: Stopwatch & Timer : 50,000,000
# Advanced Task Killer : 50,000,000
# iTranslate Translator & Dictionary : 10,000,000
# aCalendar - Android Phone : 10,000,000
# Wunderlist: To-Do List & Tasks : 10,000,000
# U+Box : 10,000,000
# Todoist: To-do lists for task management & errands : 10,000,000
# S Note : 10,000,000
# QR Scanner & Barcode Scanner 2018 : 10,000,000
# Polaris Office - Word, Docs, Sheets, Slide, PDF : 10,000,000
# Notepad & To do list : 10,000,000
# Notepad : 10,000,000
# NQ Mobile Security & Antivirus : 10,000,000
# MyVodafone (India) - Online Recharge & Pay Bills : 10,000,000
# Mobile Security: Antivirus, Web Scan & App Lock : 10,000,000
# Mobile Security & Antivirus : 10,000,000
# Metro name iD : 10,000,000
# LOCX Applock Lock Apps & Photo : 10,000,000
# Keeper: Free Password Manager & Secure Vault : 10,000,000
# Jorte Calendar & Organizer : 10,000,000
# HTC Mail : 10,000,000
# HTC File Manager : 10,000,000
# HTC Calendar : 10,000,000
# Google PDF Viewer : 10,000,000
# Google Assistant : 10,000,000
# Fake Call - Fake Caller ID : 10,000,000
# Easy Voice Recorder : 10,000,000
# Chrome Beta : 10,000,000
# CM FILE MANAGER HD : 10,000,000
# AutoCAD - DWG Viewer & Editor : 10,000,000
# Any.do: To-do list, Calendar, Reminders & Planner : 10,000,000
# AndroZip™ FREE File Manager : 10,000,000
# All-In-One Toolbox: Cleaner, Booster, App Manager : 10,000,000
# AVG Cleaner – Speed, Battery & Memory Booster : 10,000,000
# AT&T Mobile Transfer : 10,000,000
# ASUS SuperNote : 10,000,000
# ASUS Quick Memo : 10,000,000
# ASUS Calling Screen : 10,000,000
# APUS Booster - Space Cleaner & Booster : 10,000,000
# lifebox : 5,000,000
# Yandex.Disk : 5,000,000
# Ultimate Notepad : 5,000,000
# Trello : 5,000,000
# To Do List : 5,000,000
# The Maner : 5,000,000
# PDF Viewer & Book Reader : 5,000,000
# Note Everything : 5,000,000
# My Claro Peru : 5,000,000
# Microsoft Translator : 5,000,000
# MediaFire : 5,000,000
# Keep My Notes - Notepad & Memo : 5,000,000
# Ginger Keyboard - Emoji, GIFs, Themes & Games : 5,000,000
# G Cloud Backup : 5,000,000
# EBookDroid - PDF & DJVU Reader : 5,000,000
# DigiCal Calendar Agenda : 5,000,000
# Content Transfer : 5,000,000
# Clean My Android : 5,000,000
# Calendar Widget Month + Agenda : 5,000,000
# Business Calendar 2 : 5,000,000
# Archos File Manager : 5,000,000
# pCloud: Free Cloud Storage : 1,000,000
# e-Boks.dk : 1,000,000
# Ultimate Chest Tracker : 1,000,000
# Today Calendar 2017 : 1,000,000
# To-Do List Widget : 1,000,000
# To-Do Calendar Planner : 1,000,000
# To Do Reminder with Alarm : 1,000,000
# Time Recording - Timesheet App : 1,000,000
# TickTick: To Do List with Reminder, Day Planner : 1,000,000
# S’more - Earn Cash Rewards : 1,000,000
# SugarSync : 1,000,000
# Sticky Note + : Sync Notes : 1,000,000
# Squid - Take Notes & Markup PDFs : 1,000,000
# Solid Explorer File Manager : 1,000,000
# Solid Explorer Classic : 1,000,000
# Smart File Manager : 1,000,000
# Simple Notepad : 1,000,000
# Security & Privacy : 1,000,000
# Resume Free : 1,000,000
# Pushbullet - SMS on PC : 1,000,000
# Power Booster - Junk Cleaner & CPU Cooler & Boost : 1,000,000
# Planner Pro-Personal Organizer : 1,000,000
# Phone Clean Best Speed Booster : 1,000,000
# NoteToDo. Notes. To do list : 1,000,000
# New Calendar : 1,000,000
# Můj T-Mobile Business : 1,000,000
# MyMTN : 1,000,000
# Multiling O Keyboard + emoji : 1,000,000
# Microsoft To-Do: List, Task & Reminder : 1,000,000
# Mahalaxmi Dindarshika 2018 : 1,000,000
# Lyra Virtual Assistant : 1,000,000
# Loop - Habit Tracker : 1,000,000
# JotterPad - Writer, Screenplay, Novel : 1,000,000
# IFTTT : 1,000,000
# Hacker's Keyboard : 1,000,000
# Google AdSense : 1,000,000
# Extreme- Personal Voice Assistant : 1,000,000
# Epson iProjection : 1,000,000
# Emoji Android L Keyboard : 1,000,000
# EX File Explorer File Manager : 1,000,000
# ES Material Theme for Pro : 1,000,000
# Do it (Tomorrow) : 1,000,000
# Dashlane Free Password Manager : 1,000,000
# DS file : 1,000,000
# Cozi Family Organizer : 1,000,000
# Chrome Canary (Unstable) : 1,000,000
# Chelsea FC Official Keyboard : 1,000,000
# Calendar+ Schedule Planner App : 1,000,000
# Cal - Google Calendar + Widget : 1,000,000
# CY Security Antivirus Cleaner : 1,000,000
# Avast Wi-Fi Finder : 1,000,000
# Amazon Drive : 1,000,000
# Adobe Fill & Sign: Easy PDF Form Filler : 1,000,000
# Adblock Fast : 1,000,000
# ALL-IN-ONE PACKAGE TRACKING : 1,000,000
# AL Voice Recorder : 1,000,000
# Ultimate Calculator for CR : 500,000
# Time Planner - Schedule, To-Do List, Time Tracker : 500,000
# T-Mobile Content Transfer : 500,000
# Q Link Wireless Zone : 500,000
# Planning Center Services : 500,000
# Official QR Code® Reader "Q" : 500,000
# My Effectiveness: To do, Tasks : 500,000
# Memory Helper - To do list, Notepad, Notes, Memo : 500,000
# ES Holo Theme for Pro : 500,000
# DS cam : 500,000
# Ad Detect Plugin - Handy Tool : 500,000
# A-Z App Store : 500,000
# 7 Weeks - Habit & Goal Tracker : 500,000
# cm, mm to inch, feet converter tool : 100,000
# Unclouded - Cloud Manager : 100,000
# Total AV : 100,000
# TIMBER AD FILTER - Very useful ad block app : 100,000
# Synology Drive : 100,000
# Resume Builder and CV maker app : 100,000
# Pocket RxTx Free : 100,000
# MyLifeOrganized: To-Do List : 100,000
# Inch/cm/Foot Conversion : 100,000
# Ike - To-Do List, Task List : 100,000
# IQ Test : 100,000
# IDM for Facebook ★ Downloader : 100,000
# IDM Internet Download Manager : 100,000
# Goal Meter: Goal Tracker, Habit Changer,To-Do List : 100,000
# Future Cloud : 100,000
# Friday: Smart Personal Assistant : 100,000
# File Explorer : 100,000
# Exército Brasileiro : 100,000
# EZ Switch Widget : 100,000
# EZ File Manager(Root Explorer) : 100,000
# ES Disk Analyzer - Storage Space : 100,000
# Dz Dinars Numbers to letters : 100,000
# Dr.Android Repair Master 2017 : 100,000
# Download Manager Pro FREE : 100,000
# Do Not Disturb : 100,000
# DS note : 100,000
# Clean My House – Chore To Do List, Task Scheduler : 100,000
# Calculator L : 100,000
# Bits Watch Face : 100,000
# Best Applock - Locker & No Ads : 100,000
# 2Do - Reminders, To-do List & Notes : 100,000
# WiFi-o-Matic : 50,000
# WFVS 2018 | WhatApp Full Video Status & Downloader : 50,000
# U Assist - Screen Mirroring & Sharing App : 50,000
# To-do list : 50,000
# Safe Notes - Secure Ad-free notepad : 50,000
# SH Script Runner : 50,000
# Numbers Into Words : 50,000
# My C Spire : 50,000
# MultiMessage for FB Messenger : 50,000
# Inputting Plus: Ctrl + Z/F/C/V : 50,000
# EZ Display : 50,000
# ESLock File Recovery Lite : 50,000
# CTRL-F - Search the real world : 50,000
# BJ Memo Widget : 50,000
# Add-On: Alcatel (h) : 50,000
# ai.Bot Box : 10,000
# Wi-Fi Networks : 10,000
# Trimble DL : 10,000
# Trimble Ag Mobile : 10,000
# Tap N Pay : 10,000
# Solar CT PV System Power : 10,000
# Remote Control For All AC - Universal Remote : 10,000
# N Files - File Manager & Explorer : 10,000
# Mix Tank – Tank Mixing Ag App : 10,000
# Larry H Miller Automotive : 10,000
# Eurostat Country Profiles : 10,000
# Electricity Bill Calculator BD : 10,000
# EZ Inspections : 10,000
# EC Taximeter : 10,000
# DG Report Reminder : 10,000
# Curriculum Vitae - Resume CV : 10,000
# CD Library : 10,000
# Alt-C : 10,000
# Turbo AI™ - Personal assistant : 5,000
# Resume & CV Creator by Desygner : 5,000
# R-net for Android : 5,000
# Mind Map AR, Augmented Reality ARCore Mind Mapping : 5,000
# EU Economy : 5,000
# ESS Mobile for AE : 5,000
# CG - Calendars Add-On : 5,000
# Bomb and Nade Timer for CS:GO : 5,000
# BA Calculator : 5,000
# Air Conditioner Maintenance : 5,000
# Add-On: bq (a) : 5,000
# AP ENPS Mobile : 5,000
# Simple EV Calc : 1,000
# Sai Baba - Sabka Malik Ek : 1,000
# Safe Wi-Fi : 1,000
# Puck AI Personal Assistant Robot : 1,000
# Professional AV Solution & Products information : 1,000
# New Holland Agriculture T5 EC : 1,000
# My CU - Caucasus University : 1,000
# Krypton by krypt.co : 1,000
# Fayr - Co-Parenting Simplified : 1,000
# FQ METER : 1,000
# FL House : 1,000
# EZ Notes Lite : 1,000
# EF Calculator : 1,000
# DS-20000S : 1,000
# DG Phone Call Task Switcher : 1,000
# DB Manager : 1,000
# Commission Manager : 1,000
# CircleCI Viewer : 1,000
# Charlotte County, FL : 1,000
# Calendars (En, Bn, Ar) : 1,000
# CG - Conference Call Add-On : 1,000
# CA World '17 : 1,000
# BG+Phone Backup : 1,000
# BD Field Force : 1,000
# BD Attendance : 1,000
# Ag PhD Soils : 1,000
# Add-On: bq (c) : 1,000
# Add-On: bq (b) : 1,000
# AI Sight : 1,000
# Tips Microsoft Dynamics Ax : 500
# Q Actions - Digital Assistant : 500
# IP address BW : 500
# Florida Cooling Supply HVAC : 500
# Fast Notes FJ : 500
# Ek Vote : 500
# EY Events Switzerland : 500
# EY ATL Fuel Calculator : 500
# DT Manager : 500
# DN Events : 500
# CP Connect 2.0 : 500
# CJ Wilson's ZoomZoomnation : 500
# BZ Dealer : 500
# iReadMe : 100
# ec-Work : 100
# eG Monitor : 100
# Town of Princeton, BC : 100
# Tips & Tricks Dynamics AX 365 : 100
# Thistletown CI : 100
# Somos CG : 100
# SCS eC : 100
# RoutePlan.cz : 100
# Register.ca Mobile : 100
# MiAI (Artificial Intelligence) Assistant : 100
# Mat|r viewer : 100
# K-App Mitarbeiter Galeria Kaufhof : 100
# J. Polep Plus Mobile : 100
# Fort Myers FL : 100
# ES Billing System (Offline App) : 100
# EP Home Energy Hub : 100
# EG : 100
# EF Staff : 100
# DG Users : 100
# DF-Server Mobile : 100
# Cx Wize : 100
# CJ'S TIRE AND AUTO INC. : 100
# CI Time : 100
# CI Remote for Go : 100
# CI CAFETERIAS UBER : 100
# Builder (by Engineer.ai) : 100
# BW-IVMS : 100
# BV Mobile Apps : 100
# Ag Trucking Mobile App : 100
# Ag Guardian : 100
# My Ag Report : 50
# MY GULFPORT FL : 50
# EY Team Connect : 50
# EB Scanner : 50
# CX Summit : 50
# CT CONNECT : 50
# CONNECT: The Mobile CX Summit : 50
# CE SODEXO PASS FRANCE : 50
# BN DB1 App : 50
# BAMMS for BM 1Park : 50
# SKIN BK : 10
# PLMGSS FR : 10
# My CG : 10
# MinT BI : 10
# EU Brazil Green Business Forum : 10
# ER Assist : 10
# EP Cloud : 10
# EI! : 10
# EC QR : 10
# DV Web Design Tips : 10
# CQ Ukraine : 10
# BW t&t : 10
# BW Ultra : 10
# BN Inscript Improved Keyboard : 10
# BN Inscript Improved Input keyboard : 10
# BM Interventi : 10
# BAMMS for BM SQ : 10
# AQ Guards : 10
# APagri CD : 10
# ACCEPT CE MARKING : 10
# Shaggy's DM Assistant : 5
# FK Events : 5
# EC Sampler : 1
# DZ Register : 1
# DT Freight : 1
# CQ Electrical Group : 1

# %% [markdown]
# We have discussed possiblites for app designs that we could look into for development that incorporate aspects from the most popular genres, but target genres where there is potential growth and profitability. As directly targeting the markets of the most popular genres would most likely prove to be fruitless as we would be up against much larger and more numerous competitors, where in some genres they have an almost monopolistic control of the market.
#
# As disscussed earlier in the project, as part of our aims we want to develop an app that can be profitable across both the Google Play Store and the App Store. When conducting our analysis for the App Store we found the genres most promising were:
# * Book
# * Education
# * Productivity
# * Sports
#
# As we have now established the genres best to target for the App Store, we will now use those insights to look for genres for potential app profiles on the Google Play Store. The ones that look most promising at a glance to develop a cross-store app are:
# * COMICS
# * EDUCATION
# * FAMILY
# * SPORTS
# * BOOKS_AND_REFERENCE
# * PRODUCTIVITY
#
# We will investigate these specific genres and discuss them below. As we have covered ideas for potential app profiles with data from the App Store we will

# %%
print(go_bold_red('COMICS')) 
sort_table_desc(installs_per_app('COMICS'))
print(go_bold_red('EDUCATION')) 
sort_table_desc(installs_per_app('EDUCATION'))
print(go_bold_red('FAMILY')) 
sort_table_desc(installs_per_app('FAMILY'))
print(go_bold_red('SPORTS')) 
sort_table_desc(installs_per_app('SPORTS'))
print(go_bold_red('BOOKS_AND_REFERENCE')) 
sort_table_desc(installs_per_app('BOOKS_AND_REFERENCE'))
print(go_bold_red('PRODUCTIVITY')) 
sort_table_desc(installs_per_app('PRODUCTIVITY'))
# Out:
# COMICS
# LINE WEBTOON - Free Comics : 10,000,000
# comico Popular Original Cartoon Updated Everyday Comico : 5,000,000
# Perfect Viewer : 5,000,000
# Narrator's Voice : 5,000,000
# Comics : 5,000,000
# 漫咖 Comics - Manga,Novel and Stories : 1,000,000
# pixiv comic - everyone's manga app : 1,000,000
# WebComics : 1,000,000
# Tapas – Comics, Novels, and Stories : 1,000,000
# Memes Button : 1,000,000
# Marvel Unlimited : 1,000,000
# Manga Zero - Japanese cartoon and comic reader : 1,000,000
# Manga Rock - Best Manga Reader : 1,000,000
# Lezhin Comics - Daily Releases : 1,000,000
# GANMA! - All original stories free of charge for all original comics : 1,000,000
# DC Comics : 1,000,000
# Röhrich Werner Soundboard : 500,000
# Manga Master - Best manga & comic reader : 500,000
# Manga Books : 500,000
# Izneo, Read Manga, Comics & BD : 500,000
# Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game : 500,000
# TappyToon Comics & Webtoons : 100,000
# Q Avatar (Avatar Maker) : 100,000
# Laftel - Watching and Announcing Snooping, Streaming : 100,000
# Faustop Sounds : 100,000
# Emmanuella Funny Videos 2018 : 100,000
# Daily Manga - Comic & Webtoon : 100,000
# Comics Reader : 100,000
# Comic Es - Shojo manga / love comics free of charge ♪ ♪ : 100,000
# Children's cartoons (Mithu-Mina-Raju) : 100,000
# Archie Comics : 100,000
# 【Ranobbe complete free】 Novelba - Free app that you can read and write novels : 50,000
# think Comics : 50,000
# Unicorn Pokez - Color By Number : 50,000
# MangaToon - Comics updated Daily : 50,000
# Manga Net – Best Online Manga Reader : 50,000
# Ba dum tss - Rimshot widget : 50,000
# 2000 AD Comics and Judge Dredd : 50,000
# Truyện Vui Tý Quậy : 10,000
# The Vietnam Story - Fun Stories : 10,000
# Manga-FR - Anime Vostfr : 10,000
# Manga Mania - Best online manga reader : 10,000
# Manga - read Thai translation : 10,000
# Funny Jokes Photos : 10,000
# Dragon Ball Wallpaper - Ringtones : 10,000
# CJ - BR MEMES : 10,000
# Best Wallpapers Backgrounds(100,000+ 4K HD) : 10,000
# - Free Comics - Comic Apps : 10,000
# Superheroes, Marvel, DC, Comics, TV, Movies News : 5,000
# Manga AZ - Manga Comic Reader : 5,000
# Make your Be Like Bill : 5,000
# Funny Jokes and Stories 2018 : 5,000
# Hojiboy Tojiboyev Life Hacks : 1,000
# AF Comics Reader - Free : 100
# Pepsi Cards DC : 50
#
#
# EDUCATION
# Remind: School Communication : 10,000,000
# Quizlet: Learn Languages & Vocab with Flashcards : 10,000,000
# Math Tricks : 10,000,000
# Lumosity: #1 Brain Games & Cognitive Training App : 10,000,000
# Learn languages, grammar & vocabulary with Memrise : 10,000,000
# Learn English with Wlingua : 10,000,000
# Google Classroom : 10,000,000
# ClassDojo : 10,000,000
# Rosetta Stone: Learn to Speak & Read New Languages : 5,000,000
# NeuroNation - Focus and Brain Training : 5,000,000
# Mermaids : 5,000,000
# Learn English Words Free : 5,000,000
# Learn 50 languages : 5,000,000
# Khan Academy : 5,000,000
# HelloTalk — Chat, Speak & Learn Foreign Languages : 5,000,000
# Free english course : 5,000,000
# English with Lingualeo : 5,000,000
# Elevate - Brain Training Games : 5,000,000
# Coursera: Online courses : 5,000,000
# ABC Preschool Free : 5,000,000
# myHomework Student Planner : 1,000,000
# edX - Online Courses by Harvard, MIT & more : 1,000,000
# Udemy - Online Courses : 1,000,000
# Udacity - Lifelong Learning : 1,000,000
# Timetable : 1,000,000
# Thai Handwriting : 1,000,000
# THAI DICT 2018 : 1,000,000
# SoloLearn: Learn to Code for Free : 1,000,000
# Socratic - Math Answers & Homework Help : 1,000,000
# Programming Hub, Learn to code : 1,000,000
# PINKFONG Baby Shark : 1,000,000
# My Study Life - School Planner : 1,000,000
# My Class Schedule: Timetable : 1,000,000
# Memorado - Brain Games : 1,000,000
# Lynda - Online Training Videos : 1,000,000
# LinkedIn Learning: Online Courses to Learn Skills : 1,000,000
# Learn to Speak English : 1,000,000
# Learn programming : 1,000,000
# Learn Spanish - Español : 1,000,000
# Learn SQL : 1,000,000
# Learn JavaScript : 1,000,000
# Learn Java : 1,000,000
# Learn Japanese, Korean, Chinese Offline & Free : 1,000,000
# Learn HTML : 1,000,000
# Learn English with Phrases : 1,000,000
# Learn English with Aco : 1,000,000
# Learn C++ : 1,000,000
# Kanji test · Han search Kanji training (free version) : 1,000,000
# HomeWork : 1,000,000
# Free intellectual training game application | : 1,000,000
# English speaking texts : 1,000,000
# English for beginners : 1,000,000
# CppDroid - C/C++ IDE : 1,000,000
# Chegg Study - Homework Help : 1,000,000
# Cars Coloring Pages : 1,000,000
# Canvas Student : 1,000,000
# C++ Programming : 1,000,000
# C Programming : 1,000,000
# Brilliant : 1,000,000
# Blinkist - Nonfiction Books : 1,000,000
# Babbel – Learn Spanish : 1,000,000
# Study Checker : 500,000
# Speed Reading : 500,000
# Mango Languages: Lovable Language Courses : 500,000
# Lerni. Learn languages. : 500,000
# Learn English for beginners : 500,000
# Kids Mode : 500,000
# Innovative: Learn 34 Languages : 500,000
# GRE Flashcards : 500,000
# Flippy Campus - Buy & sell on campus at a discount : 500,000
# English words application mikan : 500,000
# Dinosaurs Coloring Pages : 500,000
# play2prep: ACT, SAT prep : 100,000
# TeachersPayTeachers : 100,000
# Teacher's Gradebook - Additio : 100,000
# TOEFL Prep & Practice from Magoosh : 100,000
# Socrative Teacher : 100,000
# SAT Test : 100,000
# SAT Flashcards: Prep & Vocabulary : 100,000
# Ready4 SAT (Prep4 SAT) : 100,000
# Ready4 GMAT (Prep4 GMAT) : 100,000
# Magoosh GMAT Prep & Practice : 100,000
# Listen and learn English in seven days : 100,000
# Learn English from Persian: Persian to English : 100,000
# Kids Learn Languages by Mondly : 100,000
# Homework Planner : 100,000
# GRE Prep & Practice by Magoosh : 100,000
# GMAT Math Flashcards : 100,000
# English Communication - Learn English for Chinese (Learn English for Chinese) : 100,000
# EasyBib: Citation Generator : 100,000
# Common Core : 100,000
# Ai La Trieu Phu - ALTP Free : 100,000
# SAT Vocabulary : 50,000
# Next Gen Science Standards : 50,000
# Japanese / English one-shop search dictionary - Free Japanese - English - Japanese dictionary application : 50,000
# GRE® Flashcards by Kaplan : 50,000
# GRE Tutor : 50,000
# C++ Tutorials : 50,000
# Training schedule - AllUniver : 10,000
# Quiz&Learn Python : 10,000
# Pocket SAT Math : 10,000
# Pocket GMAT Math : 10,000
# GMAT Question Bank : 10,000
#
#
# FAMILY
# Google Play Games : 1,000,000,000
# Where's My Water? Free : 100,000,000
# Tom Loves Angela : 100,000,000
# Talking Tom Cat 2 : 100,000,000
# Talking Tom Cat : 100,000,000
# Talking Tom & Ben News : 100,000,000
# Talking Ginger : 100,000,000
# ROBLOX : 100,000,000
# Minion Rush: Despicable Me Official Game : 100,000,000
# Hay Day : 100,000,000
# Farm Heroes Saga : 100,000,000
# Duolingo: Learn Languages Free : 100,000,000
# Bubble Witch 2 Saga : 100,000,000
# Bitmoji – Your Personal Emoji : 100,000,000
# aa : 50,000,000
# YouTube Kids : 50,000,000
# Voice changer with effects : 50,000,000
# Vegas Crime Simulator : 50,000,000
# Turbo FAST : 50,000,000
# Township : 50,000,000
# Tom's Love Letters : 50,000,000
# Toca Kitchen 2 : 50,000,000
# Talking Tom Bubble Shooter : 50,000,000
# SpongeBob Diner Dash : 50,000,000
# SimCity BuildIt : 50,000,000
# Photo Warp : 50,000,000
# Mobile Strike : 50,000,000
# MY LITTLE PONY: Magic Princess : 50,000,000
# MARVEL Future Fight : 50,000,000
# Last Empire - War Z: Strategy : 50,000,000
# LEGO® Juniors Create & Cruise : 50,000,000
# Hello Kitty Nail Salon : 50,000,000
# Hair Salon - Fun Games : 50,000,000
# Frozen Free Fall : 50,000,000
# Flight Simulator: Fly Plane 3D : 50,000,000
# Five Nights at Freddy's 2 Demo : 50,000,000
# Fart sound pranks : 50,000,000
# Episode - Choose Your Story : 50,000,000
# Dumb Ways to Die 2: The Games : 50,000,000
# Clash of Kings : The King Of Fighters version : 50,000,000
# Castle Clash: Heroes of the Empire US : 50,000,000
# Boom Beach : 50,000,000
# Block! Hexa Puzzle™ : 50,000,000
# Bad Piggies : 50,000,000
# Akinator : 50,000,000
# iFunny :) : 10,000,000
# busuu: Learn Languages - Spanish, English & More : 10,000,000
# Zombie Defense : 10,000,000
# Xray Scanner Prank : 10,000,000
# Xbox : 10,000,000
# Word Search Games in english : 10,000,000
# Weaphones™ Gun Sim Free Vol 1 : 10,000,000
# Voice Changer : 10,000,000
# Vlogger Go Viral - Tuber Game : 10,000,000
# Virtual Families 2 : 10,000,000
# Vimeo : 10,000,000
# V LIVE - Star Live App : 10,000,000
# U-Dictionary: Best English Learning Dictionary : 10,000,000
# Train driving simulator : 10,000,000
# Thomas & Friends: Go Go Thomas : 10,000,000
# The Voice, sing and connect : 10,000,000
# The Tribez: Build a Village : 10,000,000
# The Sims™ Mobile : 10,000,000
# The Simpsons™: Tapped Out : 10,000,000
# TRANSFORMERS: Earth Wars : 10,000,000
# TETRIS : 10,000,000
# TED : 10,000,000
# Sweet Baby Girl - Dream House and Play Time : 10,000,000
# Surprise Eggs : 10,000,000
# Supermarket – Game for Kids : 10,000,000
# Superhero Doctor 2 -ER Surgery : 10,000,000
# Strawberry Shortcake BerryRush : 10,000,000
# Star Wars™: Galaxy of Heroes : 10,000,000
# Star Girl - Fashion, Makeup & Dress Up : 10,000,000
# Star Chart : 10,000,000
# Shopkins World! : 10,000,000
# School of Dragons : 10,000,000
# Scanner Radio - Fire and Police Scanner : 10,000,000
# Sandbox - Color by Number Coloring Pages : 10,000,000
# Real Racing 3 : 10,000,000
# Real DJ Simulator : 10,000,000
# Pregnant Emergency Surgery : 10,000,000
# Police Car Driving Sim : 10,000,000
# Pocket Mortys : 10,000,000
# PlayKids - Educational cartoons and games for kids : 10,000,000
# Plants vs. Zombies™ Heroes : 10,000,000
# Plants vs. Zombies™ 2 : 10,000,000
# Planet of Cubes Survival Craft : 10,000,000
# Piano Kids - Music & Songs : 10,000,000
# PewDiePie's Tuber Simulator : 10,000,000
# Peak – Brain Games & Training : 10,000,000
# PJ Masks: Moonlight Heroes : 10,000,000
# Order & Chaos 2: 3D MMO RPG : 10,000,000
# Operate Now: Hospital : 10,000,000
# OMG Gross Zit - Date Nightmare : 10,000,000
# No.Draw - Colors by Number 2018 : 10,000,000
# No. Color - Color by Number, Number Coloring : 10,000,000
# Ninja Turtles: Legends : 10,000,000
# Nick : 10,000,000
# My Teacher - Classroom Play : 10,000,000
# My Little Pony: Harmony Quest : 10,000,000
# My Horse : 10,000,000
# My Emma :) : 10,000,000
# My Boo - Your Virtual Pet Game : 10,000,000
# Motocross Beach Jumping 3D : 10,000,000
# Millionaire Quiz Free: Be Rich : 10,000,000
# Meme Generator Free : 10,000,000
# MegaN64 (N64 Emulator) : 10,000,000
# Masha and the Bear: House Cleaning Games for Girls : 10,000,000
# Masha and the Bear. Educational Games : 10,000,000
# Masha and the Bear Child Games : 10,000,000
# Masha and Bear: Cooking Dash : 10,000,000
# Maleficent Free Fall : 10,000,000
# Madden NFL Football : 10,000,000
# MadLipz : 10,000,000
# Little Big City 2 : 10,000,000
# Lie Detector Test Prank : 10,000,000
# Lie Detector Prank : 10,000,000
# Learn English Vocabulary - 6,000 Words : 10,000,000
# LEGO® DC Mighty Micros : 10,000,000
# King of Avalon: Dragon Warfare : 10,000,000
# Kids Balloon Pop Game Free 🎈 : 10,000,000
# Kids Animals Jigsaw Puzzles 😄 : 10,000,000
# Inside Out Thought Bubbles : 10,000,000
# Idle Heroes : 10,000,000
# Ice Cream Jump : 10,000,000
# Hulu: Stream TV, Movies & more : 10,000,000
# Hot Wheels: Race Off : 10,000,000
# Heroes of Order & Chaos : 10,000,000
# Hello English: Learn English : 10,000,000
# Hair saloon - Spa salon : 10,000,000
# HBO NOW: Stream TV & Movies : 10,000,000
# HBO GO: Stream with TV Package : 10,000,000
# Gymnastics Superstar - Spin your way to gold! : 10,000,000
# Guns - Shot Sounds : 10,000,000
# Glam Doll Salon - Chic Fashion : 10,000,000
# Gangster Town: Vice District : 10,000,000
# Fun Kid Racing - Motocross : 10,000,000
# Fun Kid Racing : 10,000,000
# Free Fur All – We Bare Bears : 10,000,000
# Farming Simulator 14 : 10,000,000
# Fallout Shelter : 10,000,000
# FaceQ : 10,000,000
# Extreme Motorbike Jump 3D : 10,000,000
# Euro Truck Driver (Simulator) : 10,000,000
# Eternium : 10,000,000
# Escaping the Prison : 10,000,000
# Equestria Girls : 10,000,000
# Empires and Allies : 10,000,000
# Edmodo : 10,000,000
# Dungeon Hunter 5 – Action RPG : 10,000,000
# Dog Run - Pet Dog Simulator : 10,000,000
# Doctor Kids : 10,000,000
# Disney Magic Kingdoms: Build Your Own Magical Park : 10,000,000
# Disney Crossy Road : 10,000,000
# Dinosaur War : 10,000,000
# Design Home : 10,000,000
# DJ Electro Mix Pad : 10,000,000
# DIRECTV : 10,000,000
# DC Legends: Battle for Justice : 10,000,000
# Crazy Doctor : 10,000,000
# Cooking in the Kitchen : 10,000,000
# Cook Baked Lasagna : 10,000,000
# Coloring Book for Me & Mandala : 10,000,000
# Chuck E.'s Skate Universe : 10,000,000
# Cars: Lightning League : 10,000,000
# Card Wars Kingdom : 10,000,000
# Can Knockdown : 10,000,000
# COOKING MAMA Let's Cook! : 10,000,000
# Build a Bridge! : 10,000,000
# Bubbu – My Virtual Pet : 10,000,000
# Boomerang Make and Race : 10,000,000
# Blood Pressure Info : 10,000,000
# Block Puzzle - Wood Legend : 10,000,000
# Block City Wars + skins export : 10,000,000
# Ben 10: Alien Experience : 10,000,000
# Bejeweled Blitz : 10,000,000
# Battle of Zombies: Clans War : 10,000,000
# Barbie™ Fashion Closet : 10,000,000
# Barbie Magical Fashion : 10,000,000
# Bad Piggies HD : 10,000,000
# Baby Panda Care : 10,000,000
# Babbel – Learn Languages : 10,000,000
# Avakin Life - 3D virtual world : 10,000,000
# Angry Birds POP Bubble Shooter : 10,000,000
# Angry Birds Evolution : 10,000,000
# Angry Birds Epic RPG : 10,000,000
# Angry Birds Blast : 10,000,000
# Airplane Pilot Car Transporter : 10,000,000
# ABC Kids - Tracing & Phonics : 10,000,000
# 9GAG: Funny Gifs, Pics, Memes & Videos for IGTV : 10,000,000
# 100 Doors of Revenge : 10,000,000
# Z War-Zombie Modern Combat : 5,000,000
# World at War: WW2 Strategy MMO : 5,000,000
# War Z 2 : 5,000,000
# Virtual Cigarette Smoking (prank) : 5,000,000
# US Army Training Courses Game : 5,000,000
# Transformers Rescue Bots: Hero Adventures : 5,000,000
# Thomas & Friends: Race On! : 5,000,000
# The NBC App - Watch Live TV and Full Episodes : 5,000,000
# The CW : 5,000,000
# TO-FU Oh!SUSHI : 5,000,000
# TETRIS Blitz : 5,000,000
# TAMAGO : 5,000,000
# Sweet Baby Girl Newborn Baby : 5,000,000
# Survival Prison Escape v2: Free Action Game : 5,000,000
# Strawberry Shortcake Ice Cream Island : 5,000,000
# Star Wars™: Force Arena : 5,000,000
# Sport Car Simulator : 5,000,000
# South Park: Phone Destroyer™ : 5,000,000
# Soundtrack Attack : 5,000,000
# Soldiers of Glory: Modern War : 5,000,000
# Sexy Hot Detector Prank : 5,000,000
# S.O.L : Stone of Life EX : 5,000,000
# Rivals at War: 2084 : 5,000,000
# RISK: Global Domination : 5,000,000
# Princess Coloring Book : 5,000,000
# Power Spheres by BoBoiBoy : 5,000,000
# Pokémon TV : 5,000,000
# Palace Pets in Whisker Haven : 5,000,000
# PBS KIDS Video : 5,000,000
# PAC-MAN Pop : 5,000,000
# Offroad Car G : 5,000,000
# Nose Doctor X: Booger Mania : 5,000,000
# No.Color – Color by Number : 5,000,000
# No Pimple - Fun games : 5,000,000
# Narcos: Cartel Wars : 5,000,000
# My Little Pony Rainbow Runners : 5,000,000
# Monster High™ : 5,000,000
# Megatramp - a Story of Success! : 5,000,000
# Masha and The Bear : 5,000,000
# Mahjong : 5,000,000
# MagiMobile – Mighty Magiswords : 5,000,000
# Madagascar Surf n' Slides Free : 5,000,000
# MARVEL Strike Force : 5,000,000
# Left vs Right: Brain Training : 5,000,000
# Learn to Read with Tommy Turtle : 5,000,000
# LINE I Love Coffee : 5,000,000
# Kids Educational Game 3 Free : 5,000,000
# Instant Buttons: The Best Soundboard : 5,000,000
# Hot Bhojpuri Video songs : 5,000,000
# Home Decoration Game : 5,000,000
# Hollywood U: Rising Stars : 5,000,000
# High School Simulator 2017 : 5,000,000
# Hello Kitty Lunchbox : 5,000,000
# Heavy Bus Simulator : 5,000,000
# Hangman : 5,000,000
# Habbo - Virtual World : 5,000,000
# Guns'n'Glory : 5,000,000
# Gun Mod: Guns in Minecraft PE : 5,000,000
# Grand Theft Auto V: The Manual : 5,000,000
# Google Arts & Culture : 5,000,000
# Girls Craft: Exploration : 5,000,000
# Ghost Detector : 5,000,000
# Galaxy Defense : 5,000,000
# Free games: Masha and the Bear : 5,000,000
# Fire Emblem Heroes : 5,000,000
# FeaturePoints: Free Gift Cards : 5,000,000
# Family Guy- Another Freakin' Mobile Game : 5,000,000
# FANDOM for: GTA : 5,000,000
# Eventbrite - Discover popular events & nearby fun : 5,000,000
# Escape the Prison Room : 5,000,000
# English Grammar Test : 5,000,000
# Empire Z: Endless War : 5,000,000
# Egg, Inc. : 5,000,000
# Egg for Pou : 5,000,000
# Egg Baby : 5,000,000
# Educational Games 4 Kids : 5,000,000
# Dungeon Quest : 5,000,000
# Dungeon Boss – Strategy RPG : 5,000,000
# Dragon Sim Online: Be A Dragon : 5,000,000
# Dog Sim Online: Raise a Family : 5,000,000
# DisneyNOW – TV Shows & Games : 5,000,000
# Darkness Rises : 5,000,000
# DJ Music Pad : 5,000,000
# DC Super Hero Girls™ : 5,000,000
# Crusaders Quest : 5,000,000
# Coloring & Learn : 5,000,000
# Cat Sim Online: Play with Cats : 5,000,000
# Castle Clash: Epic Empire ES : 5,000,000
# Cartoon Wars 3 : 5,000,000
# Car Parking Game 3D - Real City Driving Challenge : 5,000,000
# Cake Shop - Kids Cooking : 5,000,000
# Bus Driver 3D: Hill Station : 5,000,000
# Bubble Bird Rescue : 5,000,000
# Bridge Constructor Playground FREE : 5,000,000
# Bejeweled Classic : 5,000,000
# Barbie Life™ : 5,000,000
# Baby puzzles : 5,000,000
# Baby Panda’s Juice Shop : 5,000,000
# Ayat - Al Quran : 5,000,000
# Anime Love Story Games: ✨Shadowtime✨ : 5,000,000
# Animal Jam - Play Wild! : 5,000,000
# Angry Shark 2016 : 5,000,000
# Angry Birds Match : 5,000,000
# Amazing Fart Sounds : 5,000,000
# ABCmouse.com : 5,000,000
# ABC – Live TV & Full Episodes : 5,000,000
# 3D Holograms Joke : 5,000,000
# 【Miku AR Camera】Mikuture : 1,000,000
# yHomework - Math Solver : 1,000,000
# el : 1,000,000
# au : 1,000,000
# ao : 1,000,000
# [adult swim] : 1,000,000
# Z Day: Hearts of Heroes : 1,000,000
# YouTube TV - Watch & Record Live TV : 1,000,000
# X-Plane 10 Flight Simulator : 1,000,000
# What's Your Story?™ ft Charmed : 1,000,000
# What was I in my Past Life : 1,000,000
# Weapon stripping 3D : 1,000,000
# We Bare Bears Match3 Repairs : 1,000,000
# Virtual lover : 1,000,000
# Virtual Assistant DataBot: Artificial Intelligence : 1,000,000
# Urban Car Simulator : 1,000,000
# Ultimate Clash Royale Tracker : 1,000,000
# Tunnel Town : 1,000,000
# Triceratops - Dino Robot : 1,000,000
# Transformers Rescue Bots: Disaster Dash : 1,000,000
# Toy Pop Cubes : 1,000,000
# Touch Racing 2 - Mini RC Race : 1,000,000
# Toddler Kids Puzzles PUZZINGO : 1,000,000
# Tiny Defense : 1,000,000
# Tic Tac Toe : 1,000,000
# Thuglife Video Maker : 1,000,000
# Thomas & Friends: Delivery : 1,000,000
# The Grand Bike V : 1,000,000
# Talking Husky Dog : 1,000,000
# TAXI DRIVER : 1,000,000
# Sword Art Online: Integral Factor : 1,000,000
# Survival Forest : Survivor Home Builder : 1,000,000
# Surely You Quest - Magiswords : 1,000,000
# Supermarket Manager: Cashier Simulator Kids Games : 1,000,000
# Supermarket Cashier Kids Games : 1,000,000
# SuperCity: Build a Story : 1,000,000
# Super Sport Car Simulator : 1,000,000
# Super Dr. Parking 3D : 1,000,000
# Super ABC! Learning games for kids! Preschool apps : 1,000,000
# Subway Simulator 3D : 1,000,000
# Starfall Free & Member : 1,000,000
# Sounds for Toddlers FREE : 1,000,000
# Snoopy's Town Tale - City Building Simulator : 1,000,000
# Seen : 1,000,000
# Sandbox Number Coloring Book Art - Color By Number : 1,000,000
# Sandbox Art-Sandbox Color by Number Coloring Pages : 1,000,000
# San Andreas Crime City Gangster 3D : 1,000,000
# Sago Mini Friends : 1,000,000
# SW Battlefront Companion : 1,000,000
# RightNow English Conversation : 1,000,000
# Resources For Virtual DJ : 1,000,000
# Replika : 1,000,000
# Red Bull TV: Live Sports, Music & Entertainment : 1,000,000
# Real Car Dr Parking Master: Parking Games 2018 : 1,000,000
# Real Airplane Flight Simulator: Pilot Games : 1,000,000
# Read Unlimitedly! Kids'n Books : 1,000,000
# Questland: Turn Based RPG : 1,000,000
# Q : 1,000,000
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles : 1,000,000
# Pu - Cute giant panda bear, baby pet care game : 1,000,000
# Princess Palace: Royal Pony : 1,000,000
# Princess Closet : Otome games free dating sim : 1,000,000
# Preschool All-In-One : 1,000,000
# Pocket Little Pony : 1,000,000
# Pocket Heroes : 1,000,000
# Plants vs. Zombies™ Watch Face : 1,000,000
# PixelDot - Color by Number Sandbox Pixel Art : 1,000,000
# PixPanda - Color by Number Pixel Art Coloring Book : 1,000,000
# PixBox Coloring - Color by number Sandbox : 1,000,000
# Pet Vet Dr - Animals Hospital : 1,000,000
# Pet Beauty Salon : 1,000,000
# Paw Patrol by ShuffleCards : 1,000,000
# PS4 Second Screen : 1,000,000
# POGO Games : 1,000,000
# PJ Masks: HQ : 1,000,000
# PBS KIDS Games : 1,000,000
# Orbita AI — Exciting mobile puzzles & riddles : 1,000,000
# Offroad Police Car DE : 1,000,000
# Offroad Pickup Truck S : 1,000,000
# Offroad Pickup Truck R : 1,000,000
# Offroad Cruiser : 1,000,000
# Offroad Car Q : 1,000,000
# Offroad 4x4 Car Driving : 1,000,000
# Office Bike Racing Simulator : 1,000,000
# OK K.O.! Lakewood Plaza Turbo : 1,000,000
# Number Counting games for toddler preschool kids : 1,000,000
# No.Diamond – Colors by Number : 1,000,000
# Nights at Cube Pizzeria 3D – 3 : 1,000,000
# Nasty Goats : 1,000,000
# My Tamagotchi Forever : 1,000,000
# My Oasis - Calming and Relaxing Idle Clicker Game : 1,000,000
# My Little Pony: Story Creator : 1,000,000
# My Little Pony Celebration : 1,000,000
# Motocross Fun Simulator : 1,000,000
# Monster Truck Driver & Racing : 1,000,000
# Monster High™ Minis Mania : 1,000,000
# Moana Island Life : 1,000,000
# Masha and the Bear: Good Night! : 1,000,000
# Masha and the Bear: Climb Racing and Car Games : 1,000,000
# Masha and the Bear. Games for kids : 1,000,000
# Masha and the Bear : 1,000,000
# Masha and The Bear Puzzle Game : 1,000,000
# Masha and The Bear Jam Day Match 3 games for kids : 1,000,000
# MapleStory M : 1,000,000
# Mad Libs : 1,000,000
# MLP Colouring Adventures : 1,000,000
# Luxury Car Simulator : 1,000,000
# Little Panda Run : 1,000,000
# Little Lovely Dentist : 1,000,000
# Little Fire Station : 1,000,000
# Lily & Leo - Crazy Circus Day : 1,000,000
# Leo and Tig : 1,000,000
# Legion of Heroes : 1,000,000
# Learn to code with el Chavo : 1,000,000
# Learn Top 300 English Words : 1,000,000
# Learn To Draw Glow Princess : 1,000,000
# Learn To Draw Glow Flower : 1,000,000
# Learn Body Parts in English : 1,000,000
# LEGO® TV : 1,000,000
# LEGO® Friends: Heartlake Rush : 1,000,000
# L.O.L. Surprise Ball Pop : 1,000,000
# Knights N Squires : 1,000,000
# Kingdoms at War: Hardcore PVP : 1,000,000
# Kids A-Z : 1,000,000
# Jewels Crush- Match 3 Puzzle : 1,000,000
# Jagobd - Bangla TV(Official) : 1,000,000
# I LOVE PASTA : 1,000,000
# How Old am I? : 1,000,000
# Home Pony 2 : 1,000,000
# Holy Knight EN : 1,000,000
# Henry Danger Crime Warp : 1,000,000
# Happy Street : 1,000,000
# Hands 'n Guns Simulator : 1,000,000
# Gun Disassembly 2 : 1,000,000
# Guardian Hunter: SuperBrawlRPG : 1,000,000
# Grow Stone Online : 2d pixel RPG, MMORPG game : 1,000,000
# Go-Go-Goat! Free Game : 1,000,000
# Garden Fever - Free! : 1,000,000
# Game for KIDS: KIDS match'em : 1,000,000
# Galaxy at War Online : 1,000,000
# Fruit Boom : 1,000,000
# French to English Speaking - Apprendre l' Anglais : 1,000,000
# Freeform – Stream Full Episodes, Movies, & Live TV : 1,000,000
# Flight Simulator X 2016 Free : 1,000,000
# Five nights at Minecraft : 1,000,000
# Five Tries At Love Dating Sim : 1,000,000
# Fat No More - Be the Biggest Loser in the Gym! : 1,000,000
# Fandom: Five Nights at Freddys : 1,000,000
# Fairy Kingdom: World of Magic and Farming : 1,000,000
# FXNOW: Movies, Shows & Live TV : 1,000,000
# FD VR Theater - for Youtube VR : 1,000,000
# Eye Transplant : ER Emergency Hospital : 1,000,000
# Exiled Kingdoms RPG : 1,000,000
# Evolution: Battle for Utopia : 1,000,000
# Ever After High™ Charmed Style : 1,000,000
# English in a Month Free : 1,000,000
# English Conversation Courses : 1,000,000
# English Audio Books - Librivox : 1,000,000
# Elmo Calls by Sesame Street : 1,000,000
# Electric Car Taxi Driver: NY City Cab Taxi Games : 1,000,000
# El Laberinto del Demonio 3D : 1,000,000
# El Falı : 1,000,000
# Egg: clicker : 1,000,000
# Educational Games for Kids : 1,000,000
# Earth to Luna! Watch and Play : 1,000,000
# EZ PZ RPG : 1,000,000
# EXO-L : 1,000,000
# ER Surgery Simulator : 1,000,000
# ER Injection Simulator: Blood Test Doctor Hospital : 1,000,000
# Dungeon Rush : 1,000,000
# Dungeon Legends - PvP Action MMO RPG Co-op Games : 1,000,000
# Dungeon Hunter Champions: Epic Online Action RPG : 1,000,000
# Drawing for Kids Learning Games for Toddlers age 3 : 1,000,000
# Draw.ly - Color by Number Pixel Art Coloring : 1,000,000
# Draw Color by Number - Sandbox Pixel Art : 1,000,000
# Dr. Unblock : 1,000,000
# Dr. Panda Town: Vacation : 1,000,000
# Dr. Panda Town : 1,000,000
# Dr. Panda Restaurant 3 : 1,000,000
# Dr. Panda Ice Cream Truck Free : 1,000,000
# Dr. Panda Café Freemium : 1,000,000
# Downtown Mafia: Gang Wars (Mobster Game) Free : 1,000,000
# Download Video Free : 1,000,000
# Dots & Co: A Puzzle Adventure : 1,000,000
# Doomsday Preppers™ : 1,000,000
# Dominos Game ✔️ : 1,000,000
# Doctor X - ER On Wheels : 1,000,000
# Doctor Pets : 1,000,000
# Do Not Disturb! 2 - Challenge Your Prank Skills! : 1,000,000
# Do Not Crash : 1,000,000
# Disney Princess Palace Pets : 1,000,000
# Disney Magic Timer by Oral-B : 1,000,000
# Discovery K!ds Play! Español : 1,000,000
# Discovery K!ds Play! : 1,000,000
# Disaster Will Strike : 1,000,000
# Dino in City-Dinosaur N Police : 1,000,000
# Death Dragon Knights RPG : 1,000,000
# Dance School Stories - Dance Dreams Come True : 1,000,000
# Dance On Mobile : 1,000,000
# DJ Mix Effects Simulator : 1,000,000
# DIRECTV for Tablets : 1,000,000
# DIRECTV Remote App : 1,000,000
# Cymath - Math Problem Solver : 1,000,000
# Cute Pet Puppies : 1,000,000
# Cursive Writing Wizard - Handwriting : 1,000,000
# Curio Quest : 1,000,000
# Crack Attack : 1,000,000
# Connect'Em : 1,000,000
# Color by Number: Pixel Art : 1,000,000
# Color by Number - Draw Sandbox Pixel Art : 1,000,000
# Color By Number - Sandbox Pixel Coloring Book : 1,000,000
# Codes for GTA San Andreas : 1,000,000
# Club Penguin Island : 1,000,000
# City Taxi Driver sim 2016: Cab simulator Game-s : 1,000,000
# City Builder 2016: County Mall : 1,000,000
# Chest Calculator for CR : 1,000,000
# Checkers ✔️ : 1,000,000
# Champions and Challengers - Adventure Time : 1,000,000
# Castle Defense 2 : 1,000,000
# Castle Clash: RPG War and Strategy FR : 1,000,000
# Cartoon Network Match Land : 1,000,000
# Candy Smash : 1,000,000
# Candy Pop Story : 1,000,000
# Candy Day : 1,000,000
# Can Your Pet? : Returns - Teen : 1,000,000
# CA Lottery Official App : 1,000,000
# Burrito Bash – We Bare Bears : 1,000,000
# Builder Craft: House Building & Exploration : 1,000,000
# Bu the Baby Bunny - Cute pet care game : 1,000,000
# Broken Screen Prank : 1,000,000
# Bridge Constructor Stunts FREE : 1,000,000
# Boomerang : 1,000,000
# Body scanner (prank) : 1,000,000
# Blamburger - Clarence : 1,000,000
# Black Survival : 1,000,000
# Best DP and Status (Daily Updates Photos) : 1,000,000
# Bejeweled Stars: Free Match 3 : 1,000,000
# Bedouin Rivals : 1,000,000
# Beauty and the Beast : 1,000,000
# Batman: Gotham’s Most Wanted! : 1,000,000
# Baby ABC in box! Kids alphabet games for toddlers! : 1,000,000
# BDCast - Bangla Live TV,Radio : 1,000,000
# Aurum Blade EX : 1,000,000
# Assemblr - Create 3D Models (Sandbox AR) : 1,000,000
# Army of Heroes : 1,000,000
# Anno: Build an Empire : 1,000,000
# Ankle Surgery ER Emergency : 1,000,000
# Ambulance Simulator 3D : 1,000,000
# Ambulance Rescue Simulator 17 : 1,000,000
# Al Quran MP3 - Quran Reading® : 1,000,000
# Al Quran Audio (Full 30 Juz) : 1,000,000
# Airplane Fly Hawaii : 1,000,000
# AdventureQuest 3D MMO : 1,000,000
# AT&T U-verse : 1,000,000
# AMC : 1,000,000
# A&E - Watch Full Episodes of TV Shows : 1,000,000
# A Call From Santa Claus! : 1,000,000
# 3D DJ – DJ Mixer 2018 : 1,000,000
# codeSpark Academy & The Foos : 500,000
# ci : 500,000
# ba : 500,000
# Xtreme Racing 2018 - Jeep & 4x4 off road simulator : 500,000
# X-ray scanner simulator : 500,000
# Wolfify - Be a Werewolf : 500,000
# V for Vampire - Free : 500,000
# UNICORN - Color By Number & Pixel Art Coloring : 500,000
# Toy Guitar with songs for kids : 500,000
# The X-Files: Deep State - Hidden Object Adventure : 500,000
# Survival Mobile:10,000 BC : 500,000
# Superhero Doctor 3 ER Surgery : 500,000
# Super Slime Blitz - Gumball : 500,000
# Super School: Educational Kids Games & Rhymes : 500,000
# Smart-AC Universal Remote Free : 500,000
# Sirens Fashion Style Game : 500,000
# Shoot Em Down Free : 500,000
# Scary Video Maker : 500,000
# SYFY : 500,000
# RPG End of Aspiration F : 500,000
# R. Physics Puzzle Game : 500,000
# Princess Adventures Puzzles : 500,000
# Police VAZ LADA Simulator : 500,000
# PokeType - Dex : 500,000
# Plastic Surgery Surgeon Simulator Er Doctor Games : 500,000
# Pixyfy: coloring by number coloring book : 500,000
# Pixelmania - Color by number & create pixel art : 500,000
# Paint By Number : 500,000
# Offroad Pickup Truck F : 500,000
# Offroad G-Class 2018 : 500,000
# OffRoad US Army Train Driving Simulator : 500,000
# OST) : 500,000
# Nuke Em All : 500,000
# Ninja Dash - Ronin Jump RPG : 500,000
# My Wild Pet: Online Animal Sim : 500,000
# My Ex Girlfriend Comes Back : 500,000
# Mosaic puzzles : 500,000
# Monica Toy TV : 500,000
# Mod GTA V for MCPE : 500,000
# Messenger Kids – Safer Messaging and Video Chat : 500,000
# Math games for kids : times tables - AB Math : 500,000
# Masha and the Bear: Evolution : 500,000
# Marked by King Bs : 500,000
# Ludo Family Dice Game : 500,000
# Like A Boss : 500,000
# Learn English Daily : 500,000
# Kids Educational :All in One : 500,000
# Kids Corner: Interactive Tales and Games for kids : 500,000
# JW Caleb y Sofia : 500,000
# I am Nose Doctor -Save my Nose : 500,000
# Hungry Hearts Diner: A Tale of Star-Crossed Souls : 500,000
# Helper for Clash Royale (All-in-1) : 500,000
# Heart Surgery Doctor - ER Emergency Game : 500,000
# Happy Fruits Bomb - Cube Blast : 500,000
# Hallmark Channel Everywhere : 500,000
# Guide for CS:GO : 500,000
# Glitter Color By Number - Glitter Number Coloring : 500,000
# German Listening : 500,000
# Garden Fruit Legend : 500,000
# Fruit Cube Blast : 500,000
# Food Network : 500,000
# Find a Way: Addictive Puzzle : 500,000
# Fantastic Chefs: Match 'n Cook : 500,000
# FJ 4x4 Cruiser Snow Driving : 500,000
# FJ 4x4 Cruiser Offroad Driving : 500,000
# FD VR Player - for Youtube 3D : 500,000
# FANDOM for: DC : 500,000
# Extreme Racing 2 - Real driving RC cars game! : 500,000
# Evolution CP & IV Calculator for pokemon : 500,000
# Endless Numbers : 500,000
# ER Doctor Kids Emergency Room : 500,000
# ENCHANT U : 500,000
# E-cigarette for free : 500,000
# Dungeon Keeper : 500,000
# Driving School 3D 2017 : 500,000
# Dr. Sudoku : 500,000
# Dr. Cares - Pet Rescue 911 🐶 : 500,000
# Dr. 2048 : 500,000
# Dolphin and fish coloring book : 500,000
# Desperate Housewives: The Game : 500,000
# DP & Status : 500,000
# DC All Access : 500,000
# DB Train Simulator : 500,000
# Cutie Cubies : 500,000
# Create A Superhero HD : 500,000
# Crazy ER Open Heart Surgery Simulator : 500,000
# Connect'Em Halloween : 500,000
# Coloring book moana : 500,000
# Color by Disney : 500,000
# Case Simulator Hero for CS:GO : 500,000
# CW Seed : 500,000
# CR & CoC Private Server - Clash Barbarians PRO : 500,000
# Block Survival Craft:The Story : 500,000
# Best Friends Dress Up & Makeup : 500,000
# Battle Gems (AdventureQuest) : 500,000
# Axe Clicker : 500,000
# All Type DP : 500,000
# Advanced calculator fx 991 es plus & 991 ms plus : 500,000
# Adult Color By Number Book: Number Coloring Pages : 500,000
# Across Age DX : 500,000
# AT&T THANKS® : 500,000
# AK-47 Sounds : 500,000
# A Word A Day : 500,000
# 3D Color by Number with Voxels : 500,000
# virtual lover 3D : 100,000
# iTooch Mathématiques CP : 100,000
# fi : 100,000
# do : 100,000
# Zapzapmath: K-6 Math Games : 100,000
# Z City : 100,000
# Yaoi Ooku: Distorted Love : 100,000
# XCOM: TBG : 100,000
# X-Wing Squadron Builder : 100,000
# Wrecker's Revenge - Gumball : 100,000
# World History Quick e-Book : 100,000
# Wonder5 Masters R : 100,000
# Wii U Simulator : 100,000
# WiFi FPV : 100,000
# Who viewed my fb profile pro★★ : 100,000
# What's Up, Snoopy? - Peanuts : 100,000
# Water Surfer Floating BMX Bicycle Rider Racing : 100,000
# Virtual Mom Surgery Doctor : ER Emergency Hospital : 100,000
# Valentines love color by number-Pixel art coloring : 100,000
# U-Disco : 100,000
# U-Craft Mobile : 100,000
# Truck Transport Raw Material : 100,000
# Treasure Hunt Hidden Objects Adventure Game : 100,000
# Treasure Defense : 100,000
# Toddler Learning Games - Little Kids Games : 100,000
# Throw Knife : 100,000
# The Noise-O-Meter : 100,000
# The Aether: Life as a God : 100,000
# Tee and Mo Bath Time Free : 100,000
# TeamWard – live help for LoL : 100,000
# Tattoo Color By Number Draw Book Page Pixel Art : 100,000
# Talking Boyfriend : 100,000
# Sworkit Kids - Fitness Meets Fun : 100,000
# Spider grinder in screen funny : 100,000
# Smokes for CS:GO : 100,000
# Sleeping Delivery : 100,000
# Skylink Live TV CZ : 100,000
# Sight Words Pre-K to Grade-3 : 100,000
# SegPlay Mobile Paint by Number : 100,000
# School scientific calculator fx 500 es plus 500 ms : 100,000
# Scanning under clothes (prank) : 100,000
# Scanning body and undressing people : 100,000
# Sabbath School 4 : 100,000
# STUCOR - AU : 100,000
# SAY-U : 100,000
# Robots Vs Zombies: Transform To Race And Fight : 100,000
# Rized ‼️ Color By Number & Pixel Coloring Book : 100,000
# Rhythm Patrol : 100,000
# Rabbithole : 100,000
# RPG Dragon Lapis : 100,000
# REV Robotic Enhance Vehicles : 100,000
# R. Lee Ermey's Official Sound : 100,000
# Quran for All (Al-Huda Int.) : 100,000
# Quran Juz-30 - Mahad al Zahra : 100,000
# Quiz for Clash Royale™ : 100,000
# Poly Art: Paint by Sticker, Color by Number Puzzle : 100,000
# Pixel art pro-Sand box,paint by number,number draw : 100,000
# PeopleTV - Watch Celebrity News : 100,000
# Papumba Academy - Fun Learning For Kids : 100,000
# OurHome – chores, rewards, groceries and calendar : 100,000
# Offroad Car H : 100,000
# OWLIE BOO : 100,000
# O-Level Past Papers & Solution (up to 2017) : 100,000
# Myth Defense 2: DF : 100,000
# My Handbook : EE, EC, EI, E&T, EEE, EECS : 100,000
# My EF : 100,000
# Montessori Preschool : 100,000
# Mobile C [ C/C++ Compiler ] : 100,000
# Mcqueen Coloring pages : 100,000
# Math Solver : 100,000
# Masterchef Cooking Games: Fun Restaurant & Kitchen : 100,000
# Marathi DP - status and message,jokes,Video app : 100,000
# Lux Home Decorating Room Games : 100,000
# Loved by King Bs : 100,000
# Lottery Results: Florida : 100,000
# Little Pets Animal Guardians : 100,000
# Lire avec Sami et Julie : 100,000
# Lifeguard Beach Rescue ER Emergency Hospital Games : 100,000
# Lettre et demande d'emploi : 100,000
# Lettre de motivation et CV : 100,000
# Learners Test Free: AU Driver Knowledge Test (DKT) : 100,000
# Learn Math with el Chavo : 100,000
# Learn English with El Chavo. : 100,000
# Learn C# - .Net - C Sharp Programming Tutorial App : 100,000
# Kpop Music Quiz (K-pop Game) : 100,000
# Korean English Translator : 100,000
# Kingdom in Chaos : 100,000
# Kids Doctor ER Emergency Rescue Kids Hospital Game : 100,000
# KISW 99.9 FM SEATTLE : 100,000
# Just a Line - Draw Anywhere, with AR : 100,000
# Job CV Maker & Portfolio Maker : 100,000
# Je Parle ANGLAIS - Apprendre l’anglais Audio cours : 100,000
# J-UFO : 100,000
# I am Dentist - Save my Teeth : 100,000
# I Am Wizard : 100,000
# How it works: AK-74N : 100,000
# Hot Bhojpuri Video Song 2018 - Free Movies : 100,000
# Hospital ER Emergency Heart Surgery: Doctor Games : 100,000
# Heart Surgery Emergency Doctor : 100,000
# Halloween Sandbox Number Coloring- Color By Number : 100,000
# Gods Wars Ex : Vampire : 100,000
# German Vocabulary Trainer : 100,000
# Gaydorado : 100,000
# GT-R R35 Drift Simulator : 100,000
# Fuzzy Seasons: Animal Forest : 100,000
# FunnyPixels - Color by number Sandbox : 100,000
# Funny Jokes : 100,000
# Foot Surgery Hospital Simulator: ER Doctor Games : 100,000
# Filmi Gaane : 100,000
# Fifth Edition DM Tools : 100,000
# FML F*ck my life + widget : 100,000
# FD VR Video Player - (Stored) : 100,000
# FD VR - Virtual Reality Camera : 100,000
# FD VR - Virtual 3D Web Browser : 100,000
# FANDOM: Arrow and The Flash : 100,000
# Explora con el Chavo : 100,000
# European War 5:Empire : 100,000
# Esto Es Guerra TVN : 100,000
# Em Fuga Brasil : 100,000
# Elifba Quran Learning Game : 100,000
# Elevator Simulator Lift EM ALL : 100,000
# El Laberinto del Demonio 2 : 100,000
# Eh Volevi! : 100,000
# Educationboard Results BD : 100,000
# ES Remote : 100,000
# ER Hospital Simulator : 100,000
# ER Heart Surgery - Emergency Simulator Game : 100,000
# ER Doctor City Emergency - Surgery City Doc FREE : 100,000
# EF English Live for phone : 100,000
# EF English Live Business : 100,000
# E! : 100,000
# Dual N-Back - Brain game : 100,000
# Du Chinese – Mandarin Lessons : 100,000
# DrivingTest : 100,000
# DreamWorks Friends : 100,000
# Dragon Nest M : 100,000
# Dr. Truck Driver : Real Truck Simulator 3D : 100,000
# Dr. Pixel: Pill mania Classic : 100,000
# Dr. Cares - Amy's Pet Clinic 🐈 🐕 : 100,000
# Doll House Design & Decoration 2: Girls House Game : 100,000
# Differential Equations Steps : 100,000
# Dentist Surgery ER Emergency Doctor Hospital Games : 100,000
# Denis Brogniart - AH ! : 100,000
# Deck Shop for Clash Royale : 100,000
# DataCamp - Learn R, Python & SQL : 100,000
# Dash Tag - Fun Endless Runner! : 100,000
# Dance Magic Fashion Style Games : 100,000
# DW Learn German - A1, A2, B1 and placement test : 100,000
# DP and Status : 100,000
# DO YOU KNOW THE WAY Soundboard : 100,000
# DB for Fallout Shelter : 100,000
# Cute Images for Whatsapp : 100,000
# Crazy Colors: Bubbles Matching : 100,000
# Companion for Fortnite & Fortnite Battle Royale : 100,000
# Coloring Book at Five Nights : 100,000
# Color By Numbers - Art Game for Kids and Adults : 100,000
# Clumsy Santa ER Surgery : 100,000
# Classic FC 64 IN 1 : 100,000
# Citation du Jour - Motivation : 100,000
# Chest Simulator for Clash Royale : 100,000
# Chess for Kids - Play & Learn : 100,000
# Chess School for Beginners : 100,000
# Chess PRO Free : 100,000
# Cheats for GTA V : 100,000
# Cheat Codes for GTA V : 100,000
# ChatBot AI Talking Girl : 100,000
# ChatBolo - AI Chatbot Online : 100,000
# Castle Defense : Invasion : 100,000
# Cardinal Quest 2 : 100,000
# Car Racing game for Kids - Beepzz Dogs 🐕 : 100,000
# Car Parking Nissan GT-R R35 Simulator : 100,000
# CX-10WiFi : 100,000
# CV Formats 2018 : 100,000
# CV Examples 2018 : 100,000
# CP RACING 2 FREE : 100,000
# CN Summer Challenge : 100,000
# CK FFXIV Companion : 100,000
# C-SPAN Radio : 100,000
# C Programming - Learn Code, Theory & Discuss : 100,000
# C Pattern Programs Free : 100,000
# Butterfly Pixel Art - coloring by number : 100,000
# Bubble Shooter DX : 100,000
# Blagues et Histoires Drôles : 100,000
# Bita and the Animals - Pelos Ares : 100,000
# Beauty Rental Shop : 100,000
# Be My Princess: PARTY : 100,000
# Be My Princess 2 : 100,000
# Be My Princess : 100,000
# Batmobile™ R/C Controller : 100,000
# Basketball FRVR - Shoot the Hoop and Slam Dunk! : 100,000
# Baby Tiger Care - My Cute Virtual Pet Friend : 100,000
# BF 3d Wallpapers : 100,000
# Avenger Legends : 100,000
# Art Pixel Coloring. Color by Number. : 100,000
# Arabic Alif Ba Ta For Kids : 100,000
# Alphabet A-Z : 100,000
# All C Programs : 100,000
# Alchemy Classic Ad Free : 100,000
# Al-Quran Ahmad Saud Offline : 100,000
# Al jazeera TV : 100,000
# Ah! Monster : 100,000
# Agent HQ for The Division : 100,000
# Age of Procreation DX : 100,000
# AdventureQuest Dragons : 100,000
# Adventure Xpress : 100,000
# Advanced Warfare Guns : 100,000
# Adult Color by Number Book - Paint Mandala Pages : 100,000
# AU Results 2017 Auzone : 100,000
# AU Results - AU COE Corner : 100,000
# AR Remote Car : 100,000
# AK-47: Simulator and Shooting : 100,000
# AG Subway Simulator Lite : 100,000
# AE Sudoku : 100,000
# AE Roundy POP : 100,000
# AE Bubble:Offline Bubble Games : 100,000
# AC Remote Control Simulator : 100,000
# AC REMOTE UNIVERSAL-PRO : 100,000
# A-Z Punjabi Songs & Music Videos 2018 : 100,000
# 3D DJ – Music Mixer with Virtual DJ : 100,000
# 3D Color by Number: Voxel, Unicorn, Pixel Art 3D : 100,000
# 10 Minutes a Day Times Tables : 100,000
# du View : 50,000
# Zowi App : 50,000
# Yuzu eReader : 50,000
# Virtual Boyfriend Chat : 50,000
# University of Alabama : 50,000
# Universal AC Remote Control Simulator : 50,000
# The Lost Lands:DH Lite : 50,000
# Tamago Tap Clicker Egg : 50,000
# Summer Camp Island AR : 50,000
# Smokes Guide for CS:GO : 50,000
# Sketchfab : 50,000
# Shortcuts for After Effects : 50,000
# Shiver: Moonlit Grove CE : 50,000
# Royale Tournaments : 50,000
# Real AI : 50,000
# Quadratic Equation Solver with Steps and Graphs : 50,000
# Profile Pictures - Best DP Status : 50,000
# Pregnant Mom ER Emergency Doctor Hospital Games : 50,000
# Pony Friends 🦄 - Beepzz racing game for kids : 50,000
# Painting By Numbers : 50,000
# OTOME of Ikemen cafe : 50,000
# Nose Surgery ER Simulator Lite : 50,000
# My Nexus for CS:S & CS:GO : 50,000
# My Android Device S/W & H/W : 50,000
# Morse Player Free : 50,000
# Love Signal: D-Mate : 50,000
# Lie Detector : 50,000
# Learn C [NEW] : 50,000
# Learn Bulgarian Free : 50,000
# La Poupée du Voyant : 50,000
# Kiss Me! Lip Kissing Test : 50,000
# King Burger Dash : 50,000
# Job CV Maker-Portfolio Maker , Resume Maker : 50,000
# Intellijoy Early Learning Academy : 50,000
# Igitabo cy'Indirimbo : 50,000
# INFAMY RO : 50,000
# Hadith du jour : 50,000
# Guardians of Ancora : 50,000
# Going Abroad : 50,000
# Free Florida DMV Test 2018 : 50,000
# Fantasy Squad W : 50,000
# Fake Call From Wengie Prank : 50,000
# FR: My Secret Pets!  : 50,000
# FL Lottery Results : 50,000
# European Union Simulator : 50,000
# Elif Ba - Learn The Holy Quran : 50,000
# Ek Kauwa Pyasa Tha : 50,000
# ER Blood Draw Doctor & Surgeon : 50,000
# EF Parеnts : 50,000
# EF Mentor: Words : 50,000
# EF English Live for tablets : 50,000
# EF Classroom : 50,000
# Dx Ludo : 50,000
# CritDice - Dice Roller : 50,000
# Cook 'n Learn Smart Kitchen : 50,000
# CompTIA Exam Training : 50,000
# Car Parking Crane N Drifting : 50,000
# Cambridge English FC : 50,000
# CT Lottery : 50,000
# CS Guns Shoot : 50,000
# CK-12: Practice Math & Science : 50,000
# C Programming Zone : 50,000
# Break the Egg : 50,000
# Blood Injection : ER Emergency Doctor ER injection : 50,000
# Block Puzzle : Night in Egypt : 50,000
# Beast of Lycan Isle CE : 50,000
# BP Scanner Prank : 50,000
# BJ-UFO : 50,000
# BF games : 50,000
# BF 4 Guns : 50,000
# BD Radio TV Free List : 50,000
# BD All Results : 50,000
# Artificial Intelligence : 50,000
# All-in-One Mahjong 3 FREE : 50,000
# Alif Ba Ta Song - Arabic Kids : 50,000
# Account Class-12 Solutions (D K Goel) Vol-1 : 50,000
# Account Class-11 Solutions (D K Goel) : 50,000
# AV Pro Voice Changer : 50,000
# AR Dragon Pet : 50,000
# AQ: First Contact : 50,000
# AP Psychology Prep: Practice Tests and Flashcards : 50,000
# AK Math Coach : 50,000
# AJ Academy: Amazing Animals : 50,000
# 101 C Programming Problems : 50,000
# v-view : 10,000
# the Egg - crack the egg : 10,000
# cx-33wifi : 10,000
# cx-32wifi : 10,000
# codeEazy - C/C++/JAVA : 10,000
# cg guruji : 10,000
# Z-Empire: Dead Strike : 10,000
# Yaoi Novels - Shounen ai Book&fiction : 10,000
# YEBIS OpenGL ES 3.0 Tech Demo : 10,000
# Wi u Emulator : 10,000
# Who Viewed My FB Profile : 10,000
# Visuelles Wörterbuch Audio-App : 10,000
# Virtual Mother Surgery Doctor : Emergency Hospital : 10,000
# Villains vs Superheroes : 10,000
# University of Florida : 10,000
# Union League : 10,000
# Ultrasound A-Z : 10,000
# Toys Defense: Horror Land : 10,000
# Toy Battle Z : 10,000
# The CW TN app 2018 : 10,000
# TV.AE : 10,000
# TV Local El Salvador : 10,000
# T Uploader : 10,000
# Super Doctor 1-Pregnant Mom ER Surgery Simulator : 10,000
# Super AR : 10,000
# Sufara.ba : 10,000
# Study AP World History : 10,000
# Start the Hunt for the Lost Treasure : 10,000
# Spinal Cord Surgery Doctor: Operation ER surgery : 10,000
# Spacecraft AR : 10,000
# Solar System AR ( ARCore ) : 10,000
# Skill Tree - BL Pre Sequel : 10,000
# Shoulder Surgery ER Emergency Doctor Game : 10,000
# Servidor Privado de CR y CoC - Light Royale : 10,000
# Romance et Mystères au Lycée : 10,000
# RoboPad++ : 10,000
# Red Embrace (BL/Yaoi Game) : 10,000
# R Programming Solution : 10,000
# QST : 10,000
# Q Wunder : 10,000
# Proverbes du monde : 10,000
# Professor Online SEDUC-CE : 10,000
# Pregnant Mom Surgery Newborn Twins Baby Birth Care : 10,000
# Pocket U ASW : 10,000
# Pinoy Kid Song Ako ay may Lobo : 10,000
# Permit Test FL Florida DHSMV : 10,000
# Permit Test Connecticut CT DMV : 10,000
# Permit Test AZ Arizona MVD DOT : 10,000
# POLARIS 2MFG : 10,000
# Old: CL-150 : 10,000
# OFF-ROAD SIMULATOR 4x4 : REAL : 10,000
# Nasihat - Chalo ae Pyaara : 10,000
# Nancy Drew Codes and Clues : 10,000
# N-Back : 10,000
# My Theme Park: RollerCoaster & Water Park Tycoon : 10,000
# My EF Center : 10,000
# Multi Surgery ER Emergency Hospital : Doctor Game : 10,000
# Monster Park AR - Jurassic Dinosaurs in Real World : 10,000
# Mom Doctor ER Emergency Family Game : 10,000
# Math Quiz Free: Grades K,1,2,3 : 10,000
# Make a burger king : 10,000
# Maher EL Mouaikly - Offline : 10,000
# MJX H : 10,000
# Louis CK : 10,000
# Live Radio BD : 10,000
# Let's Learn Alif Ba Ta : 10,000
# Learn alif ba ta : 10,000
# Learn R Language Easy Way : 10,000
# Learn C Programming (Examples) (OFFLINE) : 10,000
# Learn Artificial Intelligence : 10,000
# Knightfall™ AR : 10,000
# Kiddopia - Preschool Learning Games : 10,000
# K-pop Music : 10,000
# Jenga® AR : 10,000
# Jarvis artificial intelligent : 10,000
# JONACK (D Story Teller) : 10,000
# J-Novel Club : 10,000
# I AM RICH : 10,000
# How it Works: FN SCAR assault rifle : 10,000
# Hidden Objects Treasure Hunt Adventure Games : 10,000
# Hidden Object Florida Vacation Adventure Fun Game : 10,000
# Hand Doctor Games ER Surgery Simulator : 10,000
# Gun Simulator - Gun Games : 10,000
# Grenade Practice for CS:GO : 10,000
# Goody.ba : 10,000
# GF - BF Chat Stories - Hindi English Convesation : 10,000
# GATE CS Engineering 2019 Exam Prep App : 10,000
# Fortune Quest: Savior : 10,000
# Florida DMV Permit Test -Fl : 10,000
# FlexBook : 10,000
# Fashion Pony Girls Dress Up Makeup Game : 10,000
# Fashion Girls Dress up Makeup : 10,000
# FR: My Famous Lover : 10,000
# FD VR Store -VR Games and Apps : 10,000
# FD VR Player - for 360 Youtube : 10,000
# FD VR Cardboard Featured 360 Videos : 10,000
# FD VR - Virtual Photo Gallery : 10,000
# Ethical Hacking : 10,000
# English for Everyone : 10,000
# English Bite : 10,000
# Elemental Galaxy Dx - Match3 : 10,000
# Ek Onkar : 10,000
# Ek Bander Ne Kholi Dukan : 10,000
# Ei-ij Spelling Dutch : 10,000
# Eating Show - Food BJ : 10,000
# EP Chain Reaction : 10,000
# EF Smart English for Phone : 10,000
# EF English Live Business Tablet : 10,000
# EB Mobile : 10,000
# Driving Suv Toyota Car Simulator : 10,000
# Daily K-Talk : 10,000
# DZ Blagues : 10,000
# DX Simulation for OOO Dx Belt : 10,000
# DX Simulation Belt for Build henshin : 10,000
# DV-LOTTERY 2019 REGISTRATION : 10,000
# DV-2019 Results : 10,000
# DT Driving Test Theory : 10,000
# DRC Sim - Wii U Gamepad : 10,000
# DR CONTROL : 10,000
# DQSalmaan - A fan made App : 10,000
# Crack the blue angry birds egg : 10,000
# Comptia A+ 220-901 & 220-902 : 10,000
# CompTIA A+ Pocket Prep : 10,000
# City Driving Jeep Mania: Parking Passion 2018 : 10,000
# Christian Questions Podcast : 10,000
# Cerulean Heart : 10,000
# Car Driving Simulator Citroen : 10,000
# Calculate My IQ : 10,000
# CX-WiFi720P : 10,000
# CX-17WIFI : 10,000
# CV Creator : 10,000
# CT-Stream Player : 10,000
# CS-Touch : 10,000
# CS Interview FAQs : 10,000
# CP evolution calculator Pokemo : 10,000
# CP Creepypasta : 10,000
# CP Calculator : 10,000
# CN Sayin' - Cartoon Network : 10,000
# CJ SO COOL : 10,000
# CG Shikshak : 10,000
# CG Samanya Gyan : 10,000
# CG Job Alerts : 10,000
# CE Broker : 10,000
# CASE K-12 Math English Science : 10,000
# C Examples : 10,000
# C BOOK-C PROGRAMS : 10,000
# Burger King Foot Lettuce : 10,000
# Bubble Bo-Bo : 10,000
# Bsc Agri Notes : 10,000
# Br Shafi : 10,000
# BkEmu - BK-0010/11M emulator : 10,000
# Bg TV Online : 10,000
# Best DP And Video Status 2018 For Whatsapp : 10,000
# Be Like Bro - Compilation : 10,000
# Baba Yaad Hai?(BK's) : 10,000
# BU Mobile : 10,000
# BSc Ag Entrance Preparation : 10,000
# BSC IT : 10,000
# BK Murli Dictionary (H to E) : 10,000
# BF Movies Fun : 10,000
# BF Abstract 3d Pictures : 10,000
# BD Earn Pro : 10,000
# BA VPN - Free Unlimited VPN : 10,000
# Az Content : 10,000
# Arizona Mobile : 10,000
# Arizona DMV Permit Test - AZ : 10,000
# Arabic Alphabet Alif Ba Ta Wooden Blocks : 10,000
# Anime Expo 2018 : 10,000
# Alabama DMV Permit Test - AL : 10,000
# Al-Quran Al-Muallim : 10,000
# Ah! Cutie : 10,000
# Ad-free Triangle Solver : 10,000
# Account Class-12 Solutions (D K Goel) Vol-2 : 10,000
# AZ Lottery Players Club : 10,000
# AV Phonetics : 10,000
# AV High School District : 10,000
# AU Students Zone (Result 2016) : 10,000
# AU Spark : 10,000
# AR Toys: Playground Sandbox | Remote Car : 10,000
# AR Sport Cars : 10,000
# AP Mobile : 10,000
# AP Flashcards : 10,000
# AP Chemistry Prep: Practice Tests and Flashcards : 10,000
# AP Biology Study Guide + Quiz : 10,000
# AP Biology Prep: Practice Tests, Flashcards : 10,000
# AK-47 Assault Rifle : 10,000
# AK Interactive : 10,000
# AB Crush Match 3 : 10,000
# AB Blast Match 3 : 10,000
# 3DAnimeGirl DX DreamPortrait KAWAII Girl DressUp : 10,000
# studentsLife by FH Kärnten : 5,000
# learn c in hindi : 5,000
# bX Hot Articles by Ex Libris : 5,000
# Weapons simulator AK-47 : 5,000
# Voyance du pyromancien : 5,000
# Virtual Brain Surgery Simulator : Kid ER Emergency : 5,000
# USMLE Step 2 CK Cards Lite : 5,000
# Truck Simulator DT 3D : 5,000
# The DL Hughley Show : 5,000
# The CW TV app : 5,000
# ...
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000
# 50000 Free eBooks & Free AudioBooks : 5,000,000
# wikiHow: how to do anything : 1,000,000
# eBoox: book reader fb2 epub zip : 1,000,000
# Stats Royale for Clash Royale : 1,000,000
# Satellite AR : 1,000,000
# ReadEra – free ebook reader : 1,000,000
# Oxford A-Z of English Usage : 1,000,000
# My Little Pony AR Guide : 1,000,000
# Koran Read &MP3 30 Juz Offline : 1,000,000
# Hafizi Quran 15 lines per page : 1,000,000
# Golden Dictionary (EN-AR) : 1,000,000
# Free Books - Spirit Fanfiction and Stories : 1,000,000
# FamilySearch Tree : 1,000,000
# English-Myanmar Dictionary : 1,000,000
# EGW Writings : 1,000,000
# Cloud of Books : 1,000,000
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000
# Book store : 1,000,000
# All Maths Formulas : 1,000,000
# All Language Translator Free : 1,000,000
# Al Quran Al karim : 1,000,000
# Youboox - Livres, BD et magazines : 500,000
# SDA Sabbath School Quarterly : 500,000
# Recipes of Prophetic Medicine for free : 500,000
# Only 30 days in English, the guideline is guaranteed : 500,000
# Offline: English to Tagalog Dictionary : 500,000
# NOOK Audiobooks : 500,000
# NOOK App for NOOK Devices : 500,000
# Google I/O 2018 : 500,000
# Golden Dictionary (FR-AR) : 500,000
# Flybook : 500,000
# English to Urdu Dictionary : 500,000
# English Persian Dictionary : 500,000
# English Grammar Complete Handbook : 500,000
# Azpen eReader : 500,000
# Al-Quran 30 Juz free copies : 500,000
# Al Quran (Tafsir & by Word) : 500,000
# cloudLibrary : 100,000
# V Made : 100,000
# URBANO V 02 instruction manual : 100,000
# Surah Al-Waqiah : 100,000
# Sabbath School : 100,000
# Pdf Book Download - Read Pdf Book : 100,000
# Offline English Dictionary : 100,000
# Litnet - E-books : 100,000
# Hymnes et Louanges : 100,000
# How to Write CV : 100,000
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000
# Guide (for X-MEN) : 100,000
# Free Panda Radio Music : 100,000
# Free Book Reader : 100,000
# English translation from Bengali : 100,000
# EGW Writings 2 : 100,000
# Download free book with green book : 100,000
# Bible with EGW Comments : 100,000
# BakaReader EX : 100,000
# Aab e Hayat Full Novel : 100,000
# eBoox new: Reader for fb2 epub zip books : 50,000
# SH-02J Owner's Manual (Android 8.0) : 50,000
# La citadelle du musulman : 50,000
# Fertilizer Removal By Crop : 50,000
# EZ Quran : 50,000
# E-Book Read - Read Book for free : 50,000
# DV 2019 - EDV Photo & Form : 50,000
# C Programs and Reference : 50,000
# C Programs Handbook : 50,000
# Bible du Semeur-BDS (French) : 50,000
# Al-Muhaffiz : 50,000
# TN Patta Citta & EC : 10,000
# R Language Reference Guide : 10,000
# Kristian Hla Bu : 10,000
# Kinot & Eichah for Tisha B'Av : 10,000
# Guide for DB Xenoverse 2 : 10,000
# Guide for DB Xenoverse : 10,000
# English To Shona Dictionary : 10,000
# Easy Cv maker 2018 : 10,000
# DV 2019 Entry Guide : 10,000
# DM Screen : 10,000
# Bulgarian French Dictionary Fr : 10,000
# Borneo Bible, BM Bible : 10,000
# Bootable Methods(USB-CD-DVD) : 10,000
# BR Ambedkar Biography & Quotes : 10,000
# BD All Sim Offer : 10,000
# B&H Kids AR : 10,000
# Ay Mohabbat Teri Khatir Novel : 10,000
# Ay Hasnain k Nana Milad Naat : 10,000
# Anonymous caller detection : 10,000
# Ag PhD Field Guide : 10,000
# Ag PhD Deficiencies : 10,000
# Ae Allah na Dai (Rasa) : 10,000
# AP Stamps and Registration : 10,000
# Learn R Programming Full : 5,000
# Learn CT Scan Of Head : 5,000
# Fanfic-FR : 5,000
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000
# EC - AP & Telangana : 5,000
# Duaa Ek Ibaadat : 5,000
# DC HSEMA : 5,000
# CA Laws 2018 (California Laws and Codes) : 5,000
# Browsery by Barnes & Noble : 5,000
# Bilingual Dictionary Audio App : 5,000
# B y H Niños ES : 5,000
# AY Sing : 5,000
# AW Tozer Devotionals - Daily : 5,000
# AC Air condition Troubleshoot,Repair,Maintenance : 5,000
# bp e-store : 1,000
# Tozer Devotional -Series 1 : 1,000
# The SCP Foundation DB fr nn5n : 1,000
# The Pursuit of God : 1,000
# SA HLA BU : 1,000
# R Quick Reference Big Data : 1,000
# R Programing Offline Tutorial : 1,000
# Painting Lulu DC Super Friends : 1,000
# La Fe de Jesus : 1,000
# Greek Bible FP (Audio) : 1,000
# Florida Statutes (FL Code) : 1,000
# Florida - Pocket Brainbook : 1,000
# Fix Error Google Playstore : 1,000
# EU Data Protection : 1,000
# EU Charter : 1,000
# EP Research Service : 1,000
# EB Annual Meetings : 1,000
# Dr. Doug's Tips : 1,000
# DV 2018 Winners Guide : 1,000
# DC Public Library : 1,000
# D. H. Lawrence Poems FREE : 1,000
# Chemin (fr) : 1,000
# CW Nuclear : 1,000
# C Offline Tutorial : 1,000
# BM Box : 1,000
# BD Fishpedia : 1,000
# Arizona Statutes, ARS (AZ Law) : 1,000
# Ag PhD Soybean Diseases : 1,000
# Ag PhD Planting Population Calculator : 1,000
# AE Bulletins : 1,000
# SDA Collegiate Quarterly : 500
# Modlitební knížka CZ : 500
# Learn SAP BW on HANA : 500
# Learn SAP BW : 500
# Le Fe de Jesus : 500
# La Fe de Jesús : 500
# Catholic La Bu Zo Kam : 500
# MOD Black for BM : 100
# EU IP Codes : 100
# Cypress College Library : 100
# CompactiMa EC pH Calibration : 100
# BU Alsace : 100
# Anime Mod for BM : 100
# GATE 21 years CS Papers(2011-2018 Solved) : 50
# A-J Media Vault : 50
# Learn R Programming : 10
# Khrifa Hla Bu (Solfa) : 10
# Guide for IMS DB : 10
# CY Spray nozzle : 10
# Guide for R Programming : 5
# EW PDF : 5
# CZ-Help : 5
# BibleRead En Cy Zh Yue : 5
#
#
# PRODUCTIVITY
# Google Drive : 1,000,000,000
# Microsoft Word : 500,000,000
# Google Calendar : 500,000,000
# Dropbox : 500,000,000
# Cloud Print : 500,000,000
# WPS Office - Word, Docs, PDF, Note, Slide & Sheet : 100,000,000
# SwiftKey Keyboard : 100,000,000
# Samsung Notes : 100,000,000
# Microsoft PowerPoint : 100,000,000
# Microsoft Outlook : 100,000,000
# Microsoft OneNote : 100,000,000
# Microsoft OneDrive : 100,000,000
# Microsoft Excel : 100,000,000
# Google Slides : 100,000,000
# Google Sheets : 100,000,000
# Google Keep : 100,000,000
# Google Docs : 100,000,000
# Evernote – Organizer, Planner for Notes & Memos : 100,000,000
# ES File Explorer File Manager : 100,000,000
# ColorNote Notepad Notes : 100,000,000
# CamScanner - Phone PDF Creator : 100,000,000
# Adobe Acrobat Reader : 100,000,000
# myAT&T : 50,000,000
# Verizon Cloud : 50,000,000
# QR Droid : 50,000,000
# My Airtel-Online Recharge, Pay Bill, Wallet, UPI : 50,000,000
# Mobizen Screen Recorder - Record, Capture, Edit : 50,000,000
# MEGA : 50,000,000
# File Browser by Astro (File Manager) : 50,000,000
# Do It Later: Tasks & To-Dos : 50,000,000
# Calculator - unit converter : 50,000,000
# Alarm Clock: Stopwatch & Timer : 50,000,000
# Advanced Task Killer : 50,000,000
# iTranslate Translator & Dictionary : 10,000,000
# aCalendar - Android Phone : 10,000,000
# Wunderlist: To-Do List & Tasks : 10,000,000
# U+Box : 10,000,000
# Todoist: To-do lists for task management & errands : 10,000,000
# S Note : 10,000,000
# QR Scanner & Barcode Scanner 2018 : 10,000,000
# Polaris Office - Word, Docs, Sheets, Slide, PDF : 10,000,000
# Notepad & To do list : 10,000,000
# Notepad : 10,000,000
# NQ Mobile Security & Antivirus : 10,000,000
# MyVodafone (India) - Online Recharge & Pay Bills : 10,000,000
# Mobile Security: Antivirus, Web Scan & App Lock : 10,000,000
# Mobile Security & Antivirus : 10,000,000
# Metro name iD : 10,000,000
# LOCX Applock Lock Apps & Photo : 10,000,000
# Keeper: Free Password Manager & Secure Vault : 10,000,000
# Jorte Calendar & Organizer : 10,000,000
# HTC Mail : 10,000,000
# HTC File Manager : 10,000,000
# HTC Calendar : 10,000,000
# Google PDF Viewer : 10,000,000
# Google Assistant : 10,000,000
# Fake Call - Fake Caller ID : 10,000,000
# Easy Voice Recorder : 10,000,000
# Chrome Beta : 10,000,000
# CM FILE MANAGER HD : 10,000,000
# AutoCAD - DWG Viewer & Editor : 10,000,000
# Any.do: To-do list, Calendar, Reminders & Planner : 10,000,000
# AndroZip™ FREE File Manager : 10,000,000
# All-In-One Toolbox: Cleaner, Booster, App Manager : 10,000,000
# AVG Cleaner – Speed, Battery & Memory Booster : 10,000,000
# AT&T Mobile Transfer : 10,000,000
# ASUS SuperNote : 10,000,000
# ASUS Quick Memo : 10,000,000
# ASUS Calling Screen : 10,000,000
# APUS Booster - Space Cleaner & Booster : 10,000,000
# lifebox : 5,000,000
# Yandex.Disk : 5,000,000
# Ultimate Notepad : 5,000,000
# Trello : 5,000,000
# To Do List : 5,000,000
# The Maner : 5,000,000
# PDF Viewer & Book Reader : 5,000,000
# Note Everything : 5,000,000
# My Claro Peru : 5,000,000
# Microsoft Translator : 5,000,000
# MediaFire : 5,000,000
# Keep My Notes - Notepad & Memo : 5,000,000
# Ginger Keyboard - Emoji, GIFs, Themes & Games : 5,000,000
# G Cloud Backup : 5,000,000
# EBookDroid - PDF & DJVU Reader : 5,000,000
# DigiCal Calendar Agenda : 5,000,000
# Content Transfer : 5,000,000
# Clean My Android : 5,000,000
# Calendar Widget Month + Agenda : 5,000,000
# Business Calendar 2 : 5,000,000
# Archos File Manager : 5,000,000
# pCloud: Free Cloud Storage : 1,000,000
# e-Boks.dk : 1,000,000
# Ultimate Chest Tracker : 1,000,000
# Today Calendar 2017 : 1,000,000
# To-Do List Widget : 1,000,000
# To-Do Calendar Planner : 1,000,000
# To Do Reminder with Alarm : 1,000,000
# Time Recording - Timesheet App : 1,000,000
# TickTick: To Do List with Reminder, Day Planner : 1,000,000
# S’more - Earn Cash Rewards : 1,000,000
# SugarSync : 1,000,000
# Sticky Note + : Sync Notes : 1,000,000
# Squid - Take Notes & Markup PDFs : 1,000,000
# Solid Explorer File Manager : 1,000,000
# Solid Explorer Classic : 1,000,000
# Smart File Manager : 1,000,000
# Simple Notepad : 1,000,000
# Security & Privacy : 1,000,000
# Resume Free : 1,000,000
# Pushbullet - SMS on PC : 1,000,000
# Power Booster - Junk Cleaner & CPU Cooler & Boost : 1,000,000
# Planner Pro-Personal Organizer : 1,000,000
# Phone Clean Best Speed Booster : 1,000,000
# NoteToDo. Notes. To do list : 1,000,000
# New Calendar : 1,000,000
# Můj T-Mobile Business : 1,000,000
# MyMTN : 1,000,000
# Multiling O Keyboard + emoji : 1,000,000
# Microsoft To-Do: List, Task & Reminder : 1,000,000
# Mahalaxmi Dindarshika 2018 : 1,000,000
# Lyra Virtual Assistant : 1,000,000
# Loop - Habit Tracker : 1,000,000
# JotterPad - Writer, Screenplay, Novel : 1,000,000
# IFTTT : 1,000,000
# Hacker's Keyboard : 1,000,000
# Google AdSense : 1,000,000
# Extreme- Personal Voice Assistant : 1,000,000
# Epson iProjection : 1,000,000
# Emoji Android L Keyboard : 1,000,000
# EX File Explorer File Manager : 1,000,000
# ES Material Theme for Pro : 1,000,000
# Do it (Tomorrow) : 1,000,000
# Dashlane Free Password Manager : 1,000,000
# DS file : 1,000,000
# Cozi Family Organizer : 1,000,000
# Chrome Canary (Unstable) : 1,000,000
# Chelsea FC Official Keyboard : 1,000,000
# Calendar+ Schedule Planner App : 1,000,000
# Cal - Google Calendar + Widget : 1,000,000
# CY Security Antivirus Cleaner : 1,000,000
# Avast Wi-Fi Finder : 1,000,000
# Amazon Drive : 1,000,000
# Adobe Fill & Sign: Easy PDF Form Filler : 1,000,000
# Adblock Fast : 1,000,000
# ALL-IN-ONE PACKAGE TRACKING : 1,000,000
# AL Voice Recorder : 1,000,000
# Ultimate Calculator for CR : 500,000
# Time Planner - Schedule, To-Do List, Time Tracker : 500,000
# T-Mobile Content Transfer : 500,000
# Q Link Wireless Zone : 500,000
# Planning Center Services : 500,000
# Official QR Code® Reader "Q" : 500,000
# My Effectiveness: To do, Tasks : 500,000
# Memory Helper - To do list, Notepad, Notes, Memo : 500,000
# ES Holo Theme for Pro : 500,000
# DS cam : 500,000
# Ad Detect Plugin - Handy Tool : 500,000
# A-Z App Store : 500,000
# 7 Weeks - Habit & Goal Tracker : 500,000
# cm, mm to inch, feet converter tool : 100,000
# Unclouded - Cloud Manager : 100,000
# Total AV : 100,000
# TIMBER AD FILTER - Very useful ad block app : 100,000
# Synology Drive : 100,000
# Resume Builder and CV maker app : 100,000
# Pocket RxTx Free : 100,000
# MyLifeOrganized: To-Do List : 100,000
# Inch/cm/Foot Conversion : 100,000
# Ike - To-Do List, Task List : 100,000
# IQ Test : 100,000
# IDM for Facebook ★ Downloader : 100,000
# IDM Internet Download Manager : 100,000
# Goal Meter: Goal Tracker, Habit Changer,To-Do List : 100,000
# Future Cloud : 100,000
# Friday: Smart Personal Assistant : 100,000
# File Explorer : 100,000
# Exército Brasileiro : 100,000
# EZ Switch Widget : 100,000
# EZ File Manager(Root Explorer) : 100,000
# ES Disk Analyzer - Storage Space : 100,000
# Dz Dinars Numbers to letters : 100,000
# Dr.Android Repair Master 2017 : 100,000
# Download Manager Pro FREE : 100,000
# Do Not Disturb : 100,000
# DS note : 100,000
# Clean My House – Chore To Do List, Task Scheduler : 100,000
# Calculator L : 100,000
# Bits Watch Face : 100,000
# Best Applock - Locker & No Ads : 100,000
# 2Do - Reminders, To-do List & Notes : 100,000
# WiFi-o-Matic : 50,000
# WFVS 2018 | WhatApp Full Video Status & Downloader : 50,000
# U Assist - Screen Mirroring & Sharing App : 50,000
# To-do list : 50,000
# Safe Notes - Secure Ad-free notepad : 50,000
# SH Script Runner : 50,000
# Numbers Into Words : 50,000
# My C Spire : 50,000
# MultiMessage for FB Messenger : 50,000
# Inputting Plus: Ctrl + Z/F/C/V : 50,000
# EZ Display : 50,000
# ESLock File Recovery Lite : 50,000
# CTRL-F - Search the real world : 50,000
# BJ Memo Widget : 50,000
# Add-On: Alcatel (h) : 50,000
# ai.Bot Box : 10,000
# Wi-Fi Networks : 10,000
# Trimble DL : 10,000
# Trimble Ag Mobile : 10,000
# Tap N Pay : 10,000
# Solar CT PV System Power : 10,000
# Remote Control For All AC - Universal Remote : 10,000
# N Files - File Manager & Explorer : 10,000
# Mix Tank – Tank Mixing Ag App : 10,000
# Larry H Miller Automotive : 10,000
# Eurostat Country Profiles : 10,000
# Electricity Bill Calculator BD : 10,000
# EZ Inspections : 10,000
# EC Taximeter : 10,000
# DG Report Reminder : 10,000
# Curriculum Vitae - Resume CV : 10,000
# CD Library : 10,000
# Alt-C : 10,000
# Turbo AI™ - Personal assistant : 5,000
# Resume & CV Creator by Desygner : 5,000
# R-net for Android : 5,000
# Mind Map AR, Augmented Reality ARCore Mind Mapping : 5,000
# EU Economy : 5,000
# ESS Mobile for AE : 5,000
# CG - Calendars Add-On : 5,000
# Bomb and Nade Timer for CS:GO : 5,000
# BA Calculator : 5,000
# Air Conditioner Maintenance : 5,000
# Add-On: bq (a) : 5,000
# AP ENPS Mobile : 5,000
# Simple EV Calc : 1,000
# Sai Baba - Sabka Malik Ek : 1,000
# Safe Wi-Fi : 1,000
# Puck AI Personal Assistant Robot : 1,000
# Professional AV Solution & Products information : 1,000
# New Holland Agriculture T5 EC : 1,000
# My CU - Caucasus University : 1,000
# Krypton by krypt.co : 1,000
# Fayr - Co-Parenting Simplified : 1,000
# FQ METER : 1,000
# FL House : 1,000
# EZ Notes Lite : 1,000
# EF Calculator : 1,000
# DS-20000S : 1,000
# DG Phone Call Task Switcher : 1,000
# DB Manager : 1,000
# Commission Manager : 1,000
# CircleCI Viewer : 1,000
# Charlotte County, FL : 1,000
# Calendars (En, Bn, Ar) : 1,000
# CG - Conference Call Add-On : 1,000
# CA World '17 : 1,000
# BG+Phone Backup : 1,000
# BD Field Force : 1,000
# BD Attendance : 1,000
# Ag PhD Soils : 1,000
# Add-On: bq (c) : 1,000
# Add-On: bq (b) : 1,000
# AI Sight : 1,000
# Tips Microsoft Dynamics Ax : 500
# Q Actions - Digital Assistant : 500
# IP address BW : 500
# Florida Cooling Supply HVAC : 500
# Fast Notes FJ : 500
# Ek Vote : 500
# EY Events Switzerland : 500
# EY ATL Fuel Calculator : 500
# DT Manager : 500
# DN Events : 500
# CP Connect 2.0 : 500
# CJ Wilson's ZoomZoomnation : 500
# BZ Dealer : 500
# iReadMe : 100
# ec-Work : 100
# eG Monitor : 100
# Town of Princeton, BC : 100
# Tips & Tricks Dynamics AX 365 : 100
# Thistletown CI : 100
# Somos CG : 100
# SCS eC : 100
# RoutePlan.cz : 100
# Register.ca Mobile : 100
# MiAI (Artificial Intelligence) Assistant : 100
# Mat|r viewer : 100
# K-App Mitarbeiter Galeria Kaufhof : 100
# J. Polep Plus Mobile : 100
# Fort Myers FL : 100
# ES Billing System (Offline App) : 100
# EP Home Energy Hub : 100
# EG : 100
# EF Staff : 100
# DG Users : 100
# DF-Server Mobile : 100
# Cx Wize : 100
# CJ'S TIRE AND AUTO INC. : 100
# CI Time : 100
# CI Remote for Go : 100
# CI CAFETERIAS UBER : 100
# Builder (by Engineer.ai) : 100
# BW-IVMS : 100
# BV Mobile Apps : 100
# Ag Trucking Mobile App : 100
# Ag Guardian : 100
# My Ag Report : 50
# MY GULFPORT FL : 50
# EY Team Connect : 50
# EB Scanner : 50
# CX Summit : 50
# CT CONNECT : 50
# CONNECT: The Mobile CX Summit : 50
# CE SODEXO PASS FRANCE : 50
# BN DB1 App : 50
# BAMMS for BM 1Park : 50
# SKIN BK : 10
# PLMGSS FR : 10
# My CG : 10
# MinT BI : 10
# EU Brazil Green Business Forum : 10
# ER Assist : 10
# EP Cloud : 10
# EI! : 10
# EC QR : 10
# DV Web Design Tips : 10
# CQ Ukraine : 10
# BW t&t : 10
# BW Ultra : 10
# BN Inscript Improved Keyboard : 10
# BN Inscript Improved Input keyboard : 10
# BM Interventi : 10
# BAMMS for BM SQ : 10
# AQ Guards : 10
# APagri CD : 10
# ACCEPT CE MARKING : 10
# Shaggy's DM Assistant : 5
# FK Events : 5
# EC Sampler : 1
# DZ Register : 1
# DT Freight : 1
# CQ Electrical Group : 1

# %%
average_installs('COMICS')
average_installs('EDUCATION')
average_installs('FAMILY')
average_installs('SPORTS')
average_installs('BOOKS_AND_REFERENCE')
average_installs('PRODUCTIVITY')
# Out:
# COMICS
# Number of apps : 55
# Number of apps under 100 million : 55
# Average installs for apps under 100 million : 817,657
#
#
# EDUCATION
# Number of apps : 103
# Number of apps under 100 million : 103
# Average installs for apps under 100 million : 1,833,495
#
#
# FAMILY
# Number of apps : 1675
# Number of apps under 100 million : 1661
# Average installs for apps under 100 million : 2,344,308
# Average installs for apps at and over 100 million : 164,285,714
#
#
# SPORTS
# Number of apps : 301
# Number of apps under 100 million : 299
# Average installs for apps under 100 million : 2,994,083
# Average installs for apps at and over 100 million : 100,000,000
#
#
# BOOKS_AND_REFERENCE
# Number of apps : 190
# Number of apps under 100 million : 185
# Average installs for apps under 100 million : 1,437,212
# Average installs for apps at and over 100 million : 280,000,000
#
#
# PRODUCTIVITY
# Number of apps : 345
# Number of apps under 100 million : 323
# Average installs for apps under 100 million : 3,379,657
# Average installs for apps at and over 100 million : 213,636,364

# %% [markdown]
# The `COMICS` genre has quite a low average installs per app at `817,657`. While there might be some opportunity here due to less competition from bigger developers, the potential for profitability would be less compared to the other genres listed above. However the idea of an app we have suggested for the `Book` Genre on the App Store could be replicated for the `COMICS` genre where instead the app can focus on user created comics and graphic novels. The same idea with users networking with each other and sharing their created works. This type of app would also fit under the `Book` genre on the App Store.
#
# The `EDUCATION` genre's apps all have less than 50 million installs. This means compared to other genres we would be competing against less dominating apps. With an average of `1,833,495` installs per app we could see better profitability than with the `LIBRARIES_AND_DEMO` and `COMIC` genres. As was the case with the App Store we see the same types of apps here with game-style education apps, utility apps designed for educational institutions or environments, and strictly learning based on such topics as programming, foreign languages and maths. As with the App Store we can draw the same conclusions for this genre by looking to develop a gamification educational app that aims for a younger audience or those with a lower overall level of education. This can help us stand out amongst the apps in this genre, as it appears to be filled with 'brain training/cogntive games' or straight up course and module structured learning apps. There is not really a blending of the two in this genre.
#
# As with the `Game` genre being oversaturated on the App Store we decided not to investigate it for the Google Play Store either. For the same reasons is why we will not be looking to develop an app for the `FAMILY` genre as it looks to be for game apps aimed at children. It also suffers the same problem as with the `GAME` genre with it containing lots of apps (`1675` in this case) that do not get much traction and so it would be harder for us to compete within this genre.
#
# The `SPORTS` genre has far more apps than it does on the App Store, it also includes gaming apps as well that are focused on sports such as `PES CLUB MANAGER` and `EA SPORTS UFC`. While the App Store's genre had `69` apps, the Google Play Store contains `301` suggesting a potential for more competition on this store. There also appears to be only 2 apps within this genre that have over 100 million installs and when these are removed the average installs per app drops from `3,638,640` to `2,994,083`. Compared to other genres on the Google Play Store this is a good result as we will have less big competitors to deal with. Within the App Store there are fantasy league sports apps, this si also the case in the Google Play Store as well, and as suggested on our analysis of this genre for the App Store we will need to innovate and add extra features to stand out amongst the fantasy league sports apps. As noted before because of the way that Google Play Store has decided to categorise sports gaming apps, under this genre, we will be competing with them for this market. Though by focusing the gaming aspects on party activites such as trivia and quizzes it can offer something different to what the core gaming apps offer in this genre.
#
# Looking at the `BOOKS_AND_REFERENCE` genre on we can already see that there are considerably more apps (190) than with the `Books` (14 apps) and the `Reference` (18 apps) genres combined on the App Store. What this can mean is that developing an app for this genre may prove to be more profitable on the App Store, by virtue of there being less competiton, than on the Google Play Store. For the Google Play Store there also appears to be more apps designed to be dictionaires and far more apps dedicated to a single book, there are quite a few that have been for the Quran for example. For this genre there are only 5 apps that have over 100 million installs, however there is a signifcant decrease in average installs per app when these apps are removed from `8,767,811` to `1,437,212`. Here we are also seeing some apps that are skewing the popularity of this genre. For this genre like on the App Store, `BOOKS_AND_REFERENCE`has libraries that are the most popular apps in the genre. As discussed previously having an app focusing a user created content with social/forum functions can help us stand out in this genre.
#
# The `PRODUCTIVITY` has the second most amount of apps for the 6 genres we have selected for potential app profiles above at `345`. This, like most of the other genres we have looked at for further analysis, is a considerably higher amount of apps than what is contained in the `Productivity` genre on the App Store at `56`. Here on the Google Play Store we can also see that this genre is much more popular, being the 5th most popular, but on the App Store this is not the case with the genre being in the bottom half in terms of popularity. We can see that are `22` apps in this genre on the Google Play Store that have over 100 million installs which certainly skew the popularity as when these are removed the average installs drops from `16,787,331` to `3,379,657`. However when we look at the apps that are popular on the Google PLay Store not all of them are as popular on the App Store. This could potentially be due to the user ratings of the App Store not working as general tool for popularity, as perhaps users of apps from the `Productivity` genre are less likely to rate those apps than with other genres. Here for designing an app we would also be facing more competition on the Google Play Store due to the higher number of apps present in this genre in comparison to the App Store. We could be facing a similar issue in terms of profitability like as discussed with the `BOOKS_AND_REFERENCE` genre. Much like with the App Store this genre is dominated by 'office' apps and developing a gamification office app would help it to stand out.

# %% [markdown]
# # Conclusion
#
# We set out on this project to find a profitable app profile that can be used across both the Google Play Store and the App Store. As our main source of revenue would come from in app advertisements we wanted to look at the data of free english apps.
#
# What we found is that they are multiple avenues that we can approach when designing a profitable app. Genres which seem to have potential across both stores are productivity, books and reference (books for Google Play Store), sports, and education. We wanted to develop apps for more practical purposes rather than entertainment or 'fun' due to the oversaturation of such genres as `GAME` and `Games`. This is refelected in the genres we decided to come up with app recommendations for.
#
# From the genres we investigated further for potential app profiles, we noticed that the majority of their Google Play Store equivalents had more apps. We have noted that this could mean that app we develop may end up performing better on the App Store due to less competition. However, as noted in our validation strategy we will be building the app for the Google Play Store first so we should be able to circumvent this issue.
